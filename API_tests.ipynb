# %%
# from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# from sklearn.decomposition import (
#     NMF, 
#     LatentDirichletAllocation,
#     TruncatedSVD
# )
import requests, gensim, spacy, json, nltk
import pandas as pd
from io import StringIO
# import warnings
# warnings.filterwarnings("ignore", category=DeprecationWarning)
# # warnings.filterwarnings('ignore')
# from sklearn.model_selection import GridSearchCV
# from nltk.tokenize import wordpunct_tokenize
# from nltk.metrics import ConfusionMatrix
# from nltk.tokenize import word_tokenize
# from nltk.probability import FreqDist
# from nltk.stem import PorterStemmer, WordNetLemmatizer
# import matplotlib.pyplot as plt
# from functools import reduce
# from time import time
# import numpy as np
# import re

# %% [markdown]
# ## Bing news search

# %%
import requests

url = "https://bing-news-search1.p.rapidapi.com/news/search?mkt=pt-br"

querystring = {"q":"<REQUIRED>","freshness":"Month","textFormat":"Raw","safeSearch":"Off"}

headers = {
    'x-bingapis-sdk': "true",
    'x-rapidapi-host': "bing-news-search1.p.rapidapi.com",
    'x-rapidapi-key': "0388aaee5emsh59b4fba5041dd03p1959efjsn7e9a12071136"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"_type": "News", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/news\/search?q=%3cREQUIRED%3e", "queryContext": {"_type": "QueryContext", "originalQuery": "<REQUIRED>", "adultIntent": false}, "totalEstimatedMatches": 11, "sort": [{"_type": "SortValue", "name": "Melhor correspondência", "id": "relevance", "isSelected": true, "url": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/news\/search?q=%3cREQUIRED%3e"}, {"_type": "SortValue", "name": "Mais recente", "id": "date", "isSelected": false, "url": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/news\/search?q=%3cREQUIRED%3e&sortby=date"}], "value": [{"_type": "NewsArticle", "name": "Celsius responds to NYAG crackdown on crypto lending platforms", "url": "https:\/\/br.advfn.com\/noticias\/COINTELEGRAPH\/2021\/artigo\/86321910", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=OVFT.3Ie3YcPObZ1wSu9dia5H4y&pid=News", "width": 700, "height": 466}}, "description": "'If any regulatory or technical changes are required in a specific jurisdiction, Celsius will provide clear and timely communication as needed,' said the firm. ...Continue reading", "provider": [{"_type": "Organization", "name": "ADVFN", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=ODF.hxKKM-JIHCNOU_ws5wG28w&pid=news"}}}], "datePublished": "2021-10-19T21:00:00.0000000Z", "category": "Brazil"}, {"_type": "NewsArticle", "name": "UK Gambling Commission opens inquiry into fantasy NFT soccer game Sorare", "url": "https:\/\/br.advfn.com\/noticias\/COINTELEGRAPH\/2021\/artigo\/86280487", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=OVFT.FM4D8U_zxV4_cYz33xp4ey&pid=News", "width": 700, "height": 466}}, "description": "The UK gambling watchdog is trying to determine whether or not fantasy NFT soccer game Sorare should be required to have a gambling license. ...Continue reading UK Gambling Commission", "provider": [{"_type": "Organization", "name": "ADVFN", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=ODF.hxKKM-JIHCNOU_ws5wG28w&pid=news"}}}], "datePublished": "2021-10-14T02:51:00.0000000Z"}, {"_type": "NewsArticle", "name": "Enterprise and Cyber Security Services from Fujitsu", "url": "https:\/\/www.fujitsu.com\/br\/products\/computing\/peripheral\/scanners\/business\/fi800r\/", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=OVFT.A5mI2aV2zj6sVY1EewT5hS&pid=News", "width": 311, "height": 126}}, "description": "Serviços de segurança corporativa e cibernética da Fujitsu. Os serviços de segurança cibernética orientados por inteligência da Fujitsu oferecem uma forma preditiva e em tempo real de identificar, ent", "about": [{"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/919266ec-4730-2a32-3e85-1a57c4f66c49", "name": "Fujitsu"}, {"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/a828cf41-b938-49fe-7986-4b336618d413", "name": "Brazil"}], "provider": [{"_type": "Organization", "name": "Fujitsu", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=ODF.2wEwzVVXn_tI_jir6fYJ2w&pid=news"}}}], "datePublished": "2021-10-25T19:30:00.0000000Z"}, {"_type": "NewsArticle", "name": "Tesla Cybertruck | Flagra em vídeo mostra novo protótipo sendo testado; veja", "url": "https:\/\/br.noticias.yahoo.com\/tesla-cybertruck-flagra-em-v%C3%ADdeo-195000203.html", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=OVFT.-gznn62pAk-WaEEOkQdViS&pid=News", "width": 700, "height": 393}}, "description": "Retrovisores chamaram atenção do público, mas o próprio Elon Musk comentou sobre eles; \"são o ...

# %%
len(response.text)
print(response)
# Out:
# <Response [200]>

# %%
import requests

url = "https://bing-news-search1.p.rapidapi.com/news"

querystring = {"safeSearch":"Off","textFormat":"Raw"}

headers = {
    'x-bingapis-sdk': "true",
    'x-rapidapi-host': "bing-news-search1.p.rapidapi.com",
    'x-rapidapi-key': "0388aaee5emsh59b4fba5041dd03p1959efjsn7e9a12071136"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"_type": "News", "webSearchUrl": "https:\/\/www.bing.com\/news\/search?q=top+stories&form=TNSA02", "value": [{"_type": "NewsArticle", "name": "These 5 Stocks Are in Line for Tax-Loss Selling. That’s an Opportunity.", "url": "https:\/\/www.barrons.com\/articles\/tax-loss-selling-stocks-opportunity-51635281673", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=OVFT.sm8OP3gkez5JxfRlfWAvWi&pid=News", "width": 700, "height": 350}}, "description": "October often brings the heaviest tax-loss selling, when fund managers unload money-losing stocks to offset gains from other ones.", "about": [{"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/458fb3ec-80f7-2a40-2f5e-ea0bf47fe7f6", "name": "Stock"}, {"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/be4b8d19-f2d8-860f-8afc-0d851fce4cd0", "name": "Selling"}, {"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/9dd49936-bcb7-56ac-d769-f94d457bf532", "name": "Tax"}], "provider": [{"_type": "Organization", "name": "Barron's", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=ODF.BNX5L8Z_CjgHVLbVH0I2NQ&pid=news"}}}], "datePublished": "2021-10-27T12:30:00.0000000Z"}, {"_type": "NewsArticle", "name": "COP26: Climate change protesters must not to distract from their message by causing too much disruption – Steve Cardownie", "url": "https:\/\/www.msn.com\/en-gb\/money\/other\/cop26-climate-change-protesters-must-not-to-distract-from-their-message-by-causing-too-much-disruption-steve-cardownie\/ar-AAPYnla", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=OVFT.nhsMCgBiXdolAP4E39aEZi&pid=News", "width": 700, "height": 367}}, "description": "The news that environmental activist Greta Thunberg will participate in “Friday’s For Future” Glasgow school strike march on November 5 is sure to boost the number of participants as they seek to convince world leaders attending the COP26 conference to take the appropriate action to avert a climate change disaster.", "about": [{"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/a46f1a91-44c3-4ad5-806b-095f7cffbfd8", "name": "Steve Cardownie"}, {"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/6d13718b-a368-291d-4b7d-4ff55ece9887", "name": "Climate change"}], "mentions": [{"_type": "Thing", "name": "Steve Cardownie"}, {"_type": "Thing", "name": "Climate change"}, {"_type": "Thing", "name": "Distraction"}], "provider": [{"_type": "Organization", "name": "MSN", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=ODF.FPGiCjSpNWuR3YuGCSVHjA&pid=news"}}}], "datePublished": "2021-10-27T12:30:00.0000000Z"}, {"_type": "NewsArticle", "name": "US is ‘years behind’ China on hypersonic weapons, Raytheon head says", "url": "https:\/\/www.scmp.com\/news\/china\/military\/article\/3153830\/us-years-behind-china-hypersonic-weapons-raytheon-head-says", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl": "https:\/\/www.bing.com\/th?id=OVFT.OkI-M9yR2v9wX4tpp7CqUy&pid=News", "width": 700, "height": 367}}, "description": "Defence contractor CEO Gregory Hayes says the superfast technology is the most destabilising threat to the homeland.", "about": [{"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/5fcc3d97-0cf2-94e5-6dad-cd70e387bd69", "name": "China"}, {"_type": "Thing", "readLink": "https:\/\/api.cognitive.microsoft.com\/api\/v7\/entities\/807ea597-509b-d501-da4d-32d60db15957", "name": "Raytheon"}], "provider": [{"_type": "Organization", "name": "South China Morning Post", "image": {"_type": "ImageObject", "thumbnail": {"_type": "ImageObject", "contentUrl" ...

# %%
# import requests

# url = "https://bing-news-search1.p.rapidapi.com/news/search"

# querystring = {"q":"<REQUIRED>","freshness":"Day","textFormat":"Raw","safeSearch":"Off"}

# headers = {
#     'x-bingapis-sdk': "true",
#     'x-rapidapi-host': "bing-news-search1.p.rapidapi.com",
#     'x-rapidapi-key': "0388aaee5emsh59b4fba5041dd03p1959efjsn7e9a12071136"
#     }

# response = requests.request("GET", url, headers=headers, params=querystring)

# print(response.text)

# %%
import requests

url = "https://bing-news-search1.p.rapidapi.com/news/trendingtopics"

querystring = {"textFormat":"Raw","safeSearch":"Off"}

headers = {
    'x-bingapis-sdk': "true",
    'x-rapidapi-host': "bing-news-search1.p.rapidapi.com",
    'x-rapidapi-key': "0388aaee5emsh59b4fba5041dd03p1959efjsn7e9a12071136"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)

# %% [markdown]
# ## NewsAPI

# %%
# Define API key and URLs for requests
headers = {'Authorization': '843f966d9f6d465bba288803803ee132'}
everything_news_url = 'https://newsapi.org/v2/everything'
sources_url = 'https://newsapi.org/v2/sources'

# %%
# headlines_payload = {'category': 'general', 'country': 'br, pt', "pageSize":100}
everything_politics_payload = {'q': 'congresso, política', 'language': 'pt', 'sortBy': 'popularity',\
                               'from':'2021-10-25', "pageSize":100}
everything_president_payload = {'q': "presidente, Bolsonaro", 'language': 'pt', 'sortBy': 'popularity',\
                               'from':'2021-10-25', "pageSize":100}
everything_economy_payload = {'q': "economia", 'language': 'pt', 'sortBy': 'popularity',\
                             'from':'2021-10-25', "pageSize":100}
everything_sports_payload = {'q': 'esporte', 'language': 'pt', 'sortBy': 'popularity',
                            'from':'2021-10-25', "pageSize":100}
sources_payload= {'category': 'general', 'language': 'pt'}
sports_sources_payload = {'category': 'sports', 'language': 'pt'}

# %%
resp_sources = requests.get(url = sources_url,\
                           headers = headers,\
                           params = sources_payload)
resp_sports_sources = requests.get(url = sources_url,\
                           headers = headers,\
                           params = sports_sources_payload)

# %%
response_politics = requests.get(url=everything_news_url,\
                                 headers=headers, params=everything_politics_payload)
response_president = requests.get(url=everything_news_url,\
                                  headers=headers, params=everything_president_payload)
response_economy = requests.get(url=everything_news_url,\
                                  headers=headers, params=everything_economy_payload)
response_sports = requests.get(url=everything_news_url,\
                                  headers=headers, params=everything_sports_payload)

# %%
dict_pol = json.loads(json.dumps(response_politics.json()))
dict_pres = json.loads(json.dumps(response_president.json()))
dict_econ = json.loads(json.dumps(response_economy.json()))
dict_sports = json.loads(json.dumps(response_sports.json()))

# %%
dicts = [dict_pol, dict_pres, dict_econ, dict_sports]

for d in dicts:
    for article in d['articles']:
        article['source_name'] = article['source']['name']

# %%
pol_articles = dict_pol['articles']
pres_articles = dict_pres['articles']
econ_articles = dict_econ['articles']
sports_articles = dict_sports['articles']

# %%
df_pol = pd.read_json(StringIO(json.dumps(pol_articles)))
df_pres = pd.read_json(StringIO(json.dumps(pres_articles)))
df_econ = pd.read_json(StringIO(json.dumps(econ_articles)))
df_sports = pd.read_json(StringIO(json.dumps(sports_articles)))

# %% [markdown]
# ## WebSearch APIs

# %%
import requests

url = "https://contextualwebsearch-websearch-v1.p.rapidapi.com/api/search/TrendingNewsAPI"

querystring = {"pageNumber":"1","pageSize":"10","withThumbnails":"false","location":"us"}

headers = {
    'x-rapidapi-host': "contextualwebsearch-websearch-v1.p.rapidapi.com",
    'x-rapidapi-key': "0388aaee5emsh59b4fba5041dd03p1959efjsn7e9a12071136"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"_type":"news","didUMean":"","totalCount":28,"relatedSearch":[],"value":[{"id":"7125042370436245869","title":"After the scandals Anthopoulos Click lead teams to Series","url":"https://www.washingtonpost.com/sports/mlb/after-the-scandals-anthopoulos-click-lead-teams-to-series/2021/10/27/bb664538-36f0-11ec-9662-399cfa75efee_story.html","description":"Atlanta general manager Alex Anthopoulos and Houston GM James Click both over teams in turmoil and led them to the World Series","body":"ArrowRight\nI walked back to the hotel and I was like cramming for an exam, try to study up on the Braves before my interview, he said.\nHe got the job 16 days later as Atlantas general manager. This week hes back at Minute Maid after helping lead the Braves to their first World Series appearance since 1999.\nAnthopoulos and Houston general manager James Click took over teams in turmoil. Anthopoulos was hired six weeks after GM John Coppolella was forced to resign when Major League Baseballs investigation uncovered rules violations committed by the Braves in the international player market. Click was the No. 3 official in the Tampa Bay Rays baseball department when he was hired by the Astros in February 2020, three weeks after GM Jeff Luhnow was suspended by MLB and then fired by Houston for his role in the teams sign-stealing scandal.\nAdvertisement\nStory continues below advertisement\nAnd just after getting his new job, Clicks orientation was disrupted by the pandemic. He wasnt able to have coffee and dinners with staff for a year.\nI was here for four or five weeks before the world shut down, he said Monday ahead of the World Series opener, which the Braves won 6-2 Tuesday night. And so I had to try to do as much of it over Zoom and other means as possible, which is challenging. Not being able to observe people at their jobs in their natural environment can make it challenging to get to know everybody.\nClick, a 43-year-old Yale history major, and Anthopoulos, a 44-year-old economics major at McMaster University in Hamilton, Ontario, lead organizations with celebrated managers seeking their first dugout titles: Houstons 72-year-old Dusty Baker and Atlantas 66-year-old Brian Snitker, completing his 45th season in the Braves organization.\nAdvertisement\nStory continues below advertisement\nBoth teams won pennants with high but not leading payrolls: Houston was eighth at $188 million as of Aug. 31 and Atlanta 15th at $149 million.\nBorn in Montreal, Anthopoulos started as an intern with the low-spending Expos in 2000, joined Toronto as scouting coordinator and rose to general manager in 2009. He left in January 2016 to become the Dodgers VP of baseball operations under Andrew Friedman and Farhan Zaidi, and got the Braves job less than two seasons later.\nId been in Toronto six years and I thought I was improving as a GM, he said. Going to LA, it was like going to grad school for two years. I wish Id had another year or two because I was learning a ton and I took a ton of what I learned, that I brought it to Atlanta.\nStory continues below advertisement\nAnthopoulos thinks of the example of Billy Beane, who is starting his 25th year as head of the Oakland Athletics baseball operations.\nAdvertisement\nNever the excuses of, Oh, not having resources or money. He always tries to win, Anthopoulos said. They dont do rebuilds. And Farhan will say the same thing: Im not into three-year plans, five-year plans. Im just trying to make good decisions and win when we win.\nAs Atlanta approached the All-Star break below .500 following the loss of all three starting outfielders, Anthopolous recalled a conversation he had with Beane in May or June.\nIf youre close, two months is a long time, 60 games is a lot of games, and you just need to be close because a lot of teams are just going to quit, and its going to give you an opportunity, he said Beane told him. It doesnt sound that complicated, but it makes sense.\nStory continues below advertisement\nAtlanta obt ...

# %%
import requests

url = "https://contextualwebsearch-websearch-v1.p.rapidapi.com/api/search/NewsSearchAPI"

querystring = {"q":"taylor swift","pageNumber":"1","pageSize":"10","autoCorrect":"true","fromPublishedDate":"null","toPublishedDate":"null"}

headers = {
    'x-rapidapi-host': "contextualwebsearch-websearch-v1.p.rapidapi.com",
    'x-rapidapi-key': "0388aaee5emsh59b4fba5041dd03p1959efjsn7e9a12071136"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
