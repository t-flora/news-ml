# %% [markdown]
# ## Free Newscatcher API

# %%
query = 'Aviação OR Transporte OR Anúncio'
lang = 'pt'
category = ''
to_rank = 10000
all_news = False

# %%
import requests, spacy, json, nltk
from io import StringIO
import pandas as pd
import numpy as np
import re
from datetime import datetime
timestamp = datetime.now().strftime("%d-%b-%Y-%H:%M")

# %% [markdown]
# ### Alternative with their Python tutorials

# %%
import time
import csv
import os
import json
import requests
import pandas as pd

# This code is heavily based on the documentation example below:
# https://docs.newscatcherapi.com/knowledge-base/guides-and-tutorials/export-news-into-a-csv-with-python

# URL of our News API
base_url = 'https://api.newscatcherapi.com/v2/search'

# Your API key
X_API_KEY = 'w3pkzEPVMX8WaRnjK3kMpO7I5JmDteGFCFRcaUJgcCE'

# %%
# Put API key to headers to be authorized to perform a call
headers = {'x-api-key': X_API_KEY}

# Define your desired parameters
### Multiple parameters
if all_news:
    params = [
        {
            'q': 'Economia OR Politica OR Crime',
            'lang': 'pt',
            'to_rank': 10000,
            'topic': "news",
            'page_size': 100,
            'page': 1
        },
        {
            'q': 'Evento',
            'lang': 'pt',
            'to_rank': 10000,
            'topic': "entertainment",
            'page_size': 100,
            'page': 1
        },
        {
            'q': 'Esporte',
            'lang': 'pt',
            'to_rank': 10000,
            'topic': "sport",
            'page_size': 100,
            'page': 1
        },
        {
            'q': 'Internacional',
            'lang': 'pt',
            'to_rank': 10000,
            'topic': "world",
            'page_size': 100,
            'page': 1
        }#,
#     {
#         'q': 'Negocios',
#         'lang': 'pt',
#         'to_rank': 10000,
#         'topic': "business",
#         'page_size': 100,
#         'page': 1
#     }
    ]
else:
    params = {
        'q': query,
        'lang': lang,
        'to_rank': to_rank,
        'topic':category,
        'page_size': 100,
        'page': 1
        }

# Make a simple call with both headers and params
# response = requests.get(base_url, headers=headers, params=params)

# # Encode received results
# results = json.loads(response.text.encode())
# if response.status_code == 200:
#     print('Done')
# else:
#     print(results)
#     print('ERROR: API call failed.')

# %%
##########################################
###### Code for multiple parameters ######
##########################################

if all_news:
    # Variable to store all found news articles, mp stands for "multiple queries"
    all_news_articles = []

    # Infinite loop which ends when all articles are extracted
    for separated_param in params:

        print(f'Query in use => {str(separated_param)}')
        
        while True:
            # Wait for 1 second between each call
            time.sleep(1)

            # GET Call from previous section enriched with some logs
            response = requests.get(base_url, headers=headers, params=separated_param)
            results = json.loads(response.text.encode())
            if response.status_code == 200:
                print(f'Done for page number => {separated_param["page"]}')

                # print(json.dumps(response.json(), indent=4, sort_keys=True))
                # Adding your parameters to each result to be able to explore afterwards
                for i in results['articles']:
                    i['used_params'] = str(separated_param)

                # Storing all found articles
                all_news_articles.extend(results['articles'])

                # Ensuring to cover all pages by incrementing "page" value at each iteration
                separated_param['page'] += 1
                if separated_param['page'] > results['total_pages']:
                    print("All articles have been extracted")
                    break
                else:
                    print(f'Proceed extracting page number => {separated_param["page"]}')
            else:
                print(results)
                print(f'ERROR: API call failed for page number => {separated_param["page"]}')
                break

    print(f'Number of extracted articles => {str(len(all_news_articles))}')
else:
    # Variable to store all found news articles
    all_news_articles = []

    # Ensure that we start from page 1
    params['page'] = 1

    # Infinite loop which ends when all articles are extracted
    while True:

        # Wait for 1 second between each call
        time.sleep(1)

        # GET Call from previous section enriched with some logs
        response = requests.get(base_url, headers=headers, params=params)
        results = json.loads(response.text.encode())
        if response.status_code == 200:
            print(f'Done for page number => {params["page"]}')


            # Adding your parameters to each result to be able to explore afterwards
            for i in results['articles']:
                i['used_params'] = str(params)


            # Storing all found articles
            all_news_articles.extend(results['articles'])

            # Ensuring to cover all pages by incrementing "page" value at each iteration
            params['page'] += 1
            if params['page'] > results['total_pages']:
                print("All articles have been extracted")
                break
            else:
                print(f'Proceed extracting page number => {params["page"]}')
        else:
            print(results)
            print(f'ERROR: API call failed for page number => {params["page"]}')
            break

    print(f'Number of extracted articles => {str(len(all_news_articles))}')
# Out:
# Done for page number => 1
# Proceed extracting page number => 2
# Done for page number => 2
# Proceed extracting page number => 3
# Done for page number => 3
# Proceed extracting page number => 4
# Done for page number => 4
# Proceed extracting page number => 5
# Done for page number => 5
# Proceed extracting page number => 6
# Done for page number => 6
# Proceed extracting page number => 7
# Done for page number => 7
# Proceed extracting page number => 8
# Done for page number => 8
# Proceed extracting page number => 9
# Done for page number => 9
# Proceed extracting page number => 10
# Done for page number => 10
# Proceed extracting page number => 11
# Done for page number => 11
# Proceed extracting page number => 12
# Done for page number => 12
# Proceed extracting page number => 13
# Done for page number => 13
# Proceed extracting page number => 14
# Done for page number => 14
# Proceed extracting page number => 15
# Done for page number => 15
# Proceed extracting page number => 16
# Done for page number => 16
# Proceed extracting page number => 17
# Done for page number => 17
# Proceed extracting page number => 18
# Done for page number => 18
# Proceed extracting page number => 19
# Done for page number => 19
# Proceed extracting page number => 20
# Done for page number => 20
# Proceed extracting page number => 21
# Done for page number => 21
# Proceed extracting page number => 22
# Done for page number => 22
# Proceed extracting page number => 23
# Done for page number => 23
# Proceed extracting page number => 24
# Done for page number => 24
# Proceed extracting page number => 25
# Done for page number => 25
# Proceed extracting page number => 26
# Done for page number => 26
# Proceed extracting page number => 27
# Done for page number => 27
# Proceed extracting page number => 28
# Done for page number => 28
# Proceed extracting page number => 29
# Done for page number => 29
# Proceed extracting page number => 30
# Done for page number => 30
# Proceed extracting page number => 31
# Done for page number => 31
# All articles have been extracted
# Number of extracted articles => 3081

# %%
all_news_articles[0]
# Out:
# {'title': 'Dia Internacional da Aviação Civil enfatiza inovações para maior conectividade',
#  'author': '07/12/2021 02h23',
#  'published_date': '2021-12-07 05:23:54',
#  'published_date_precision': 'full',
#  'link': 'https://noticias.uol.com.br/ultimas-noticias/onu-news/2021/12/07/dia-internacional-da-aviacao-civil-enfatiza-inovacoes-para-maior-conectividade.htm',
#  'clean_url': 'uol.com.br',
#  'excerpt': 'Mais de 65,5 milhões de pessoas trabalham no setor com foco em proteção de passageiros, tripulações e transporte de vacinas; tema é "Promovendo a Inovação para o Desenvolvimento da Aviação Global".',
#  'summary': 'Mais de 65,5 milhões de pessoas trabalham no setor com foco em proteção de passageiros, tripulações e transporte de vacinas; tema é "Promovendo a Inovação para o Desenvolvimento da Aviação Global".Clique aqui para ler a notícia completa',
#  'rights': 'uol.com.br',
#  'rank': 657,
#  'topic': 'news',
#  'country': 'BR',
#  'language': 'pt',
#  'authors': [],
#  'media': 'https://conteudo.imguol.com.br/c/_layout/v3/logoUOL2021/default-share/noticias.png',
#  'is_opinion': False,
#  'twitter_account': 'UOLNoticias @UOL',
#  '_score': 26.075209,
#  '_id': 'f4a75f334b8f119a154fb8e2c0061cf0',
#  'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"}

# %%
# Define variables
unique_ids = []
unique_excerpts = []
unique_urls = []
unique_articles = []

# excs = []
# summs = []
# links = []

# Each article has keys: '_id', '_score', 'author', 'authors', 'clean_url', 'country', 'is_opinion', 'language', 'link', 'media', 'published_date', 'published_date_precision', 'rank', 'rights', 'summary', 'title', 'topic', 'twitter_account']
# Iterate on each article and check whether we saw this _id before
for article in all_news_articles:
    eb = article['excerpt'] not in unique_excerpts
    lb = article['link'] not in unique_urls
    if article['_id'] not in unique_ids:
        unique_ids.append(article['_id'])
        if eb and lb:
            unique_excerpts.append(article['excerpt'])
            unique_urls.append(article['link'])
            unique_articles.append(article)

# %%
# Import data into pandas
pandas_table = pd.DataFrame(results['articles'])
pandas_table
# Out:
#                                                 title  \
# 0   Bússola & Cia: Elmeco consolida liderança com ...
# 1   Tudo sobre a Temporada Um de Call of Duty: Van...
# 2   Exploração espacial: de Marte a cometa, a huma...
# 3   Governo trava reforma tributária, diz vice-pre...
# 4   Vítima de estupro no RJ tratada com descaso po...
# ..                                                ...
# 76  As lições da vacina que chegou de 'braço em br...
# 77  As lições da vacina que chegou de 'braço em br...
# 78  Como Guerra do Iraque espalhou violência e cri...
# 79  As lições da vacina que chegou de 'braço em br...
# 80  As lições da vacina que chegou de 'braço em br...
#
#                                                author       published_date  \
# 0                                             Bússola  2021-12-08 15:49:06
# 1       Publicado em 06/12/2021 17:20 Por Alan Uemura  2021-12-07 03:45:00
# 2                                                None  2021-12-09 13:00:00
# 3                                      Edson Sardinha  2021-12-07 10:01:54
# 4                                       Daniele Dutra  2021-12-07 07:00:00
# ..                                                ...                  ...
# 76    Matheus Magenta - Da BBC News Brasil em Londres  2021-12-08 20:19:00
# 77    Matheus Magenta - Da Bbc News Brasil Em Londres  2021-12-08 20:19:51
# 78                                              Https  2021-12-09 16:47:43
# 79  'Matheus Magenta - Da Bbc News Brasil Em Londres'  2021-12-09 14:38:00
# 80                                    BBC News Brasil  2021-12-08 20:25:43
#
#    published_date_precision  \
# 0                      full
# 1          timezone unknown
# 2          timezone unknown
# 3                      full
# 4                      full
# ..                      ...
# 76                     full
# 77                     full
# 78                     full
# 79                     full
# 80                     full
#
#                                                  link     clean_url  \
# 0   https://exame.com/bussola/bussola-cia-elmeco-c...     exame.com
# 1   https://observatoriodegames.uol.com.br/colunas...    uol.com.br
# 2   https://g1.globo.com/ciencia/noticia/2021/12/0...     globo.com
# 3   https://congressoemfoco.uol.com.br/area/congre...    uol.com.br
# 4   https://www.uol.com.br/universa/noticias/redac...    uol.com.br
# ..                                                ...           ...
# 76     https://www.bbc.com/portuguese/brasil-53533707       bbc.com
# 77  https://esportes.yahoo.com/noticias/li%C3%A7%C...     yahoo.com
# 78  https://www.bbc.com/portuguese/internacional-5...       bbc.com
# 79     https://www.bbc.com/portuguese/brasil-53533707       bbc.com
# 80  https://www.terra.com.br/noticias/brasil/as-li...  terra.com.br
#
#                                               excerpt  \
# 0   Confira novidades e informações exclusivas sob...
# 1   Conquiste todas as frentes - Vanguard entra no...
# 2   Apesar de um acidente que abalou o programa es...
# 3   Para o senador, o Executivo trava a reforma e ...
# 4   Uma mulher de 36 anos que foi vítima de estupr...
# ..                                                ...
# 76  É possível traçar paralelos entre a invenção d...
# 77  É possível traçar paralelos entre a invenção d...
# 78  Conflito que mais impacto causou em todo o mun...
# 79  Desde então, a vacinação se tornou uma das mai...
# 80  É possível traçar paralelos entre a invenção d...
#
#                                               summary  \
# 0   Por Bússola\nCom uma área de 480 metros quadra...
# 1   Conquiste todas as frentes e descubra este seg...
# 2   Um sonho, porém, continuou vivo: a conquista d...
# 3   A reforma tributária pode dar seu primeiro pas...
# 4   Uma mulher de 36 anos que foi vítima de estupr...
# ..                                                ...
# 76  A única erradicação de uma doença na história ...
# 77  A única erradicação de uma doença na história ...
# 78  Há 29 minutosCrédito, Getty ImagesLegenda da f...
# 79  Matheus Magenta - Da BBC News Brasil em Londre...
# 80  A única erradicação de uma doença na história ...
#
#                                         rights  rank topic  country language  \
# 0                                    exame.com  8779  news  unknown       pt
# 1                                   uol.com.br   657  news       BR       pt
# 2                                         None   784  news       PT       pt
# 3                                   uol.com.br   657  news       BR       pt
# 4                                   uol.com.br   657  news       BR       pt
# ..                                         ...   ...   ...      ...      ...
# 76                                   em.com.br    84  news       GB       pt
# 77                                   yahoo.com    30  news       US       pt
# 78  Copyright British Broadcasting Corporation    84  news       GB       pt
# 79                   correiobraziliense.com.br    84  news       GB       pt
# 80                                terra.com.br  3152  news       BR       pt
#
#                                               authors  \
# 0                                           [Bússola]
# 1                                                  []
# 2                                                  []
# 3   [Edson Sardinha, Congresso Em Foco, Sylvio Cos...
# 4   [Daniele Dutra, Colaboração Para Universa, No ...
# ..                                                ...
# 76  [Estado De Minas, Matheus Magenta - Da Bbc New...
# 77  [Matheus Magenta - Da Bbc News Brasil Em Londres]
# 78                  [Https, Www.Facebook.Com Bbcnews]
# 79  ['Matheus Magenta - Da Bbc News Brasil Em Lond...
# 80                                  [BBC News Brasil]
#
#                                                 media  is_opinion  \
# 0   https://exame.com/wp-content/uploads/2021/12/G...       False
# 1   https://observatoriodegames.uol.com.br/wp-cont...       False
# 2   https://s2.glbimg.com/PN9eCYebwHI9UZuSK9nfrafV...       False
# 3   https://congressoemfoco.uol.com.br/wp-content/...       False
# 4   https://conteudo.imguol.com.br/c/entreteniment...       False
# ..                                                ...         ...
# 76  https://i.em.com.br/ZjS60Ej_Ynh8S-8wzRKJtI9FrA...        True
# 77  https://s.yimg.com/uu/api/res/1.2/4ZNjq5Y5hJbM...       False
# 78  https://ichef.bbci.co.uk/news/1024/branded_por...       False
# 79  https://midias.correiobraziliense.com.br/_midi...       False
# 80  https://p2.trrsf.com/image/fget/cf/1200/628/mi...       False
#
#      twitter_account    _score                               _id  \
# 0             @exame  3.663830  19384f0f3e4801385bc2bcad0ba32b2f
# 1               None  3.633274  d4d09c80eab43427f723189ca1293d75
# 2               None  3.631285  859ac56a87fc6da97fece0cb4a9e202d
# 3   @congressoemfoco  3.611361  4ec37e08dcda58994026e53fa4adb8ac
# 4                UOL  3.610144  8aa20200f33fee07b3a88823726d5c3c
# ..               ...       ...                               ...
# 76           @em_com  2.195018  6681d64150f2e2b52366cbf99d8e6968
# 77          @YahooBr  2.194939  2548157feebf9f68a63af6e39083ab70
# 78        @bbcbrasil  2.193445  5f5eef810b38f2ccf66328f00ffad27b
# 79          @correio  2.193445  468e632c28c40764059d932da702a7c5
# 80            @terra  2.144209  38b9449dadf2b8239a3f2b67f3ed2c3e
#
#                                           used_params
# 0   {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 1   {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 2   {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 3   {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 4   {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# ..                                                ...
# 76  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 77  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 78  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 79  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 80  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
#
# [81 rows x 20 columns]

# %%
all_news_articles
# Out:
# [{'title': 'Dia Internacional da Aviação Civil enfatiza inovações para maior conectividade',
#   'author': '07/12/2021 02h23',
#   'published_date': '2021-12-07 05:23:54',
#   'published_date_precision': 'full',
#   'link': 'https://noticias.uol.com.br/ultimas-noticias/onu-news/2021/12/07/dia-internacional-da-aviacao-civil-enfatiza-inovacoes-para-maior-conectividade.htm',
#   'clean_url': 'uol.com.br',
#   'excerpt': 'Mais de 65,5 milhões de pessoas trabalham no setor com foco em proteção de passageiros, tripulações e transporte de vacinas; tema é "Promovendo a Inovação para o Desenvolvimento da Aviação Global".',
#   'summary': 'Mais de 65,5 milhões de pessoas trabalham no setor com foco em proteção de passageiros, tripulações e transporte de vacinas; tema é "Promovendo a Inovação para o Desenvolvimento da Aviação Global".Clique aqui para ler a notícia completa',
#   'rights': 'uol.com.br',
#   'rank': 657,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://conteudo.imguol.com.br/c/_layout/v3/logoUOL2021/default-share/noticias.png',
#   'is_opinion': False,
#   'twitter_account': 'UOLNoticias @UOL',
#   '_score': 26.075209,
#   '_id': 'f4a75f334b8f119a154fb8e2c0061cf0',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Teresina perdeu metade dos passageiros de avião na pandemia; menor número em 10 anos , diz IBGE',
#   'author': None,
#   'published_date': '2021-12-10 14:45:00',
#   'published_date_precision': 'timezone unknown',
#   'link': 'https://g1.globo.com/pi/piaui/noticia/2021/12/10/teresina-perdeu-metade-dos-passageiros-de-aviao-na-pandemia-menor-numero-dos-ultimos-10-anos-diz-ibge.ghtml',
#   'clean_url': 'globo.com',
#   'excerpt': 'Além disso, o transporte de cargas em aviões com saída da capital piauiense reduziu 43,2% no período.',
#   'summary': 'A capital do Piauí teve queda de 49,9% na quantidade de passageiros transportados por via aérea em 2020, ano em que a pandemia da Covid-19 começou, quando comparado a 2019. O dado é do estudo Redes e Fluxo do Território: Ligações Aéreas 2019-2020, produzido pelo Instituto Brasileiro de Geografia e Estatística (IBGE). Em 2019, 1,1 milhão de pessoas partiram de Teresina por via aérea, enquanto em 2020 apenas 559 mil fizeram o mesmo. O número obtido durante a pandemia foi menor do que a quantidade de passageiros registrados em 2010, quando viajaram 764 mil pessoas.',
#   'rights': 'globo.com',
#   'rank': 784,
#   'topic': 'news',
#   'country': 'PT',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://s2.glbimg.com/Y9sVN_6LHfkpVAE7VdJSFXPY1q4=/1200x/smart/filters:cover():strip_icc()/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2020/I/T/7k8Ht7TrKoob6lI8Y8BA/captura-de-tela-2020-06-03-as-16.09.15.jpg',
#   'is_opinion': False,
#   'twitter_account': None,
#   '_score': 23.587915,
#   '_id': '83c2660cc901f803e890b1cee7a5ca4f',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Rio é a segunda capital no país que mais perdeu passageiros em voos em 5 anos, diz IBGE',
#   'author': 'Carolina Nalin',
#   'published_date': '2021-12-10 16:51:55',
#   'published_date_precision': 'full',
#   'link': 'https://oglobo.globo.com/economia/negocios/rio-a-segunda-capital-no-pais-que-mais-perdeu-passageiros-em-voos-em-5-anos-diz-ibge-25313980',
#   'clean_url': 'globo.com',
#   'excerpt': 'Levantamento que analisa o setor aéreo mostra que capital fluminense amargou queda de 16% no fluxo de viajantes. Salvador teve maior queda',
#   'summary': 'RIO - O Rio é a segunda capital que mais perdeu passageiros em cinco anos. É o que aponta o levantamento do IBGE intitulado "Redes e fluxos do território", divulgado nesta sexta-feira. A capital fluminense amargou queda 16% no fluxo de passageiros entre 2015 e 2019. A retração só não foi maior que a de Salvador, que registrou recuo de 20% no período. Na disputa:\xa0Dona do Galeão quer levar Santos Dumont em leilão de privatização, dizem fontesA redução do fluxo de passageiros no Rio pode ser agravada com o esvaziamento do Galeão, fortemente afetado pelo fechamento de fronteiras e a consequente diminuição de voos na pandemia.',
#   'rights': 'globo.com',
#   'rank': 784,
#   'topic': 'news',
#   'country': 'PT',
#   'language': 'pt',
#   'authors': ['Carolina Nalin'],
#   'media': 'https://ogimg.infoglobo.com.br/economia/25313550-9fa-9f8/FT1086A/760/96594376_ECORio-09-12-2021-GaleaoMovimentoMovimento-baixissimo-no-aeroporto-internacional-T.jpg',
#   'is_opinion': False,
#   'twitter_account': '@JornalOGlobo',
#   '_score': 22.97717,
#   '_id': 'ddfbbb289e25b75a5c46b7c9855b5c2c',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'UE proíbe 97 companhias de aviação de sobrevoar espaço aéreo europeu',
#   'author': '06/12/2021 11h40Atualizada em 06/12/2021 12h07',
#   'published_date': '2021-12-06 14:40:14',
#   'published_date_precision': 'full',
#   'link': 'https://noticias.uol.com.br/ultimas-noticias/rfi/2021/12/06/ue-proibe-97-companhias-de-aviacao-de-sobrevoar-espaco-aereo-europeu.htm',
#   'clean_url': 'uol.com.br',
#   'excerpt': 'A Comissão Europeia atualizou nesta segunda-feira (6) a lista de companhias aéreas proibidas de operar no espaço aéreo europeu por não cumprirem as normas internacionais de segurança.De acordo com a…',
#   'summary': 'A Comissão Europeia atualizou nesta segunda-feira (6) a lista de companhias aéreas proibidas de operar no espaço aéreo europeu por não cumprirem as normas internacionais de segurança.De acordo com a revisão da lista europeia, 97 operadoras estão agora proibidas de voar no bloco, menos do que as 103 listadas anteriormente. Isto porque várias empresas moldavas foram reinseridas na lista "depois de melhorias na segurança aérea no país", como a Air Moldova, a HiSky e a FlyOne, que atende a França. Todas as companhias aéreas de 15 países fazem a partir de agora parte da lista de proibições da União Europeia (UE).',
#   'rights': '',
#   'rank': 657,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://conteudo.imguol.com.br/c/entretenimento/5f/2021/11/30/aeroporto-de-joanesburgo-no-dia-27-de-novembro-voos-cancelados-a-medida-que-os-paises-fechavam-suas-fronteiras-para-a-africa-do-sul-1638321968494_v2_615x300.jpg',
#   'is_opinion': False,
#   'twitter_account': 'UOLNoticias @UOL',
#   '_score': 22.94881,
#   '_id': '3d9b7ac88daacdc605af30046542306e',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'UE proíbe 97 companhias de aviação de sobrevoar espaço aéreo europeu',
#   'author': 'Texto Por',
#   'published_date': '2021-12-06 14:40:14',
#   'published_date_precision': 'full',
#   'link': 'https://www.rfi.fr/br/europa/20211206-ue-pro%C3%ADbe-97-companhias-de-avia%C3%A7%C3%A3o-de-sobrevoar-espa%C3%A7o-a%C3%A9reo-europeu',
#   'clean_url': 'rfi.fr',
#   'excerpt': 'A Comissão Europeia atualizou nesta segunda-feira (6) a lista de companhias aéreas proibidas de operar no espaço aéreo europeu por não cumprirem as normas internacionais de segurança.',
#   'summary': 'A UE publicou uma lista de proibição de companhias que não devem sobrevoar o espaço aéreo europeu por não atender às normas de segurança.\n\nA Comissão Europeia atualizou nesta segunda-feira (6) a lista de companhias aéreas proibidas de operar no espaço aéreo europeu por não cumprirem as normas internacionais de segurança.\n\nPublicidade Leia mais\n\nDe acordo com a revisão da lista europeia, 97 operadoras estão agora proibidas de voar no bloco, menos do que as 103 listadas anteriormente. Isto porque várias empresas moldavas foram reinseridas na lista "depois de melhorias na segurança aérea no país", como a Air Moldova, a HiSky e a FlyOne, que atende a França.',
#   'rights': 'rfi.fr',
#   'rank': 1696,
#   'topic': 'news',
#   'country': 'FR',
#   'language': 'pt',
#   'authors': ['Texto Por'],
#   'media': 'https://s.rfi.fr/media/display/65a96370-5697-11ec-926c-005056a97e36/w:1280/p:16x9/AP07030207074.jpg',
#   'is_opinion': False,
#   'twitter_account': '@RFI_Br',
#   '_score': 22.026545,
#   '_id': '0d8366fddb447757e5b72902d7833eab',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Eve, da Embraer, e Sidney Seaplanes se unem por táxi aéreo elétrico com pedido de 50 eVTOLs',
#   'author': None,
#   'published_date': '2021-12-06 00:00:00',
#   'published_date_precision': 'date',
#   'link': 'https://valor.globo.com/empresas/noticia/2021/12/06/eve-da-embraer-e-sidney-seaplanes-se-unem-por-txi-areo-eltrico-com-pedido-de-50-evtols.ghtml',
#   'clean_url': 'globo.com',
#   'excerpt': 'A entrega das aeronaves deve ter início em 2026 e o acordo tem como foco apoiar o turismo e a aviação regional na Austrália',
#   'summary': 'A Eve, empresa de mobilidade aérea urbana (UAM, na sigla em inglês) da Embraer, firmou mais uma parceria na Austrália, agora com a Sydney Seaplanes, para implantação de operações de táxi aéreo elétrico na região da Grande Sydney, incluindo a encomenda de 50 aeronaves elétricas de decolagem e pouso vertical (eVTOL). A entrega das aeronaves pela Eve deve ter início em 2026 e o acordo tem como foco apoiar o turismo e a aviação regional na Austrália. Em nota, a Embraer informa que a parceria acelera o turismo mais sustentável na região da Grande Sydney usando aviação 100% elétrica com emissão zero.',
#   'rights': None,
#   'rank': 784,
#   'topic': 'news',
#   'country': 'PT',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://s2.glbimg.com/PksPpxS900AtkIwI8_WtNkLOV_k=/1200x/smart/filters:cover():strip_icc()/i.s3.glbimg.com/v1/AUTH_63b422c2caee4269b8b34177e8876b93/internal_photos/bs/2021/U/L/OFTN3WSP6P4UwBV0tztw/captura-de-tela-2021-12-06-as-11.25.04.png',
#   'is_opinion': False,
#   'twitter_account': None,
#   '_score': 20.84601,
#   '_id': '3f10d3e06100861202bd804bc8e32c36',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': "Empresa australiana encomenda 50 'carros voadores' da Embraer para serviço de táxi aéreo",
#   'author': 'Estadão Conteúdo',
#   'published_date': '2021-12-06 22:44:20',
#   'published_date_precision': 'full',
#   'link': 'https://www.terra.com.br/economia/empresa-australiana-encomenda-50-carros-voadores-da-embraer-para-servico-de-taxi-aereo,1973e6cbfb595a3865422a7ed9ab65af6gwca2tg.html',
#   'clean_url': 'terra.com.br',
#   'excerpt': 'A parceria entre as empresas visa acelerar o turismo sustentável em Sydney, na Austrália, mas entregas serão só em 2026',
#   'summary': 'O sonho do carro voador está mais perto de virar realidade. A Eve Urban Air Mobility Solutions (Eve), da Embraer, e a Sydney Seaplanes, empresa da Austrália, anunciaram nesta segunda-feira uma parceria para iniciar a implantação de operações de táxi aéreo elétrico na cidade de Sydney. A Sydney Seaplanes encomendou 50 aeronaves elétricas de decolagem e pouso vertical (eVTOLs) da Eve, com entregas previstas a partir de 2026.\nSegundo a Embraer, a nova parceria acelera o turismo sustentável na região da grande Sydney ao utilizar veículos de aviação 100% elétricos e com zero emissão de poluentes.',
#   'rights': 'terra.com.br',
#   'rank': 3152,
#   'topic': 'economics',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['Estadão Conteúdo'],
#   'media': 'https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg',
#   'is_opinion': False,
#   'twitter_account': '@terra',
#   '_score': 20.384226,
#   '_id': 'd56d9346f8a8d63e365c45bc768f04f6',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': "Casal remonta avião e estuda transformá-lo em atrativo turístico: 'Um entretenimento para Morretes, gerando empregos, atraindo turistas'",
#   'author': None,
#   'published_date': '2021-12-03 13:15:33',
#   'published_date_precision': 'full',
#   'link': 'https://g1.globo.com/pr/parana/noticia/2021/12/03/casal-remonta-aviao-e-estuda-transforma-lo-em-atrativo-turistico-um-entretenimento-para-morretes-gerando-empregos-atraindo-turistas.ghtml',
#   'clean_url': 'globo.com',
#   'excerpt': "Aeronave 'estacionou' em propriedade privada do município na última quarta-feira (1º). Apesar de terem interesse em criar novo atrativo, proprietários ainda não definiram data para execução.",
#   'summary': 'Como precisou ser parcialmente desmontado para chegar ao novo lar, o Airbus A318 está agora recebendo de volta estruturas e peças como asas e trem de pouso. O processo deve demorar entre 10 e 15 dias, segundo os novos proprietários Fábio Freitas e Cláudia Zaias. Apesar do estudo e do desejo, ainda deve demorar um tempo para a função turística do avião se concretizar. Segundo o casal, por enquanto, a intenção está "só no coração". \'Pode ser que no futuro vire um entretenimento para Morretes, gerando empregos, atraindo turistas, enriquecendo a cidade.',
#   'rights': '© Copyright Globo Comunicação e Participações S.A.',
#   'rank': 784,
#   'topic': 'news',
#   'country': 'PT',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://s2.glbimg.com/upeqezuT9JjCervMgJ7llWr1svU=/1200x/smart/filters:cover():strip_icc()/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2021/S/h/9sv0AOQ9yveUDqUL5pWg/aviao-morretes-estacionado-ponte.jpeg',
#   'is_opinion': False,
#   'twitter_account': None,
#   '_score': 20.23954,
#   '_id': 'cd4212483966d5739fd3aa60bf7ef1dd',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Polícia Federal recebe oficialmente avião Embraer E175 em Brasília',
#   'author': 'R7.com',
#   'published_date': '2021-12-08 19:25:00',
#   'published_date_precision': 'full',
#   'link': 'https://noticias.r7.com/prisma/luiz-fara-monteiro/policia-federal-recebe-oficialmente-aviao-embraer-e175-em-brasilia-08122021',
#   'clean_url': 'r7.com',
#   'excerpt': 'Dois jatos deste modelo serão incorporados à frota da corporação. Aeronaves voavam pela Flybe no Reino Unido',
#   'summary': 'O Blog presencia a cerimônia no hangar da Coordenação de Aviação (CAV) da Polícia Federal, em Brasília (DF), onde será oficialmente entregue o primeiro jato Embraer E175 da PF. A aeronave\xa0será utilizada no apoio logístico da entidade, incluindo o transporte de pessoal e detentos. O ministro da Justiça e Segurança Pública, Anderson Torres é aguardado, além do advogado-geral da União, Bruno Bianco Leal. O minstro da Casa Civil da presid~encia da República, Ciro Nogueira também está presente. As autoridades são recepcionadas pelo diretor-geral da PF, Paulo Gustavo Maiurino.',
#   'rights': 'r7.com',
#   'rank': 6198,
#   'topic': 'news',
#   'country': 'unknown',
#   'language': 'pt',
#   'authors': ['R7.com'],
#   'media': 'https://img.r7.com/images/convidados-fotografam-o-embraer-e175-da-policia-federal-08122021161947053?dimensions=771x420&',
#   'is_opinion': False,
#   'twitter_account': '@portalr7',
#   '_score': 20.14305,
#   '_id': '8085dcf5235a5536b60840731f78299c',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Eve, da Embraer, recebe encomenda de 50 táxis aéreos voadores para Austrália',
#   'author': 'O Globo',
#   'published_date': '2021-12-06 15:22:50',
#   'published_date_precision': 'full',
#   'link': 'https://oglobo.globo.com/economia/eve-da-embraer-recebe-encomenda-de-50-taxis-aereos-voadores-para-australia-25307579',
#   'clean_url': 'globo.com',
#   'excerpt': 'No domingo, a empresa de mobilidade aérea urbana havia anunciado acordo com a Nautilus Aviation, maior operadora de helicópteros do norte da Austrália',
#   'summary': "FLÓRIDA E MELBOURNE — A Eve, empresa de mobilidade aérea urbana (UAM, na sigla em inglês) da Embraer, recebeu novas encomendas de eVTOLs, como são conhecidas as aeronaves elétricas de decolagem e pouso vertical, desta vez de duas empresas australianas. Em outubro, a empresa brasileira havia fechado uma encomenda de 100 'carros voadores'.Conheça:\xa0 Os planos de Gol, Azul e Embraer para tirar do papel os ‘carros voadores'Nesta segunda-feira, a Eve fechou uma parceria com a Sydney Seaplanes, líder na transição para a aviação sustentável na Austrália, que encomendou 50 unidades de eVTOL da Eve, com entregas previstas para começar também a partir de 2026.",
#   'rights': 'globo.com',
#   'rank': 784,
#   'topic': 'news',
#   'country': 'PT',
#   'language': 'pt',
#   'authors': ['O Globo'],
#   'media': 'https://ogimg.infoglobo.com.br/in/25150331-c0a-f8f/FT1086A/760/aeronave-eletrica.jpg',
#   'is_opinion': False,
#   'twitter_account': '@JornalOGlobo',
#   '_score': 20.115242,
#   '_id': 'b49c0a37916e8f49f228197a31c3e3d5',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Pandemia derrubou pela metade transporte de passageiros em 2020',
#   'author': 'R7.com',
#   'published_date': '2021-12-10 13:41:00',
#   'published_date_precision': 'full',
#   'link': 'https://noticias.r7.com/economia/pandemia-derrubou-pela-metade-transporte-de-passageiros-em-2020-10122021',
#   'clean_url': 'r7.com',
#   'excerpt': 'Número de viajantes recuou para 44 milhões, enquanto cargas transportadas caíram para 282 mil toneladas, aponta IBGE',
#   'summary': 'Economia | Do R7 10/12/2021 - 10h41 (Atualizado em 10/12/2021 - 10h50) \n Um dos setores mais afetados pela pandemia do novo coronavírus, a aviação civil vivenciou uma queda de 53% no número de passageiros transportados ao longo do ano passado, aponta estudo divulgado nesta sexta-feira (10) pelo IBGE (Instituto Brasileiro de Geografia e Estatística). Conforme os dados, o número de viajantes passou de 93,8 milhões para 44 milhões, enquanto as cargas tiveram redução de 400 mil toneladas para 282 mil toneladas (-29,6%) no mesmo período.',
#   'rights': 'r7.com',
#   'rank': 6198,
#   'topic': 'economics',
#   'country': 'unknown',
#   'language': 'pt',
#   'authors': ['R7.com'],
#   'media': 'https://img.r7.com/images/passageiro-no-aeroporto-de-barajas-em-madrid-onde-voos-do-brasil-foram-suspensos-05032021164707857?dimensions=442x241&',
#   'is_opinion': False,
#   'twitter_account': '@portalr7',
#   '_score': 19.789557,
#   '_id': 'df480ab09ad2f8bf3d1478ff370698d5',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Como Nossa Senhora de Loreto se tornou padroeira dos pilotos de avião',
#   'author': 'Philip Kosloski',
#   'published_date': '2021-12-10 11:32:32',
#   'published_date_precision': 'full',
#   'link': 'https://pt.aleteia.org/2021/12/10/como-nossa-senhora-de-loreto-se-tornou-padroeira-dos-pilotos-de-aviao/',
#   'clean_url': 'aleteia.org',
#   'excerpt': 'A proclamação de Nossa Senhora de Loreto como padroeira dos aviadores veio depois de uma bênção especial aos aviões.',
#   'summary': "Created with Sketch.By Skycolors | ShutterstockPhilip Kosloski - publicado em 10/12/21A primeira metade do século XX viu um rápido progresso no domínio dos transportes.\xa0Não apenas o automóvel foi inventado, mas também houve os primeiros voos de Santos Dumont e dos irmãos Wright.Com o desenvolvimento da tecnologia, os pioneiros da aviação enviaram um pedido ao Papa Bento XV.\xa0Em um discurso no ano de 2010, o Papa Bento XVI\xa0explicou\xa0que o seu antecessor proclamou Nossa Senhora de Loreto como padroeira dos aviadores:'Prezados amigos, no dia 24 de março de 1920 o meu predecessor\xa0Bento XV, de veneranda memória, proclamou a Bem-Aventurada Virgem Maria de Loreto, Padroeira de todos os aviadores, com referência ao arcanjo Gabriel, que desceu do céu para transmitir a Maria ‘o feliz anúncio' da Maternidade divina (cf.",
#   'rights': 'aleteia.org',
#   'rank': 6746,
#   'topic': 'news',
#   'country': 'unknown',
#   'language': 'pt',
#   'authors': ['Philip Kosloski'],
#   'media': 'https://wp.pt.aleteia.org/wp-content/uploads/sites/5/2018/06/web3-flight-deck-of-modern-plane-the-pilots-cockpit-crew-of-aircraft-prepares-for-landing-at-the-airport-shutterstock_386239714.jpg?w=620&h=310&crop=1',
#   'is_opinion': False,
#   'twitter_account': '@aleteiapt',
#   '_score': 19.202003,
#   '_id': '51922170bfcfd4947a5d31aac4c38c4b',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Homem embriagado é detido após deixar filho de 11 anos dirigir carro em SP',
#   'author': 'Yahoo Notícias',
#   'published_date': '2021-12-06 14:04:54',
#   'published_date_precision': 'full',
#   'link': 'https://br.noticias.yahoo.com/homem-embriagado-e-detido-apos-deixar-filho-de-11-anos-dirigir-carro-em-sp-140454975.html',
#   'clean_url': 'yahoo.com',
#   'excerpt': 'Rapaz pode pegar de seis meses a um ano de prisão',
#   'summary': 'Realizando um sonho de infância ao jogar pelo Botafogo, o lateral-direito Rafael não esqueceu seu...RIO - A Justiça Eleitoral declarou o governador afastado do Tocantins, Mauro Carlesse (PSL),...Ad•WayfairPor que este anúncio?Obrigado por seu feedback. Removeremos isso e faremos as alterações necessárias.Find furniture you love, at prices that fit your budget with flexible financing.Caio Blat viajou do Rio até Campinas, no interior de São Paulo, para a formatura de Antonio Blat,...Simulação de computador e experimento de laboratório indicam bom potencial; análise de registros da doença neurológica indicam que prevalência é menor entre quem já consome o medicamentopara disfunção erétilIinformação vem da\xa0análise preliminar de um grupo de 22 pessoas da província de\xa0Gauteng, epicentro da\xa0Ômicron\xa0na África do Sul e do Reino UnidoAd•LeafFilter PartnerPor que este anúncio?Obrigado por seu feedback.',
#   'rights': 'Copyright (c) 2021 Yahoo! Inc. All rights reserved.',
#   'rank': 30,
#   'topic': 'news',
#   'country': 'US',
#   'language': 'pt',
#   'authors': ['Yahoo Notícias'],
#   'media': 'https://s.yimg.com/os/creatr-uploaded-images/2021-11/c0dda3e0-43e7-11ec-bfff-66ee9d1974e3',
#   'is_opinion': False,
#   'twitter_account': '@YahooBr',
#   '_score': 19.048117,
#   '_id': '4e6a8b4cfdd839dd4bd36ee7e3fad180',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'América do Sul e Caribe lideram retomada da conectividade aérea internacional',
#   'author': None,
#   'published_date': '2021-12-09 00:00:00',
#   'published_date_precision': 'date',
#   'link': 'https://valor.globo.com/empresas/noticia/2021/12/09/america-do-sul-e-caribe-lideram-retomada-da-conectividade-aerea-internacional.ghtml',
#   'clean_url': 'globo.com',
#   'excerpt': 'A América do Sul e Caribe aparecem na liderança entre todas as regiões na retomada da conectividade aérea internacional, segundo dados da Associação Internacional de Transporte Aéreo (Iata). O motivo,…',
#   'summary': "A América do Sul e Caribe aparecem na liderança entre todas as regiões na retomada da conectividade aérea internacional, segundo dados da Associação Internacional de Transporte Aéreo (Iata). O motivo, entretanto, não é tão bom: a falta de infraestrutura em outros modais de transporte (como ferroviário) não deixa outra alternativa ao viajante, que depende mais dos aviões, explicou o vice-presidente regional das Américas, Peter Cerdá, em conferência na tarde desta quinta-feira com jornalistas. 'O transporte de passageiro é uma necessidade (via modal aéreo na região).",
#   'rights': None,
#   'rank': 784,
#   'topic': 'news',
#   'country': 'PT',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://s2.glbimg.com/nkC4j90eI_3pALQ-9ARGIW83gN4=/1200x/smart/filters:cover():strip_icc()/i.s3.glbimg.com/v1/AUTH_63b422c2caee4269b8b34177e8876b93/internal_photos/bs/2021/F/p/VnuFMKQPACIgUFFZxxkQ/plane-1362587-1920.jpg',
#   'is_opinion': False,
#   'twitter_account': None,
#   '_score': 19.033875,
#   '_id': '79599b4d64a6ac97a34330770073e71f',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Cade aprova compra pela Chevron de controle de negócio de óleos básicos da Neste',
#   'author': 'Estadão Conteúdo',
#   'published_date': '2021-12-06 15:41:05',
#   'published_date_precision': 'full',
#   'link': 'https://www.terra.com.br/economia/cade-aprova-compra-pela-chevron-de-controle-de-negocio-de-oleos-basicos-da-neste,3ae989945bae68da56c6f4adcf7cd692ne0v88ym.html',
#   'clean_url': 'terra.com.br',
#   'excerpt': 'A Superintendência Geral (SG) do Conselho Administrativo de Defesa Econômica (Cade) aprovou sem restrições o ato de concentração envolvendo a Ch',
#   'summary': 'A Superintendência Geral (SG) do Conselho Administrativo de Defesa Econômica (Cade) aprovou sem restrições o ato de concentração envolvendo a Chevron Global Energy Inc. e Neste Oyj. O despacho pela aprovação está publicado no Diário Oficial da União desta segunda-feira.\nSegundo o parecer da SG, a operação consiste na aquisição, pela Chevron, do controle exclusivo do negócio de óleos básicos da Neste. O Grupo Chevron não adquirirá, no entanto, qualquer planta de produção. O valor da operação não foi divulgado, por ser a operação de acesso restrito às requerentes.',
#   'rights': 'terra.com.br',
#   'rank': 3152,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['Estadão Conteúdo'],
#   'media': 'https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg',
#   'is_opinion': False,
#   'twitter_account': '@terra',
#   '_score': 18.500046,
#   '_id': '26cd1ae474dfd094fc3b33c59f866c18',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'EUA alertam que faixa 5G pode gerar interferência e desviar rotas de aeronaves',
#   'author': None,
#   'published_date': '2021-12-07 20:33:00',
#   'published_date_precision': 'full',
#   'link': 'https://www1.folha.uol.com.br/tv/tec/2021/12/eua-alertam-que-faixa-5g-pode-gerar-interferencia-e-desviar-rotas-de-aeronaves.shtml',
#   'clean_url': 'uol.com.br',
#   'excerpt': 'Indústria da aviação levanta preocupação com impacto da rede em componentes eletrônicos sensíveis',
#   'summary': 'A FAA (Administração Federal de Aviação dos EUA, em inglês) alertou nesta terça-feira (7) que a interferência do uso de espectro do 5G a ser lançado no país representa um risco para a segurança aérea e pode resultar em desvios de voos. A indústria da aviação e a FAA levantaram preocupações sobre a potencial interferência do 5G em componentes eletrônicos sensíveis de aeronaves, como altímetros de rádio. A AT&T e a Verizon concordaram em adiar o lançamento comercial do serviço de Banda C do 5G até 5 de janeiro, depois que a FAA levantou as questões.',
#   'rights': '1996 - 2021 UOL - O melhor conteúdo. Todos os direitos reservados. Segurança e privacidade',
#   'rank': 657,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://f.i.uol.com.br/fotografia/2021/11/18/163726094661969e925c795_1637260946_3x2_rt.jpg',
#   'is_opinion': False,
#   'twitter_account': 'folha',
#   '_score': 18.169682,
#   '_id': 'aaf6ccceab4273b71102b7156ecebf00',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Passagens aéreas nas alturas: Custo alto, recessão e variante Ômicron limitam retomada da aviação e queda nas tarifas',
#   'author': 'Ivan Martínez-Vargas',
#   'published_date': '2021-12-05 07:30:08',
#   'published_date_precision': 'full',
#   'link': 'https://oglobo.globo.com/economia/negocios/passagens-aereas-nas-alturas-custo-alto-recessao-variante-omicron-limitam-retomada-da-aviacao-queda-nas-tarifas-25306343',
#   'clean_url': 'globo.com',
#   'excerpt': 'Aumento das despesas das empresas com combustível e aviões, influenciados pelo dólar, é o maior entrave para aumento da oferta de voos em 2022',
#   'summary': 'SÃO PAULO - As três maiores companhias aéreas do país — Azul, Latam e Gol — caminham para restabelecer o patamar pré-pandemia nos voos domésticos até o início de 2022.A velocidade dessa retomada, porém, está ameaçada pela alta dos custos no setor, impulsionada principalmente pela desvalorização do real frente ao dólar, que influencia os gastos das empresas com combustível, arrendamento (leasing) e manutenção de aviões.Veja:\xa0 Como está a saúde financeira das três maiores empresas aéreas do paísAlém disso, a estagnação atual, uma eventual recessão no Brasil em 2022 (já prevista por bancos como Itaú e Credit Suisse) e as ainda moderadas preocupações com a variante Ômicron do coronavírus têm o potencial de reduzir o ritmo da recuperação do fluxo de passageiros, que é mais vigorosa na aviação doméstica que na internacional.',
#   'rights': 'globo.com',
#   'rank': 784,
#   'topic': 'economics',
#   'country': 'PT',
#   'language': 'pt',
#   'authors': ['Ivan Martínez-Vargas',
#    'Aguirre Talento E Thiago Bronzatto',
#    'Alfredo Mergulhão',
#    'O Globo',
#    'Rodrigo Castro',
#    'Gabriel Shinohara'],
#   'media': 'https://ogimg.infoglobo.com.br/in/23277643-39f-01f/FT1086A/760/59353109_Brasilia-BsB-DF-20-04-2016MALHA-AEREA-ENCOLHE-_-Entra-em-vigor-em-maio-a-nova-malha-aere.jpg',
#   'is_opinion': False,
#   'twitter_account': '@JornalOGlobo',
#   '_score': 18.161758,
#   '_id': '1e50c21470adfd5e6452cb61c42e2ccb',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'EUA alertam que espectro 5G pode gerar interferência e desviar rotas de aeronaves',
#   'author': 'Reuters',
#   'published_date': '2021-12-07 17:31:41',
#   'published_date_precision': 'full',
#   'link': 'https://www.terra.com.br/noticias/tecnologia/eua-alertam-que-espectro-5g-pode-gerar-interferencia-e-desviar-rotas-de-aeronaves,a2819271d9c798e690ac4e11f92f48a8qu9c24gk.html',
#   'clean_url': 'terra.com.br',
#   'excerpt': 'A Administração Federal de Aviação dos EUA (FAA, na sigla em inglês) alertou nesta terça-feira que a interferência do uso de espectro do 5G a ser lançado no',
#   'summary': 'A Administração Federal de Aviação dos EUA (FAA, na sigla em inglês) alertou nesta terça-feira que a interferência do uso de espectro do 5G a ser lançado no país representa um risco para a segurança aérea e pode resultar em desvios de voos. \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAeroporto Internacional de Los Angeles (LAX), em Los Angeles (EUA) 23/05/2020 REUTERS/Patrick T. Fallon\nFoto: Reuters\n\n\n\n A indústria da aviação e a FAA levantaram preocupações sobre a potencial interferência do 5G em componentes eletrônicos sensíveis de aeronaves, como altímetros de rádio.',
#   'rights': 'terra.com.br',
#   'rank': 3152,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['Reuters'],
#   'media': 'https://p2.trrsf.com/image/fget/cf/1200/628/middle/images.terra.com/2021/12/07/93251.jpg',
#   'is_opinion': False,
#   'twitter_account': '@terra',
#   '_score': 18.14536,
#   '_id': '8835ab3026476210c337aa38a58b54a5',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Anac discute fortalecimento da segurança na aviação brasileira',
#   'author': 'R7.com',
#   'published_date': '2021-12-08 11:07:22',
#   'published_date_precision': 'full',
#   'link': 'https://noticias.r7.com/prisma/luiz-fara-monteiro/anac-discute-fortalecimento-da-seguranca-na-aviacao-brasileira-08122021',
#   'clean_url': 'r7.com',
#   'excerpt': "Evento realizado pela agência tem foco no gerenciamento de segurança no setor aéreo. Edição do 'Safety Management Summit' acontece em São Paulo",
#   'summary': 'Luiz Fara Monteiro | Do R7 08/12/2021 - 08h07 \n Segurança aérea como prioridade na aviação civil brasileira. Esse foi o tom dos discursos que marcaram a cerimônia de abertura do Safety Management Summit – SMS Brazil 2021, evento realizado pela Agência Nacional de Aviação Civil (ANAC), em São Paulo, entre os dias 7 e 8 de dezembro. O diretor-presidente da ANAC, Juliano Noman, reforçou que a cultura de segurança como prioridade no setor aéreo/na aviação civil brasileira vem se consolidando ao longo de décadas.',
#   'rights': 'r7.com',
#   'rank': 6198,
#   'topic': 'news',
#   'country': 'unknown',
#   'language': 'pt',
#   'authors': ['R7.com'],
#   'media': 'https://img.r7.com/images/anac-seguranca-na-aviacao-brasileira-08122021075559327?dimensions=100&',
#   'is_opinion': False,
#   'twitter_account': '@portalr7',
#   '_score': 18.08614,
#   '_id': '69ef72407d5c87e87171c9bc3a6bd7f3',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'EUA alertam que 5G pode gerar interferência e desviar rota de voos; entenda',
#   'author': 'David Shepardson',
#   'published_date': '2021-12-07 16:57:48',
#   'published_date_precision': 'full',
#   'link': 'https://www.uol.com.br/tilt/noticias/reuters/2021/12/07/eua-alertam-que-espectro-5g-pode-gerar-interferencia-e-desviar-rotas-de-aeronaves.htm',
#   'clean_url': 'uol.com.br',
#   'excerpt': 'A Administração Federal de Aviação dos EUA (FAA, na sigla em inglês) alertou nesta terça-feira que a interferência do uso de espectro do 5G',
#   'summary': 'Imagem: Getty Images A Administração Federal de Aviação dos EUA (FAA, na sigla em inglês) alertou nesta terça-feira que a interferência do uso de espectro do 5G a ser lançado no país representa um risco para a segurança aérea e pode resultar em desvios de voos.A indústria da aviação e a FAA levantaram preocupações sobre a potencial interferência do 5G em componentes eletrônicos sensíveis de aeronaves, como altímetros de rádio. A AT&T e a Verizon concordaram em adiar o lançamento comercial do serviço de Banda C do 5G até 5 de janeiro, depois que a FAA levantou as questões.',
#   'rights': 'uol.com.br',
#   'rank': 657,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['David Shepardson', 'Em Washington'],
#   'media': 'https://conteudo.imguol.com.br/c/entretenimento/bf/2021/11/18/aviao-1637254728116_v2_615x300.jpg',
#   'is_opinion': False,
#   'twitter_account': 'tiltuol @UOL',
#   '_score': 18.080738,
#   '_id': 'b0352f7aaf30585c17546408a768f71a',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'O primeiro voo de passageiros movido a combustível 100% sustentável já decolou',
#   'author': 'Fast Company Brasil',
#   'published_date': '2021-12-07 10:00:22',
#   'published_date_precision': 'full',
#   'link': 'https://esportes.yahoo.com/noticias/o-primeiro-voo-passageiros-movido-100022826.html?src=rss',
#   'clean_url': 'yahoo.com',
#   'excerpt': 'POR ADELE PETERS No dia 1 de dezembro, um voo da United de Chicago para Washington, D.C. com passageiros a bordo teve, pela primeira vez, seu motor abastecido com combustível de aviação 100% sustentável, no lugar de combustíveis fósseis. Não é a primeira vez que a companhia aérea usa [...] O post O primeiro voo de passageiros movido a combustível 100% sustentável já decolou apareceu primeiro em Fast Company Brasil | O Futuro dos Negócios.',
#   'summary': 'No dia 1 de dezembro, um voo da United de Chicago para Washington, D.C. com passageiros a bordo teve, pela primeira vez, seu motor abastecido com combustível de aviação 100% sustentável, no lugar de combustíveis fósseis. Não é a primeira vez que a companhia aérea usa combustíveis mais ecológicos – todos os dias, alguns voos do Aeroporto Internacional de Los Angeles já usam combustível de aviação sustentável misturado com o combustível de aviação padrão. Mas os regulamentos atuais limitam a mistura potencial a não mais do que 50%.',
#   'rights': 'yahoo.com',
#   'rank': 30,
#   'topic': 'news',
#   'country': 'US',
#   'language': 'pt',
#   'authors': ['Fast Company Brasil'],
#   'media': 'https://s.yimg.com/ny/api/res/1.2/6oOa6v.txwGoc.IEXlF8dw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/uu/api/res/1.2/pMqTsfdqbm7cZIW9o.TFLA--~B/aD05MDA7dz0xNjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/pt/fast_company_brasil_971/5f4ce88efe9eb87c7369007f47386123',
#   'is_opinion': False,
#   'twitter_account': '@YahooBr',
#   '_score': 18.0126,
#   '_id': 'd84af43d8894dbc3eda4007313c0da01',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'GOL divulga os resultados prévios de tráfego de Novembro de 2021',
#   'author': 'Gol Linhas Aéreas Inteligentes S.A.',
#   'published_date': '2021-12-06 12:04:00',
#   'published_date_precision': 'full',
#   'link': 'https://www.prnewswire.com/news-releases/gol-divulga-os-resultados-previos-de-trafego-de-novembro-de-2021-870382648.html',
#   'clean_url': 'prnewswire.com',
#   'excerpt': '/PRNewswire/ -- A GOL Linhas Aéreas Inteligentes S.A. (B3: GOLL4 e NYSE: GOL), a maior companhia aérea doméstica do Brasil, anuncia os números prévios de...',
#   'summary': 'SÃO PAULO, 6 de dezembro de 2021 /PRNewswire/ -- A GOL Linhas Aéreas Inteligentes S.A. (B3: GOLL4 eNYSE: GOL), a maior companhia aérea doméstica do Brasil, anuncia os\xa0números prévios de tráfego do mês de novembro de 2021\xa0em comparação com o mesmo período de 2020.\nDestaques: \n\nA oferta total (ASK) da GOL aumentou em 20,4%. O total de assentos cresceu em 26,5% e o número de decolagens evoluiu 28,7%. A demanda total (RPK) da GOL aumentou em 17,1% e a taxa de ocupação foi 82,1%. \nNo mercado doméstico, a oferta (ASK) da GOL aumentou 17,6% e a demanda (RPK) cresceu em 14,8%.',
#   'rights': 'prnewswire.com',
#   'rank': 216,
#   'topic': 'news',
#   'country': 'unknown',
#   'language': 'pt',
#   'authors': ['Gol Linhas Aéreas Inteligentes S.A.'],
#   'media': 'https://www.prnewswire.com:443/content/dam/prnewswire/icons/2019-Q4-PRN-Icon-32-32.png',
#   'is_opinion': False,
#   'twitter_account': '@PRNewswire',
#   '_score': 17.99084,
#   '_id': 'd47c95afadd4c6dc0f4c415446c9fde2',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Empresa de mídia social de Donald Trump levanta US$ 1 bilhão de investidores',
#   'author': 'Yahoo Finanças',
#   'published_date': '2021-12-05 14:43:50',
#   'published_date_precision': 'full',
#   'link': 'https://br.financas.yahoo.com/noticias/empresa-de-midia-social-de-donald-trump-levanta-us-1-bilhao-de-investidores-144350511.html',
#   'clean_url': 'yahoo.com',
#   'excerpt': "No sábado (4), a Trump Media & Technology afirmou que levantou US$ 1 bilhão de 'um grupo diversificado de investidores institucionais', mas não revelou as identidades.",
#   'summary': 'Saído da cadeia recentemente, o músico posou com fãs durante o eventoPré-candidato à Presidência da República, Cabo Daciolo (Avante) já definiu seu companheiro de chapa para 2022: Felipe Neto.Ad•Chaikin AnalyticsPor que este anúncio?Obrigado por seu feedback. Removeremos isso e faremos as alterações necessárias.A massive and surprising new transition could soon impact the wealth of thousands, while leaving everyone else worse off than before.Moscou afirmou neste domingo (5) que uma "catástrofe" foi evitada depois que um avião russo foi forçado a alterar seu curso para evitar um avião espião da Otan sobre o Mar Negro.',
#   'rights': 'Copyright (c) 2021 Yahoo! Inc. All rights reserved.',
#   'rank': 30,
#   'topic': 'news',
#   'country': 'US',
#   'language': 'pt',
#   'authors': ['Yahoo Finanças'],
#   'media': 'https://s.yimg.com/ny/api/res/1.2/d18sKTycl8c3UCzCVXdEKA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2021-10/a3935b00-2d11-11ec-bf3f-7e19fd5b57af',
#   'is_opinion': False,
#   'twitter_account': '@YahooBr',
#   '_score': 17.722649,
#   '_id': '3f84a8649d5f2ca72a51441d6fc701f4',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': "United faz primeiro voo com combustível ‘100% sustentável'",
#   'author': 'Yahoo Finanças',
#   'published_date': '2021-12-03 15:14:46',
#   'published_date_precision': 'full',
#   'link': 'https://br.financas.yahoo.com/noticias/united-faz-primeiro-voo-com-combustivel-100-sustentavel-151505019.html?src=rss',
#   'clean_url': 'yahoo.com',
#   'excerpt': 'United Airlines fez história na aviação, completando um voo entre Chicago e Washington DC, usando uma fonte de combustível um pouco menos desastrosa para o meio ambiente',
#   'summary': "United Airlines fez história na aviação, completando um voo entre Chicago e Washington DC, usando uma fonte de combustível um pouco menos desastrosa para o meio ambiente. (Spencer Platt/Getty Images)\n\nUnited Airlines usou o SAF para uma viagem entre Chicago e Washington DC\n\nSAF não um combustível totalmente sustentável e custa caro para as viagens\n\nSAFs custam cerca de quatro vezes mais que o combustível convencional\n\nA United Airlines fez história na aviação, completando um voo entre Chicago e Washington DC, usando uma fonte de combustível um pouco menos desastrosa para o meio ambiente - ou, como eles preferem que você o chame, 'combustível de aviação sustentável' ou SAF no idioma da aviação.",
#   'rights': 'yahoo.com',
#   'rank': 30,
#   'topic': 'news',
#   'country': 'US',
#   'language': 'pt',
#   'authors': ['Yahoo Finanças'],
#   'media': 'https://s.yimg.com/ny/api/res/1.2/CjMw6BMv1SfaG4grT.5Uow--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2021-12/ffccef20-5445-11ec-b6ff-c3f5eecee82c',
#   'is_opinion': False,
#   'twitter_account': '@YahooBr',
#   '_score': 17.716885,
#   '_id': '00a659eeddee360f30d949033f1d8f60',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Raízen, Vibra e Air BP vão ao STJ para tentar barrar Gran Petro em Guarulhos',
#   'author': None,
#   'published_date': '2021-12-05 08:10:01',
#   'published_date_precision': 'full',
#   'link': 'https://economia.estadao.com.br/blogs/coluna-do-broad/raizen-vibra-e-air-bp-vao-ao-stj-para-tentar-barrar-gran-petro-em-guarulhos/',
#   'clean_url': 'estadao.com.br',
#   'excerpt': 'Raízen, Vibra Energia (antiga BR Distribuidora) e Air BP entrarão com uma ação no Supremo Tribunal de Justiça (STJ), na',
#   'summary': 'GRU Airport autorizou entrada da Gran Petro atendendo decisão judicial\xa0 \xa0Foto: Felipe Rau/EstadãoRaízen, Vibra Energia (antiga BR Distribuidora) e Air BP entrarão com uma ação no Supremo Tribunal de Justiça (STJ), na segunda-feira, para tentar barrar o acesso da Gran Petro à distribuição de combustíveis no Aeroporto de Guarulhos, em São Paulo. Na quinta-feira, a GRU Airport, administradora do aeroporto internacional, decidiu autorizar o abastecimento pela Gran Petro, assim que a empresa apresentar uma apólice de seguros maior para a cobertura de eventuais acidentes.',
#   'rights': 'estadao.com.br',
#   'rank': 2929,
#   'topic': 'economics',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://economia.estadao.com.br/blogs/coluna-do-broad/wp-content/uploads/sites/431/2018/10/GRU-300x200.jpg',
#   'is_opinion': True,
#   'twitter_account': '@estadao',
#   '_score': 17.4661,
#   '_id': '672f8d93ff148158b4fd6f2872c1b8f9',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Governo brasileiro recebe jato da Embraer para uso em missões da Polícia Federal (FOTOS)',
#   'author': 'Sputnik Brasil',
#   'published_date': '2021-12-09 15:15:00',
#   'published_date_precision': 'timezone unknown',
#   'link': 'https://br.sputniknews.com/20211209/governo-brasileiro-recebe-jato-da-embraer-para-uso-em-missoes-da-policia-federal-fotos-20637371.html',
#   'clean_url': 'sputniknews.com',
#   'excerpt': 'A aeronave modelo E175 da Embraer chegou nesta quarta-feira (8) a Brasília, tendo a cerimônia de chegada sido realizada no hangar da Coordenação de Aviação.',
#   'summary': "https://br.sputniknews.com/20211209/governo-brasileiro-recebe-jato-da-embraer-para-uso-em-missoes-da-policia-federal-fotos-20637371.htmlGoverno brasileiro recebe jato da Embraer para uso em missões da Polícia Federal (FOTOS)Governo brasileiro recebe jato da Embraer para uso em missões da Polícia Federal (FOTOS)A aeronave modelo E175 da Embraer chegou nesta quarta-feira (8) a Brasília, tendo a cerimônia de chegada sido realizada no hangar da Coordenação de Aviação. 09.12.2021, Sputnik Brasil2021-12-09T11:48-03002021-12-09T11:48-03002021-12-09T11:48-0300notícias do brasilbrasíliaembraerpolícia federalforça aérea brasileira (fab)/html/head/meta[@name='og:title']/@content/html/head/meta[@name='og:description']/@contenthttps://cdnnbr1.",
#   'rights': 'sputniknews.com',
#   'rank': 1076,
#   'topic': 'news',
#   'country': 'RU',
#   'language': 'pt',
#   'authors': ['Sputnik Brasil'],
#   'media': 'https://cdnnbr1.img.sputniknews.com/images/sharing/article/por/20637371.jpg?206361911639061282',
#   'is_opinion': False,
#   'twitter_account': None,
#   '_score': 17.459656,
#   '_id': 'b689124b7e6b2fa16cf04195c2c9021b',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'United é primeira a usar combustível 100% sustentável com passageiros',
#   'author': 'R7.com',
#   'published_date': '2021-12-03 01:17:00',
#   'published_date_precision': 'full',
#   'link': 'https://noticias.r7.com/prisma/luiz-fara-monteiro/united-e-primeira-a-usar-combustivel-100-sustentavel-com-passageiros-02122021',
#   'clean_url': 'r7.com',
#   'excerpt': 'Companhia diz que voo foi um marco nos esforços da indústria para combater as mudanças climáticas',
#   'summary': 'Luiz Fara Monteiro | Do R7 02/12/2021 - 22h17 \n A United informa que operou nesta quarta-feira (1) um vôo sem precedentes que servirá como um marco nos esforços da indústria para combater as mudanças climáticas: pela primeira vez na história da aviação, uma transportadora comercial voou uma aeronave de passageiros usando combustível de aviação 100% sustentável (SAF). A United anunciou ainda a segunda rodada de participantes corporativos no programa Eco-Skies Alliance SM da companhia aérea para contribuir coletivamente com a compra da SAF.',
#   'rights': 'r7.com',
#   'rank': 6198,
#   'topic': 'news',
#   'country': 'unknown',
#   'language': 'pt',
#   'authors': ['R7.com'],
#   'media': 'https://img.r7.com/images/r7-30072019142631584?dimensions=340x191&crop_position=c',
#   'is_opinion': False,
#   'twitter_account': '@portalr7',
#   '_score': 17.33985,
#   '_id': '2c6fe3add01514ca8e8d659d3aa414a8',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 1}"},
#  {'title': 'Limitar voos do Santos Dumont é solução mais rápida para dar fôlego ao Galeão',
#   'author': 'Glauce Cavalcanti',
#   'published_date': '2021-12-10 07:30:33',
#   'published_date_precision': 'full',
#   'link': 'https://oglobo.globo.com/economia/negocios/limitar-voos-do-santos-dumont-solucao-mais-rapida-para-dar-folego-ao-galeao-25313539',
#   'clean_url': 'globo.com',
#   'excerpt': 'Aeroporto internacional deve terminar o ano com 4 milhões de passageiros, muito abaixo dos 14 milhões de 2019, e trava corrida contra o tempo para se manter viável',
# ...
#   '_score': 9.475476,
#   '_id': '838663c75d793ee9ba3a05dd50a37f8e',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Uber vê retomada de corridas corporativas no Brasil com vouchers',
#   'author': 'Julia Leite',
#   'published_date': '2021-12-07 14:57:41',
#   'published_date_precision': 'full',
#   'link': 'https://esportes.yahoo.com/noticias/uber-v%C3%AA-retomada-corridas-corporativas-145741519.html?src=rss',
#   'clean_url': 'yahoo.com',
#   'excerpt': "(Bloomberg) -- As corridas corporativas da Uber Technologies voltaram aos níveis pré-pandemia no Brasil, à medida que as empresas passaram a oferecer transporte para funcionários e clientes.Most Read from BloombergThe World's Relentless Demand for Chips Turns Deadly in MalaysiaSand and Soldiers Mix as Troops Move In to Protect Cancun TouristsEven in the Metaverse, Not All Identities Are Created EqualAutomating the War on Noise PollutionThe $300 Billion Plan to Bring Green Power to China's Megaci",
#   'summary': '(Bloomberg) -- As corridas corporativas da Uber Technologies voltaram aos níveis pré-pandemia no Brasil, à medida que as empresas passaram a oferecer transporte para funcionários e clientes.\n\nMost Read from Bloomberg\n\nEm novembro, o número de corridas na unidade Uber para Empresas triplicou em relação a fevereiro de 2020, um mês antes da Covid-19 chegar ao Brasil, disse a companhia em comunicado na terça-feira. No pior momento da pandemia, as viagens corporativas despencaram 80% no país.\n\nA Uber para Empresas tinha como alvo principal o turismo de negócios desde quando começou a operar no Brasil, em 2015.',
#   'rights': 'yahoo.com',
#   'rank': 30,
#   'topic': 'news',
#   'country': 'US',
#   'language': 'pt',
#   'authors': ['Julia Leite'],
#   'media': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'is_opinion': False,
#   'twitter_account': '@YahooBr',
#   '_score': 9.474348,
#   '_id': 'ba441050c930ef432331c24f3d5036e7',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Galo grita após 50 anos: Atlético-MG desbanca dupla Flamengo-Palmeiras com alto investimento, brilho de Hulk e volta de Cuca',
#   'author': 'Lohanna Lima e Victor Martins',
#   'published_date': '2021-12-03 03:54:04',
#   'published_date_precision': 'timezone unknown',
#   'link': 'https://www.uol.com.br/esporte/reportagens-especiais/atletico-mg-e-campeao-brasileiro-apos-50-anos/',
#   'clean_url': 'uol.com.br',
#   'excerpt': 'Atlético-MG desbanca dupla Flamengo-Palmeiras com alto investimento, brilho de Hulk e volta de Cuca',
#   'summary': 'Reverenciado por outros ídolos do Atlético-MG, aplaudido nas arquibancadas, sem limite de idade: Hulk é o craque e um artilheiro para a história. Bem que o Palmeiras havia pensado na contratação antes. O Flamengo também sondou. O Galo levou.A negociação com o jogador no início da temporada pegou muita gente de surpresa. Muitas interrogações surgiram após o anúncio. Jogando por tantos anos na China, como Hulk ia se sair no futebol brasileiro?Torcedores tinham referência do Hulk da seleção de 2014 — o que, depois do 7 a 1, não é boa coisa.',
#   'rights': '1996 - 2021 UOL - O melhor conteúdo. Todos os direitos reservados. Segurança e privacidade',
#   'rank': 657,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['Lohanna Lima E Victor Martins'],
#   'media': 'https://conteudo.imguol.com.br/c/esporte/f4/2021/12/02/jogadores-do-atletico-mg-comemoram-gol-da-virada-contra-o-bahia-pelo-campeonato-brasileiro-1638485222062_v2_615x300.jpg',
#   'is_opinion': False,
#   'twitter_account': 'UOLEsporte @UOL',
#   '_score': 9.47127,
#   '_id': '61a10cc3880275b3c225b3d313ff0369',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Thaila Ayala deixa a maternidade com o filho, Francisco',
#   'author': 'Caras Digital',
#   'published_date': '2021-12-04 18:36:04',
#   'published_date_precision': 'full',
#   'link': 'https://caras.uol.com.br/bebe/thaila-ayala-deixa-a-maternidade-com-o-filho-francisco.phtml',
#   'clean_url': 'uol.com.br',
#   'excerpt': 'Francisco, o primeiro filho de Thaila Ayala e Renato Góes, nasceu na última quarta-feira, 1, no Rio de Janeiro',
#   'summary': 'Francisco, o primeiro filho de Thaila Ayala e Renato Góes, nasceu na última quarta-feira, 1, no Rio de Janeiro CARAS Digital Publicado Hoje, às 15:36 Thaila Ayala deixa a maternidade com o filho, Francisco - Foto: Beatriz Damy/Agnews Na tarde deste sábado, 4,\xa0Thaila Ayala\xa0(35) e\xa0Renato Góes\xa0(34) deixaram a maternidade com\xa0Francisco, o primeiro filho do casal.\xa0O menino nasceu na última quarta-feira, 1, no Rio de Janeiro.\xa0\n O anúncio do nascimento de Francisco foi feito pelo ator, que compartilhou em seu perfil no Instagram\xa0uma foto da marca do pezinho de herdeiro em seu braço.',
#   'rights': 'uol.com.br',
#   'rank': 657,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['Caras Digital'],
#   'media': 'https://caras.uol.com.br/images/large/2021/12/04/thaila-ayala-deixa-a-maternidade-com-o-filho-francisco-1001721.jpg?v=fb',
#   'is_opinion': False,
#   'twitter_account': '@carasbrasil',
#   '_score': 9.467795,
#   '_id': 'ed969e4ed2436eb4030c18660b55d04a',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Ícone da hotelaria, Maksoud Plaza fecha as portas após 42 anos de operação',
#   'author': 'Suzana Petropouleas',
#   'published_date': '2021-12-07 16:08:00',
#   'published_date_precision': 'full',
#   'link': 'https://esportes.yahoo.com/noticias/%C3%ADcone-da-hotelaria-maksoud-plaza-160800071.html?src=rss',
#   'clean_url': 'yahoo.com',
#   'excerpt': 'SÃO PAULO, SP (FOLHAPRESS) - Após 42 anos de funcionamento, o hotel Maksoud Plaza fechou as portas na manhã desta terça-feira (7). Vendido por R$ 132 milhões para o grupo de logística JSL, o icônico estabelecimento encerra suas operações, deixando cerca 170 funcionários sem emprego, e guardando sob sua estrutura diversas histórias que marcam o cenário cultural paulistano. Os trabalhadores que ainda atuavam no local foram avisados sobre o fim das atividades do hotel histórico logo nas primeiras h',
#   'summary': 'SÃO PAULO, SP (FOLHAPRESS) - Após 42 anos de funcionamento, o hotel Maksoud Plaza fechou as portas na manhã desta terça-feira (7). Vendido por R$ 132 milhões para o grupo de logística JSL, o icônico estabelecimento encerra suas operações, deixando cerca 170 funcionários sem emprego, e guardando sob sua estrutura diversas histórias que marcam o cenário cultural paulistano.\n\nOs trabalhadores que ainda atuavam no local foram avisados sobre o fim das atividades do hotel histórico logo nas primeiras horas desta terça (7).',
#   'rights': 'yahoo.com',
#   'rank': 30,
#   'topic': 'news',
#   'country': 'US',
#   'language': 'pt',
#   'authors': ['Suzana Petropouleas'],
#   'media': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#   'is_opinion': False,
#   'twitter_account': '@YahooBr',
#   '_score': 9.4625845,
#   '_id': '93600378151ef358b872be6bbce8acd4',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Patty Jenkins desiste de filmar "Cleópatra" com Gal Gadot',
#   'author': 'Pipoca Moderna',
#   'published_date': '2021-12-07 04:25:14',
#   'published_date_precision': 'full',
#   'link': 'https://www.terra.com.br/diversao/cinema/patty-jenkins-desiste-de-filmar-cleopatra-com-gal-gadot,d508c2a1ef9c351170f3721975737ee2bn139dlw.html',
#   'clean_url': 'terra.com.br',
#   'excerpt': '<div class="relatedcontent" data-cms="%7B%22type%22%3A%20%22IMG%22%2C%20%22position%22%3A%20null%2C%20%22size%22%3A%20%22G%22%2C%20%22id%22%3A%20%22b3722047a3e1',
#   'summary': 'Foto: Divulgação/Warner Bros. / Pipoca Moderna\n\n\n\n\nA cineasta Patty Jenkins, diretora de "Mulher-Maravilha", desistiu de filmar "Cleópatra" com Gal Gadot. Em seu lugar, a Paramount Pictures já escalou Kari Skogland, que comandou a série "Falcão e o Soldado Invernal", repleta de ação.\nEmbora os motivos da troca não tenham rendido um anúncio oficial, Jenkins teria abandonado o comando do épico histórico para dedicar mais tempo à produção de "Mulher-Maravilha 3" na Warner. Apesar disso, ela continua ligada ao projeto como produtora-executiva.',
#   'rights': 'terra.com.br',
#   'rank': 3152,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['Pipoca Moderna'],
#   'media': 'https://p2.trrsf.com/image/fget/cf/1200/628/middle/images.terra.com/2021/12/07/150929400-patty-jenkins-wonder-woman-gal-gadot.jpg',
#   'is_opinion': False,
#   'twitter_account': '@TerraDiversaoBR',
#   '_score': 9.458435,
#   '_id': '542b36b57d5910266c932773c3e5e882',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Só pedalando: como seria se bicicletas substituíssem os carros no trânsito?',
#   'author': 'Rodrigo Lara',
#   'published_date': '2021-12-07 07:00:00',
#   'published_date_precision': 'full',
#   'link': 'https://www.uol.com.br/tilt/noticias/redacao/2021/12/07/mundo-de-pedal-como-seria-se-os-carros-fossem-trocados-por-bicicletas.htm',
#   'clean_url': 'uol.com.br',
#   'excerpt': 'Apesar de já ser realidade em diferentes partes do mundo, ver as bicicletas como meio de transporte —e não como forma de lazer— é algo relativamente recente nas grandes cidades brasileiras. Aqui, há…',
#   'summary': 'Apesar de já ser realidade em diferentes partes do mundo, ver as bicicletas como meio de transporte —e não como forma de lazer— é algo relativamente recente nas grandes cidades brasileiras. Aqui, há uma série de fatores que impactam essa adoção, sendo que a infraestrutura, com a instalação de ciclovias de maneira mais abrangente, é uma das principais.Também entram nessa lista questões culturais, uma (boa) dose de politização e, claro, as particularidades geográficas de cada região. Cidades grandes com muitas ladeiras tendem a tornar o uso das bicicletas menos atraente do que em áreas planas e menores, por exemplo.',
#   'rights': 'uol.com.br',
#   'rank': 657,
#   'topic': 'tech',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['Rodrigo Lara', 'Colaboração Para Tilt', 'Em São Paulo'],
#   'media': 'https://conteudo.imguol.com.br/c/noticias/85/2021/12/06/como-seria-se-as-cidades-nao-tivesse-mais-carros-e-as-pessoas-se-descolassem-so-de-bicicletas-1638804458392_v2_615x300.png',
#   'is_opinion': False,
#   'twitter_account': 'tiltuol @UOL',
#   '_score': 9.45669,
#   '_id': '425a0a78fa874e308c7c17eee5f050fe',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Três doses de vacina da Pfizer/BioNTech podem neutralizar a variante Ômicron, aponta estudo inicial',
#   'author': 'Redetv',
#   'published_date': '2021-12-08 14:30:00',
#   'published_date_precision': 'timezone unknown',
#   'link': 'http://www.redetv.uol.com.br/jornalismo/ciencia/tres-doses-de-vacina-da-pfizer-biontech-podem-neutralizar-a-variante-omicro',
#   'clean_url': 'uol.com.br',
#   'excerpt': '(Foto: Divulgação/Ministério da Saúde) Estudos laboratoriais preliminares demonstraram que três doses da vacina da Pfizer/BioNTech podem neutralizar a nova variante do coronavírus, a Ômicron, no…',
#   'summary': "(Foto: Divulgação/Ministério da Saúde) Estudos laboratoriais preliminares demonstraram que três doses da vacina da Pfizer/BioNTech podem neutralizar a nova variante do coronavírus, a Ômicron, no organismo. Em anúncio feito nesta quarta-feira (8), a Pfizer explica que duas doses da vacina resultaram em anticorpos neutralizantes mais baixos, mas se aplicada uma terceira dose, esses anticorpos aumentam em 25 vezes. 'Amplas campanhas de vacinação e reforço em todo o mundo podem nos ajudar a proteger melhor as pessoas em todos os lugares.",
#   'rights': 'uol.com.br',
#   'rank': 657,
#   'topic': 'news',
#   'country': 'BR',
#   'language': 'pt',
#   'authors': ['Redetv'],
#   'media': 'http://images.redetv.uol.com.br/siteredetv/grupos/jornalismo/redetvinoticias/noticias/images/grandes/897273.jpg',
#   'is_opinion': False,
#   'twitter_account': '@portalredetv',
#   '_score': 9.455645,
#   '_id': '78ca6f439d468ba4cc8ee76a980b6b91',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Bolsonaro diz já conversar com possível vice e prevê anúncio em março',
#   'author': 'Reuters',
#   'published_date': '2021-12-09 13:52:24',
#   'published_date_precision': 'full',
#   'link': 'https://exame.com/brasil/bolsonaro-diz-ja-conversar-com-possivel-vice-e-preve-anuncio-em-marco/',
#   'clean_url': 'exame.com',
#   'excerpt': 'Bolsonaro comentou que considera, para sua escolha, uma pessoa que agregue votos e "respeitabilidade" à chapa, e não afastou a hipótese de o vice ser novamente um general',
#   'summary': 'O presidente Jair Bolsonaro afirmou nesta quarta-feira que já mantém conversas com um possível candidato a vice-presidente para acompanhá-lo em sua chapa na disputa pela reeleição em 2022, e acrescentou que deve anunciar o nome em março.\nBolsonaro comentou que considera, para sua escolha, uma pessoa que agregue votos e "respeitabilidade" à chapa, e não afastou a hipótese de o vice ser novamente um general. "Já estou conversando com um possível vice... não pode ser um casamento de última hora", disse o presidente em entrevista à Gazeta do Povo.',
#   'rights': 'exame.com',
#   'rank': 8779,
#   'topic': 'news',
#   'country': 'unknown',
#   'language': 'pt',
#   'authors': ['Reuters'],
#   'media': 'https://exame.com/wp-content/uploads/2021/11/presidente-Jair-Bolsonaro.jpg?quality=70&strip=info',
#   'is_opinion': False,
#   'twitter_account': '@exame',
#   '_score': 9.451736,
#   '_id': '999115dae725d59cd55f4f0d4b49fd3a',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  {'title': 'Governo rejeita passaporte da vacina e decide exigir quarentena de cinco dias de viajantes não vacinados',
#   'author': None,
#   'published_date': '2021-12-08 00:16:30',
#   'published_date_precision': 'full',
#   'link': 'https://g1.globo.com/jornal-nacional/noticia/2021/12/07/brasil-rejeita-passaporte-da-vacina-e-decide-exigir-quarentena-de-cinco-dias-de-viajantes-nao-vacinados.ghtml',
#   'clean_url': 'globo.com',
#   'excerpt': 'O governo não esclareceu como vai fiscalizar esse isolamento, e o presidente Bolsonaro voltou a desqualificar as vacinas contra Covid aplicadas em todo mundo.',
#   'summary': 'Pouco antes do anúncio oficial dessa decisão, o presidente Bolsonaro tinha desqualificado as vacinas contra Covid usadas em todo o planeta. Vladimir Netto aparece sem máscara na reportagem porque, nesta terça-feira (7), o índice de imunização completa atingiu 65% da população total do Distrito Federal, considerado seguro pelos especialistas para que as equipes trabalhem sem máscara em áreas abertas e de pouca circulação de pessoas. Em uma cerimônia no Palácio do Planalto com representantes do setor da indústria, o presidente Jair Bolsonaro criticou as recomendações da Anvisa para contenção da variante ômicron.',
#   'rights': '© Copyright Globo Comunicação e Participações S.A.',
#   'rank': 784,
#   'topic': 'news',
#   'country': 'PT',
#   'language': 'pt',
#   'authors': [],
#   'media': 'https://s2.glbimg.com/zALN3aMXRB67UwAqIRpchef1LAA=/1200x/smart/filters:cover():strip_icc()/s02.video.glbimg.com/x720/10108489.jpg',
#   'is_opinion': False,
#   'twitter_account': None,
#   '_score': 9.450769,
#   '_id': '4e68d78120f6d16bb8cd4c89bc7711f3',
#   'used_params': "{'q': 'Aviação OR Transporte OR Anúncio', 'lang': 'pt', 'to_rank': 10000, 'topic': '', 'page_size': 100, 'page': 10}"},
#  ...]

# %%
field_names = list(all_news_articles[0].keys())
# Generate CSV file from dict
with open('extracted_news_articles.csv', 'w', encoding="utf-8", newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=field_names, delimiter=";")
    writer.writeheader()
    writer.writerows(all_news_articles)

# %%
# !pip install openpyxl==3.0.9
# Out:
# Requirement already satisfied: openpyxl==3.0.9 in /root/venv/lib/python3.7/site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /root/venv/lib/python3.7/site-packages (from openpyxl==3.0.9) (1.1.0)
# WARNING: You are using pip version 20.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# Generate CSV from Pandas table
# Create Pandas table
pandas_table = pd.DataFrame(all_news_articles)

# Generate CSV
pandas_table.to_csv(f'extracted_news_articles_{timestamp}.csv')

# %%
pandas_table
# Out:
#                                                   title  \
# 0     Dia Internacional da Aviação Civil enfatiza in...
# 1     Teresina perdeu metade dos passageiros de aviã...
# 2     Rio é a segunda capital no país que mais perde...
# 3     UE proíbe 97 companhias de aviação de sobrevoa...
# 4     UE proíbe 97 companhias de aviação de sobrevoa...
# ...                                                 ...
# 3076  As lições da vacina que chegou de 'braço em br...
# 3077  As lições da vacina que chegou de 'braço em br...
# 3078  Como Guerra do Iraque espalhou violência e cri...
# 3079  As lições da vacina que chegou de 'braço em br...
# 3080  As lições da vacina que chegou de 'braço em br...
#
#                                                  author       published_date  \
# 0                                      07/12/2021 02h23  2021-12-07 05:23:54
# 1                                                  None  2021-12-10 14:45:00
# 2                                        Carolina Nalin  2021-12-10 16:51:55
# 3        06/12/2021 11h40Atualizada em 06/12/2021 12h07  2021-12-06 14:40:14
# 4                                             Texto Por  2021-12-06 14:40:14
# ...                                                 ...                  ...
# 3076    Matheus Magenta - Da BBC News Brasil em Londres  2021-12-08 20:19:00
# 3077    Matheus Magenta - Da Bbc News Brasil Em Londres  2021-12-08 20:19:51
# 3078                                              Https  2021-12-09 16:47:43
# 3079  'Matheus Magenta - Da Bbc News Brasil Em Londres'  2021-12-09 14:38:00
# 3080                                    BBC News Brasil  2021-12-08 20:25:43
#
#      published_date_precision  \
# 0                        full
# 1            timezone unknown
# 2                        full
# 3                        full
# 4                        full
# ...                       ...
# 3076                     full
# 3077                     full
# 3078                     full
# 3079                     full
# 3080                     full
#
#                                                    link     clean_url  \
# 0     https://noticias.uol.com.br/ultimas-noticias/o...    uol.com.br
# 1     https://g1.globo.com/pi/piaui/noticia/2021/12/...     globo.com
# 2     https://oglobo.globo.com/economia/negocios/rio...     globo.com
# 3     https://noticias.uol.com.br/ultimas-noticias/r...    uol.com.br
# 4     https://www.rfi.fr/br/europa/20211206-ue-pro%C...        rfi.fr
# ...                                                 ...           ...
# 3076     https://www.bbc.com/portuguese/brasil-53533707       bbc.com
# 3077  https://esportes.yahoo.com/noticias/li%C3%A7%C...     yahoo.com
# 3078  https://www.bbc.com/portuguese/internacional-5...       bbc.com
# 3079     https://www.bbc.com/portuguese/brasil-53533707       bbc.com
# 3080  https://www.terra.com.br/noticias/brasil/as-li...  terra.com.br
#
#                                                 excerpt  \
# 0     Mais de 65,5 milhões de pessoas trabalham no s...
# 1     Além disso, o transporte de cargas em aviões c...
# 2     Levantamento que analisa o setor aéreo mostra ...
# 3     A Comissão Europeia atualizou nesta segunda-fe...
# 4     A Comissão Europeia atualizou nesta segunda-fe...
# ...                                                 ...
# 3076  É possível traçar paralelos entre a invenção d...
# 3077  É possível traçar paralelos entre a invenção d...
# 3078  Conflito que mais impacto causou em todo o mun...
# 3079  Desde então, a vacinação se tornou uma das mai...
# 3080  É possível traçar paralelos entre a invenção d...
#
#                                                 summary  \
# 0     Mais de 65,5 milhões de pessoas trabalham no s...
# 1     A capital do Piauí teve queda de 49,9% na quan...
# 2     RIO - O Rio é a segunda capital que mais perde...
# 3     A Comissão Europeia atualizou nesta segunda-fe...
# 4     A UE publicou uma lista de proibição de compan...
# ...                                                 ...
# 3076  A única erradicação de uma doença na história ...
# 3077  A única erradicação de uma doença na história ...
# 3078  Há 29 minutosCrédito, Getty ImagesLegenda da f...
# 3079  Matheus Magenta - Da BBC News Brasil em Londre...
# 3080  A única erradicação de uma doença na história ...
#
#                                           rights  rank topic country language  \
# 0                                     uol.com.br   657  news      BR       pt
# 1                                      globo.com   784  news      PT       pt
# 2                                      globo.com   784  news      PT       pt
# 3                                                  657  news      BR       pt
# 4                                         rfi.fr  1696  news      FR       pt
# ...                                          ...   ...   ...     ...      ...
# 3076                                   em.com.br    84  news      GB       pt
# 3077                                   yahoo.com    30  news      US       pt
# 3078  Copyright British Broadcasting Corporation    84  news      GB       pt
# 3079                   correiobraziliense.com.br    84  news      GB       pt
# 3080                                terra.com.br  3152  news      BR       pt
#
#                                                 authors  \
# 0                                                    []
# 1                                                    []
# 2                                      [Carolina Nalin]
# 3                                                    []
# 4                                           [Texto Por]
# ...                                                 ...
# 3076  [Estado De Minas, Matheus Magenta - Da Bbc New...
# 3077  [Matheus Magenta - Da Bbc News Brasil Em Londres]
# 3078                  [Https, Www.Facebook.Com Bbcnews]
# 3079  ['Matheus Magenta - Da Bbc News Brasil Em Lond...
# 3080                                  [BBC News Brasil]
#
#                                                   media  is_opinion  \
# 0     https://conteudo.imguol.com.br/c/_layout/v3/lo...       False
# 1     https://s2.glbimg.com/Y9sVN_6LHfkpVAE7VdJSFXPY...       False
# 2     https://ogimg.infoglobo.com.br/economia/253135...       False
# 3     https://conteudo.imguol.com.br/c/entreteniment...       False
# 4     https://s.rfi.fr/media/display/65a96370-5697-1...       False
# ...                                                 ...         ...
# 3076  https://i.em.com.br/ZjS60Ej_Ynh8S-8wzRKJtI9FrA...        True
# 3077  https://s.yimg.com/uu/api/res/1.2/4ZNjq5Y5hJbM...       False
# 3078  https://ichef.bbci.co.uk/news/1024/branded_por...       False
# 3079  https://midias.correiobraziliense.com.br/_midi...       False
# 3080  https://p2.trrsf.com/image/fget/cf/1200/628/mi...       False
#
#        twitter_account     _score                               _id  \
# 0     UOLNoticias @UOL  26.075209  f4a75f334b8f119a154fb8e2c0061cf0
# 1                 None  23.587915  83c2660cc901f803e890b1cee7a5ca4f
# 2        @JornalOGlobo  22.977170  ddfbbb289e25b75a5c46b7c9855b5c2c
# 3     UOLNoticias @UOL  22.948810  3d9b7ac88daacdc605af30046542306e
# 4              @RFI_Br  22.026545  0d8366fddb447757e5b72902d7833eab
# ...                ...        ...                               ...
# 3076           @em_com   2.195018  6681d64150f2e2b52366cbf99d8e6968
# 3077          @YahooBr   2.194939  2548157feebf9f68a63af6e39083ab70
# 3078        @bbcbrasil   2.193445  5f5eef810b38f2ccf66328f00ffad27b
# 3079          @correio   2.193445  468e632c28c40764059d932da702a7c5
# 3080            @terra   2.144209  38b9449dadf2b8239a3f2b67f3ed2c3e
#
#                                             used_params
# 0     {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 1     {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 2     {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 3     {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 4     {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# ...                                                 ...
# 3076  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 3077  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 3078  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 3079  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
# 3080  {'q': 'Aviação OR Transporte OR Anúncio', 'lan...
#
# [3081 rows x 20 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2392c230-4672-47ef-bbd2-e97d3feaff76' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
