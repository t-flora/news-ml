# %% [markdown]
# # Named-entity recognition

# %%
import spacy
import matplotlib.pyplot as plt
from time import time
import pandas as pd
import random
import os
from tqdm import tqdm
import torch
random.seed(2022)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Data path and filename given to read data
DATA_PATH = "../data/csvfiles/scraped_web"
filename = "beta_announcements.csv"

# Define the model to be used. For languages with transformer-based models, they are recommended as they
# tend to have higher performance for NER according to SpaCy's benchmarks
model = "en_core_web_trf"

os.listdir(DATA_PATH)
# Out:
# ['beta_announcements.csv']

# %%
# Turn articles into dataframe. The volume of articles in a single website is low enough that dataframes
# provide a reasonable and convenient option for data manipulation.
df = pd.read_csv(DATA_PATH + "/" + filename)
df.head()
# Out:
#    Unnamed: 0                                                URL  \
# 0           0  https://www.futureflight.aero/news-article/202...
# 1           1  https://www.cae.com/news-events/press-releases...
# 2           2  https://evtol.com/features/why-evtol-developer...
# 3           3  https://evtol.com/video/martine-rothblatt-flie...
# 4           4  https://www.burlingtonfreepress.com/story/news...
#
#                                                 text  \
# 0  The U.S. Army is to support flight testing of ...
# 1  • CAE and BETA to partner and create best in c...
# 2  When many people contemplate the benefits of a...
# 3  Martine Rothblatt, CEO of the biotechnology co...
# 4  Update: This story has been updated to reflect...
#
#                                                title       published_date  \
# 0  U.S. Army Looks To Enlist Beta's Alia eVTOL wi...  2022-01-31 00:00:00
# 1                                                CAE                  NaN
# 2  Why eVTOL developer Beta gives its employees f...                  NaN
# 3                Martine Rothblatt Flies Beta’s Alia                  NaN
# 4  Ready for takeoff: Vermont nonprofit wants to ...  2021-06-08 00:00:00
#
#    summary
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# Load model
if model is not None:
    nlp = spacy.load(model)  # Load defined SpaCy model
    print("Loaded model '%s'" % model)
else:
    nlp = spacy.blank('en')  # create blank Language class
    print("Created blank 'en' model")

# Get NER pipeline component for defined model
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print("Model does not contain NER pipeline component by default. One was created and added, but it must be trained.")
else:
    ner = nlp.get_pipe('ner')
# Out:
# Loaded model 'en_core_web_trf'

# %%
bodies = list(df['text'])
titles = list(df['title'])

# %%
def check_str(texts):
    strs = []
    count_ = 0
    for b in texts:
        if type(b) == str:
            strs.append(b)
        else:
            count_ += 1
    count_perc = count_/len(texts)
    return strs, count_, count_perc

bodies = check_str(bodies)[0]
titles = check_str(titles)[0]
# print([type(bodies[i]) for i in range(len(bodies))])

# %%
def timer(f):
    """SImple timer wrapper to display function running time

    Args:
        f (func): function wrapped
    """    
    def wrapper(*args, **kwargs):
        s = time()
        res = f(*args, **kwargs)
        print(f"{(time() - s):.4f} s")
        return res
    return wrapper

@timer
def process(corpus):
    return list(nlp.pipe(corpus))

# Process texts as a stream, which is much faster than calling nlp() on each text
t_docs = process(titles)
b_docs = process(bodies) # Processing article bodies takes 35-60x longer than processing titles
# Out:
# /home/tflora/projects/capstone-project/venv/lib/python3.8/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# 0.3006 s
# 18.5642 s

# %%
def group_ents(doc, print_ents = False, ent_data_as_df = True):
    """Group entities by category and count labels and categories from `ents` attribute

    Args:
        doc (spacy.tokens.Doc.doc): Spacy document object for which to process entities
        print_ents (bool, optional): Print out each entity along with start and end characters, label, and label
        explanation. Defaults to False.

    Returns:
        dict: dictionary containing 4 dictionaries; 
            - 1 for the number of each label found in the document, 
            - 1 for the number of mentions of each uniquely identified entity,
            - 1 with lists of entities belonging to each entity label
            - 1 with text-label pairs
    """    
    if doc.ents:
        d = {"label_counts" : {}, "ent_counts" : {}, \
            "ents_per_label" : {}, "ent_data" : []}
        for ent in doc.ents:
            if print_ents:
                print("=================================================")
                print(f"Entity: {ent.text}\nStart char: {str(ent.start_char)}\nEnd char: {str(ent.end_char)}\
                    \nLabel: {ent.label_}\nLabel explanation: {spacy.explain(ent.label_)}")
                print("=================================================")
            d["label_counts"][ent.label_] = d["label_counts"].get(ent.label_, 0) + 1
            d["ent_counts"][ent.text] = d["ent_counts"].get(ent.text, 0) + 1
            if ent.label_ in d["ents_per_label"]:
                d["ents_per_label"][ent.label_].append(ent.text)
            else:
                d["ents_per_label"][ent.label_] = [ent.text]
            d['ent_data'].append([ent.text, ent.label_])
        if ent_data_as_df:
            d['ent_data'] = pd.DataFrame(d['ent_data'])
            # d["ents_per_label"][ent.label_] = d["ents_per_label"].get(ent.label_, 0).append(ent.text)
        return d
    else:
        print("No entities in doc object")
        return

print(t_docs[0])
title_data = group_ents(t_docs[0], print_ents=False, ent_data_as_df=True)
title_data['ent_data']
# Out:
# U.S. Army Looks To Enlist Beta's Alia eVTOL with Flight Test Contract
#            0        1
# 0  U.S. Army      ORG
# 1       Beta      ORG
# 2       Alia  PRODUCT
# 3      eVTOL  PRODUCT

# %%
type(t_docs[0])
# Out:
# spacy.tokens.doc.Doc

# %%
t_ent_lsts = [doc.ents for doc in t_docs]
b_ent_lsts = [doc.ents for doc in b_docs]

# %%
t_ent_lsts
# Out:
# [(U.S. Army, Beta, Alia, eVTOL),
#  (CAE,),
#  (),
#  (Martine Rothblatt, Alia),
#  (Vermont,),
#  (Williston Observer,),
#  (Amazon, Climate Fund, Fidelity),
#  (BTV,),
#  (BETA Technologies’, ALIA eVTOL, US, Air Force),
#  (BETA, first, 20, Blade),
#  (),
#  (EVTOL,),
#  (),
#  (GAMA, Beta Technologies, Toyota Motor North America),
#  (),
#  (Beta, first),
#  (),
#  (),
#  (Beta Technologies, Vermont),
#  (),
#  (),
#  (),
#  (Beta, Ava, the Edward Scissorhands),
#  (),
#  (),
#  (Beta Technologies, eVTOL)]

# %%
def count_dataset_ents(corpus, data_as_df = True):
    """Obtains count data for an entire article dataset from a given company. 

    Args:
        docs_ent_counts (list): List of dictionaries containing count data for each document object in a corpus, as processed
        in `group_ents`

    Returns:
        dict: dictionary containing 3 other dictionaries; 
            - 1 one for the total number of mentions to unique entity identifiers,
            - 1 for the total count of each entity label type, 
            - 1 with the entity lists obtained for each entity type
    """
    # Group entities in article-body corpus
    docs_ent_counts = [group_ents(doc) for doc in corpus]
    
    df = pd.DataFrame() # create empty dataframe
    c = {"entity_counts" : {}, "label_counts" : {}, "ent_lists" : {}, "ent_data" : df}
    for doc_counts in docs_ent_counts:
        # Count labels by adding one every time a label is encountered
        for l in doc_counts["label_counts"]:
            c["label_counts"][l] = c["label_counts"].get(l, 0) + 1
        for e in doc_counts["ent_counts"]:
            c["entity_counts"][e] = c["entity_counts"].get(e, 0) + 1
        epl = doc_counts["ents_per_label"]
        for ec in epl:
            if ec in c["ent_lists"]:
                c["ent_lists"][ec].extend(epl[ec])
            else:
                c["ent_lists"][ec] = epl[ec]
        if data_as_df:
            c['ent_data'] = pd.concat([c['ent_data'], doc_counts['ent_data']])
    if data_as_df:
        c['ent_data'].columns = ['entity', 'label']
    return c

# %%
c = count_dataset_ents(b_docs)
c['label_counts']
# Out:
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# /tmp/ipykernel_113351/3323011017.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c['ent_data'] = c['ent_data'].append(doc_counts['ent_data'])
# {'ORG': 25,
#  'PRODUCT': 23,
#  'DATE': 24,
#  'FAC': 12,
#  'GPE': 23,
#  'QUANTITY': 19,
#  'PERSON': 25,
#  'EVENT': 2,
#  'LAW': 3,
#  'CARDINAL': 23,
#  'ORDINAL': 15,
#  'TIME': 15,
#  'WORK_OF_ART': 6,
#  'NORP': 3,
#  'MONEY': 8,
#  'LOC': 9,
#  'PERCENT': 6}

# %%
df = c['ent_data']
df.head()
# Out:
#               entity    label
# 0      The U.S. Army      ORG
# 1  Beta Technologies      ORG
# 2           Alia 250  PRODUCT
# 3              today     DATE
# 4               Army      ORG

# %%
df['label'].value_counts()
# Out:
# ORG            662
# PERSON         319
# DATE           237
# PRODUCT        179
# CARDINAL       167
# GPE            166
# QUANTITY       114
# ORDINAL         46
# MONEY           31
# TIME            24
# FAC             23
# LOC             21
# PERCENT         15
# WORK_OF_ART      6
# NORP             4
# LAW              3
# EVENT            2
# Name: label, dtype: int64

# %%
df.groupby('label').count() # gets unique value counts
# Out:
#              entity
# label
# CARDINAL        167
# DATE            237
# EVENT             2
# FAC              23
# GPE             166
# LAW               3
# LOC              21
# MONEY            31
# NORP              4
# ORDINAL          46
# ORG             662
# PERCENT          15
# PERSON          319
# PRODUCT         179
# QUANTITY        114
# TIME             24
# WORK_OF_ART       6

# %%
print(df[df['label'] == "PERSON"])
# Out:
#             entity   label
# 18      Kyle Clark  PERSON
# 20      Will Roper  PERSON
# 27   Charles Brown  PERSON
# 20      Kyle Clark  PERSON
# 25  Nick Leontidis  PERSON
# ..             ...     ...
# 57      Kyle Clark  PERSON
# 59      Eric Adams  PERSON
# 63           Clark  PERSON
# 67           Clark  PERSON
# 70           Clark  PERSON
#
# [319 rows x 2 columns]

# %%
c['entity_counts']
# Out:
# {'The U.S. Army': 1,
#  'Beta Technologies': 18,
#  'Alia 250': 3,
#  'today': 9,
#  'Army': 1,
#  'Beta': 17,
#  'the U.S. Air Force': 3,
#  'last year': 3,
#  'Alia': 11,
#  'Agility Prime': 4,
#  'Burlington International Airport': 10,
#  'Vermont': 16,
#  'Plattsburg': 1,
#  'New York': 8,
#  '205 miles': 1,
#  '8,000 feet': 3,
#  'Kyle Clark': 22,
#  'Will Roper': 1,
#  'U.S.': 4,
#  'the Air Force': 6,
#  'the Reagan National Defense Forum': 1,
#  'December 5, 2021': 1,
#  "the Air Force's": 2,
#  'Charles Brown': 1,
#  'Afwerx': 1,
#  'FAA': 8,
#  'Part 23 type': 1,
#  '2024': 8,
#  'UPS': 8,
#  '150': 3,
#  'United Therapeutics': 13,
#  'Blade Urban Air Mobility': 2,
#  'CAE': 1,
#  'BETA': 5,
#  'BETA Technologies': 4,
#  'UPS Flight Forward': 2,
#  'United Therapeutics & Blade': 1,
#  'ALIA eVTOL Aircraft': 1,
#  'ALIA': 4,
#  'eVTOL': 4,
#  'tomorrow': 1,
#  'Advanced Air Mobility': 1,
#  'close to 75 years': 1,
#  'Nick Leontidis': 1,
#  'Civil Aviation Training Solutions': 1,
#  'first': 14,
#  'Blade': 4,
#  'U.S. Air Force': 2,
#  'hundreds of hours': 1,
#  '200 miles': 1,
#  'November 2020': 1,
#  '2020-2029': 1,
#  'Pilot Demand Outlook': 1,
#  '264,000': 1,
#  'the next ten years': 1,
#  'this new era': 1,
#  'Burlington': 13,
#  'Beta Technologies Photo': 1,
#  '17': 1,
#  '4,000 hours': 1,
#  '20 years': 1,
#  'more than a dozen': 1,
#  'Bella Riely': 1,
#  'Riely': 1,
#  'Lochie Ferrier': 1,
#  'day': 1,
#  'Ferrier': 1,
#  'month-long': 1,
#  'Swiss': 1,
#  'Lan Vu': 1,
#  'eVTOL.com': 1,
#  'Lan': 1,
#  'Vu': 1,
#  '250': 1,
#  'hundreds': 2,
#  'Fidelity Management': 1,
#  'Amazon': 3,
#  'Climate Change Fund': 1,
#  'Ford': 2,
#  'Martine Rothblatt': 5,
#  "Beta Technologies'": 3,
#  'Rothblatt': 4,
#  'Vermont Flight Academy': 1,
#  'FLIGHT VT': 1,
#  'The Flight Academy': 1,
#  'as many as 100': 1,
#  'ages 12-22': 1,
#  'this year': 1,
#  'zero': 6,
#  'Tyler Brown': 1,
#  'the Vermont Flight Academy': 1,
#  'Zero': 1,
#  'Flight VT': 1,
#  'Saturday': 1,
#  'Molly Gray': 1,
#  'Airport': 1,
#  'Gene Richards': 2,
#  'Spectrum Youth & Family Services': 1,
#  'Sara Holbrook Community Center': 1,
#  'King Street Center': 1,
#  'Boys & Girls Club': 1,
#  'Boys & Girls Club of Vergennes': 1,
#  'Mark Redmond': 1,
#  'Spectrum': 1,
#  'this summer': 1,
#  'Redmond': 1,
#  'July 10': 1,
#  'Aug. 7': 1,
#  'Dan D’Ambrosio': 1,
#  '660-1841': 1,
#  'May 27, 2021': 1,
#  'WCS': 1,
#  'JASON STARR': 1,
#  'Observer': 1,
#  'Sixth': 1,
#  'Jonah Wayman': 1,
#  'Williston Central School': 1,
#  'two': 12,
#  'Avenue D': 1,
#  'Williston': 4,
#  'Wayman': 1,
#  'Genius Hour': 1,
#  'Joy Peterson': 1,
#  'Jared Bailey': 1,
#  'Williston Central': 1,
#  '($368 million': 1,
#  'Fidelity': 1,
#  'a day': 2,
#  'Obama Administration': 1,
#  'Marine One': 1,
#  'Nick Warren': 1,
#  'this Wednesday': 1,
#  'June 11': 1,
#  'Tuesday': 1,
#  'Katie Clark': 2,
#  'his eighth-grade year': 1,
#  'Essex': 2,
#  'Essex High School': 1,
#  'Katie': 2,
#  'Harvard': 6,
#  'Kyle': 3,
#  'the Washington Capitals': 2,
#  'NHL': 1,
#  'Jonah': 1,
#  'the past year': 1,
#  'thousands': 3,
#  '170 mph': 1,
#  '250-mile': 2,
#  'a ton': 1,
#  'April': 3,
#  'VTDigger': 1,
#  'Avenue D.': 1,
#  'six': 4,
#  '2017': 7,
#  'eight': 6,
#  '200': 1,
#  'the next few years': 1,
#  'Kara Hurst': 1,
#  'The Climate Pledge Fund': 1,
#  'Clark': 14,
#  'CNBC': 1,
#  '$1 billion': 2,
#  'Beta EVAs': 1,
#  '10': 2,
#  'Alia-250 EVAs': 1,
#  'United Parcel Service': 2,
#  'an additional 140': 1,
#  'last month': 3,
#  'as many as 20': 1,
#  'EVAs': 1,
#  'Blade Air Mobility': 1,
#  '2014': 1,
#  '2021': 2,
#  'March': 2,
#  'Joby Aviation': 4,
#  '$6.6 billion': 1,
#  'A month earlier': 1,
#  'Archer': 1,
#  'SPAC': 1,
#  '$3.8 billion': 1,
#  'The Federal Aviation Administration': 2,
#  'Brian Jenkins': 1,
#  'one': 11,
#  'Ping-Pong': 2,
#  'Silicon Valley': 2,
#  '50-foot': 3,
#  'four': 9,
#  'fifth': 1,
#  'three': 4,
#  '250 miles': 4,
#  'Champlain Valley': 1,
#  'Jetsons': 1,
#  'South Burlington': 3,
#  'the last few years': 1,
#  'Oliver Parini': 1,
#  'six-foot-six': 1,
#  'Metallica': 1,
#  '13': 1,
#  'last June': 2,
#  '100-mile': 1,
#  'Chittenden County': 2,
#  'Last week': 2,
#  'second': 4,
#  'at least 10': 1,
#  'roughly $4 million': 1,
#  'up to 20': 2,
#  '800': 1,
#  'Manhattan': 1,
#  'Hamptons': 1,
#  '75': 1,
#  'a year ago': 1,
#  'more than 230': 1,
#  'more than $4 billion': 1,
#  '$143 million': 1,
#  '$190 million': 1,
#  'U.S. Securities and Exchange Commission': 1,
#  'April 1': 1,
#  'Brian Foley': 1,
#  "You're On": 1,
#  '41': 1,
#  'Harvard University': 2,
#  '2004': 2,
#  'the Harvard Gazette': 1,
#  'The Washington Capitals': 1,
#  '1999': 1,
#  'a couple of seasons': 1,
#  'Clarks': 1,
#  'iTherm Technologies': 1,
#  'Colchester': 1,
#  'Dynapower': 1,
#  'Designbook': 2,
#  'Venture.co': 1,
#  'March 2017': 1,
#  'Philadelphia': 1,
#  'Sirius Satellite Radio': 1,
#  'Bina Aspen': 1,
#  'the Terasem Movement': 1,
#  'Lincoln': 1,
#  'One': 3,
#  'Terasem': 1,
#  'Bina': 1,
#  'Bina48': 1,
#  'October 2016': 2,
#  'Uber': 6,
#  'decade': 1,
#  '2030': 1,
#  'California': 1,
#  '2016': 1,
#  'That same year': 1,
#  'Lung Biotechnology': 1,
#  '$10 million': 1,
#  'Chinese': 1,
#  'EHang': 1,
#  'that day': 1,
#  'Seven Days': 1,
#  'Underhill': 1,
#  '4 a.m.': 1,
#  'the next day': 1,
#  '$1.5 million': 1,
#  'Later that morning': 1,
#  'Dean Kamen': 2,
#  'New Hampshire': 1,
#  'Segway': 2,
#  'Stone Point': 1,
#  'Charles Davis': 1,
#  'Boston Scientific': 1,
#  'Shelburne': 1,
#  'John Abele': 1,
#  'Steve Arms': 2,
#  'MicroStrain': 2,
#  'its first year': 1,
#  'Ben Colbourn': 1,
#  'Generator': 1,
#  'Colbourn': 1,
#  'Benjamin Colbourn': 1,
#  'Lake Champlain': 7,
#  'Plattsburgh International Airport': 5,
#  'Within 10 months': 1,
#  'Ava': 9,
#  '$48 million': 2,
#  'late last month': 1,
#  'Andrew Giroux': 1,
#  'roughly 3 percent': 1,
#  'the Environmental Protection Agency': 1,
#  'recent years': 1,
#  'Nicholas Roy': 1,
#  'the Massachusetts Institute of Technology': 1,
#  '400-horsepower': 1,
#  'about 95 percent': 1,
#  'Rolls-Royce': 1,
#  'Safran': 1,
#  'Foley': 1,
#  'Mike Hirschberg': 1,
#  'the Vertical Flight Society': 1,
#  'Hirschberg': 1,
#  'more than 200': 2,
#  'Last year': 1,
#  'the Federal Aviation Administration': 4,
#  'Plattsburgh': 9,
#  "New Year's Day this year": 1,
#  'BTV': 2,
#  'almost daily': 2,
#  '101st': 1,
#  'the day': 1,
#  'FlightAware': 1,
#  'more than 90 miles': 1,
#  '5,900 feet': 1,
#  '150 miles per hour': 1,
#  '2020': 2,
#  'Department of Defense': 1,
#  'Patrick Leahy': 1,
#  'D': 1,
#  'Vt.': 1,
#  'an extra $25 million': 1,
#  'The Air Force': 2,
#  'Springfield': 4,
#  'Ohio': 3,
#  'Washington': 4,
#  'D.C.': 4,
#  'up to $44 million': 1,
#  'Air Force': 4,
#  'Nathan Diller': 2,
#  'Brian Jenkins/Beta Technologies': 1,
#  'Richard Aboulafia': 1,
#  'Virginia': 1,
#  'Teal Group': 1,
#  'Aboulafia': 1,
#  'the turn of the millennium': 1,
#  'Eclipse Aviation': 1,
#  'hundreds of millions': 1,
#  'The last few months': 1,
#  'Robin Riedel': 1,
#  'McKinsey & Company': 1,
#  '2019': 3,
#  'the last couple of years': 1,
#  'Three': 1,
#  'February': 1,
#  'as much as $1.6 billion': 1,
#  'McKinsey': 1,
#  'at least $300 billion': 1,
#  'annually': 2,
#  'Riedel': 1,
#  'more than $750 million': 1,
#  'the next two to three years': 1,
#  'late April': 1,
#  '60': 2,
#  '2026': 2,
#  'Derek Brouwer': 1,
#  'More than 30': 1,
#  '100': 2,
#  'each day': 1,
#  'a recent Wednesday': 1,
#  '18-year-old': 1,
#  'Willa': 1,
#  '16': 1,
#  'Last fall': 1,
#  'Matt Cherouny': 1,
#  '35-year-old': 1,
#  'Cherouny': 1,
#  'the University of Vermont': 1,
#  'Green Mountain Coffee Roasters': 1,
#  'Tesla': 5,
#  'several years ago': 1,
#  'Vermont Business Magazine': 2,
#  'Richards': 1,
#  'nearly 40-acre': 1,
#  'more than half': 1,
#  'the winter': 1,
#  'Vermont Employment Growth Incentive': 1,
#  'up to $2.8 million': 1,
#  'Miro Weinberger': 1,
#  'Leahy': 1,
#  'last week': 4,
#  'Congress': 1,
#  'Joe Biden': 1,
#  'less than an hour': 2,
#  'New York State': 1,
#  'East': 1,
#  'West': 1,
#  'Rutland': 1,
#  'Dan Delabruere': 1,
#  'Airport Drive': 1,
#  'the US Air Force’s': 1,
#  'ALIA eVTOL': 1,
#  'The U.S. Air Force': 1,
#  'more than a year': 1,
#  '516c': 1,
#  '7,000-pound': 1,
#  'AFWERX': 1,
#  'the United States Air Force': 1,
#  'AFRL': 1,
#  'the US Air Force': 2,
#  'the Air Force Research Laboratory': 1,
#  'the Air Force’s': 2,
#  'Air Force Agility Prime': 1,
#  'Last month': 2,
#  'the same week': 2,
#  'Armed Forces': 1,
#  'BLADE': 1,
#  'December 2020': 1,
#  'Logistics': 1,
#  'Medical': 1,
#  'Defense': 1,
#  'Passenger': 1,
#  'every day': 1,
#  'UAM': 1,
#  'Rob Wiesenthal': 1,
#  'Electric Vertical Aircraft': 1,
#  'almost every day': 1,
#  'EVA': 1,
#  '2025': 2,
#  'third': 1,
#  'late 2024': 1,
#  '250 nautical mile': 1,
#  'up to 170 miles per hour': 1,
#  'The United States Air Force': 1,
#  'USAF': 1,
#  '250 nautical miles': 3,
#  'less than 50 minutes': 1,
#  'nine percent': 1,
#  '2035': 1,
#  'the next 20 years': 1,
#  'United States': 1,
#  'America': 1,
#  'VT': 1,
#  'OH': 1,
#  'Electric Vertical Aircraft ("EVA"': 1,
#  'Part 23': 1,
#  'over 250': 1,
#  'Boeing': 3,
#  'SpaceX': 1,
#  'Lockheed Martin': 1,
#  'General Electric': 1,
#  'Blade Urban Air Mobility ("Blade"': 1,
#  'Today': 2,
#  'Experience Investment Corp.': 1,
#  'NASDAQ': 1,
#  'EXPC': 1,
#  'Beta Technologies’': 3,
#  'Vertical Takeoff and Landing (eVTOL)': 1,
#  'Atlanta': 1,
#  'GA': 1,
#  '1,400-pound': 1,
#  'up to': 2,
#  '170 miles per hour': 1,
#  'Juan Perez': 1,
#  'an hour': 1,
#  'under one hour': 1,
#  'more than 12,000': 1,
#  'up to 10,000': 1,
#  'Arrival': 1,
#  'U.S. Federal Aviation Administration': 1,
#  'Part 135 Standard': 1,
#  'daily': 2,
#  'up to 7,500 lbs': 1,
#  'NY': 1,
#  'Vt': 1,
#  '.': 1,
#  'ten': 1,
#  'up to 150': 1,
#  'UPS Brand Central': 1,
#  'NYSE': 1,
#  '$84.6 billion': 1,
#  'more than 220': 1,
#  'more than 540,000': 1,
#  'First': 2,
#  'billion-dollar': 1,
#  'March 16': 1,
#  'Eric Adams': 8,
#  'Wednesday': 1,
#  'Alia-250': 1,
#  'nearly 200': 1,
#  'Camron “Arlo” Guthrie': 1,
#  'early-morning': 1,
#  'several months': 1,
#  'a few weeks': 2,
#  'recent weeks': 1,
#  'week': 2,
#  'only 18 miles/29 kilometers': 1,
#  'just three': 1,
#  'five': 2,
#  '50 minutes': 1,
#  '400 km': 1,
#  'the General Aviation Manufacturer’s Association': 1,
#  'GAMA': 2,
#  'Pennsylvania': 1,
#  'Wright Patterson Air Force Base': 1,
#  'the United States': 2,
#  '18 stories': 1,
#  'The General Aerospace Manufacturers Association': 1,
#  'Toyota Motor North America': 1,
#  'Airbus Corporate Jets': 1,
#  'Hartzell Engine Technologies': 1,
#  'Incora': 1,
#  'Pamela Cohn': 1,
#  'Hyundai': 1,
#  'Wisk': 1,
#  'Gary Gysin': 1,
#  'early March': 1,
#  'the U.S. Congress': 1,
#  'Mar. 15': 1,
#  'Propulsion and Innovation': 1,
#  'JoeBen Bevirt': 1,
#  'Roei Ganzarski': 1,
#  'MagniX': 1,
#  'Eviation': 1,
#  'CB Hall': 1,
#  'about 3.5 percent': 1,
#  'That 3.5 percent': 1,
#  '4 to': 1,
#  '5 percent': 2,
#  'yearly': 1,
#  '2010': 1,
#  'VBM': 1,
#  'US Air Force': 1,
#  'EVTOL': 1,
#  'Airbus': 4,
#  'between 2026 and 2030': 1,
#  '40,000-square-foot': 1,
#  'January 19': 1,
#  '177': 1,
#  '14,000-square-foot': 1,
#  '22,000-square-foot': 1,
#  'just under one million': 1,
#  'night': 1,
#  'The Virtues of Simplicity': 1,
#  'Maryland': 1,
#  'North Carolina': 1,
#  'UT': 1,
#  'Organ Manufacturing Group': 1,
#  'the end of the decade': 1,
#  'only two to three tons': 1,
#  '288 miles': 1,
#  'about $53 million': 1,
#  'Federal Aviation Administration': 3,
#  'two-and-a-half-': 1,
#  '2022': 1,
#  '2023': 1,
#  '2027': 1,
#  'each year': 1,
#  '20': 1,
#  'the American Transplant Foundation': 1,
#  '108 to 120 thousand': 1,
#  'the United Network for Organ Sharing': 1,
#  'about 40,000': 1,
#  'many thousands': 1,
#  'Uber Elevate': 1,
#  'Elevate Network': 1,
#  'Dallas': 2,
#  'Los Angeles': 1,
#  'Melbourne': 1,
#  'NASA': 2,
#  'up to nine': 1,
#  '240-volt': 1,
#  'Southern Vermont': 1,
#  'June 19, 2020': 1,
#  '8 minutes, 45 seconds': 1,
#  'Friday, June 12': 1,
#  'roughly 30-minute': 1,
#  '100 feet': 3,
#  'Sikorsky': 1,
#  'S-61N': 1,
#  'Quebec': 1,
#  'Helicarrier': 1,
#  'just a few hundred feet': 1,
#  '10,000 pounds': 1,
#  '4,535 kilograms': 1,
#  'something': 1,
#  'at least a year': 1,
#  'Aaron Lighter': 1,
#  'Fred Carrier': 1,
#  'multimillion-dollar': 1,
#  'the weeks and months': 1,
#  '90 knots': 1,
#  '40 knots': 1,
#  '6,000-lb': 1,
#  '2,720-kg': 1,
#  '3,000 lb': 1,
#  '1,360 kg': 1,
#  '15-meter': 1,
#  'a sunny day': 1,
#  'three-degree': 1,
#  'Friday': 1,
#  'Arctic': 1,
#  'under an hour': 1,
#  '6,000 pounds': 1,
#  '3,800 pounds': 1,
#  'just one': 1,
#  'Thomas James': 1,
#  'New England': 1,
#  "New York State's": 1,
#  'Vermont Tech Jam': 1,
#  "Tom O'Leary": 1,
#  'Lyft': 1,
#  '38-year-old': 1,
#  'the spring of 2017': 1,
#  'just 10 months': 1,
#  "O'Leary": 1,
#  'Horizon Air': 1,
#  'Dealer.com': 1,
#  'Tesla Motors': 1,
#  'Palo Alto': 1,
#  'Calif.': 1,
#  'a half dozen': 1,
#  'July': 1,
#  '21': 1,
#  'Defense Advanced Research Projects Agency': 1,
#  'years': 1,
#  'tens,': 1,
#  'hundreds, of millions of dollars': 1,
#  'Toyota': 1,
#  'General Motors': 1,
#  'a decade ago': 1,
#  'the morning': 1,
#  'the same afternoon': 1,
#  'Ten years ago': 1,
#  'a month': 1,
#  'a few days': 1,
#  'a matter of two months': 1,
#  'the Environmental Defense Fund': 1,
#  '2 to': 1,
#  '3 percent': 1,
#  '2050': 1,
#  '5.64': 1,
#  'gallon': 1,
#  '429': 1,
#  'Bell': 2,
#  '3,600': 1,
#  'around $100': 1,
#  'about 10,000 hours': 1,
#  'only 1,000 to 3,000.': 1,
#  'hundreds of gallons': 1,
#  'Engineering Thesis of the Year': 1,
#  '15 years': 1,
#  'LORD Sensing-MicroStrain': 1,
#  'Arms': 1,
#  'LORD': 1,
#  '2012': 1,
#  'November 2017': 1,
#  'Artur Adib': 1,
#  'Twitter': 1,
#  'Mozilla': 1,
#  "New Mexico's": 1,
#  'Los Alamos National Laboratory': 1,
#  'Adib': 1,
#  '1970s': 1,
#  "'80s": 1,
#  'Cessna 172': 1,
#  'next year': 1,
#  'the next five to 50 years': 1,
#  'F-4 Phantom': 1,
#  'the Air Force Reserve': 1,
#  'Enstrom': 2,
#  '28FX': 2,
#  'X-': 2,
#  'Plane': 2,
#  'Austin Meyers': 1,
#  'the next decade': 1,
#  'Plattsburgh Air Force Base': 1,
#  'the Ava XC': 3,
#  '4,000-pound': 2,
#  'two years': 1,
#  'The Drive': 2,
#  '90 degrees': 2,
#  '35-foot': 3,
#  'more than 170': 1,
#  'this week': 1,
#  'spring': 1,
#  'summer': 1,
#  'SiriusXM': 2,
#  'seven percent': 2,
#  'every year': 2,
#  'the past several decades': 2,
#  '300 watt-hours': 2,
#  'just a few years': 2,
#  'Eric Adams\n\n': 1,
#  'his college days': 1,
#  'the last 15 years': 1,
#  'GE Global Research': 2,
#  'Scaled Composites': 2,
#  '12,000-foot': 1,
#  'three to 10': 1,
#  'between 20 and': 1,
#  '30 percent': 1,
#  '90 to 99 percent': 1,
#  'the thousands': 1,
#  'coming decades': 1,
#  '1982': 1,
#  'Eagle': 1,
#  'up to 290 miles': 2,
#  'Elan Head': 1,
#  'February 7, 2019': 1,
#  '16 minutes, 32 seconds': 1,
#  'dozens': 1,
#  'as early as 2023': 1,
#  'Ava XC': 2,
#  'Lancair': 2,
#  'ES': 1,
#  'RDD Enterprises': 1,
#  'Blue Force Technologies': 1,
#  '124': 1,
#  'as far as zero degrees': 1,
#  '10.7-meter': 2,
#  '124 kilowatt-hours': 1,
#  'around 4,000 pounds': 1,
#  '1,815 kilograms': 1,
#  'more than 180': 1,
#  'Douglas': 1,
#  'Sitka': 1,
#  '39': 1,
#  'Austin Meyer': 2,
#  'X': 1,
#  '-': 1,
#  '35': 1,
#  'Meyer': 1,
#  'less than 1,000': 1,
#  'Bell-Boeing': 1,
#  'V22': 1,
#  'Leonardo AW609': 1,
#  '154 knots': 2,
#  '90-degree': 2,
#  '72 knots': 2,
#  'as high as 25 knots': 2,
#  'a week': 1,
#  'The Ava XC': 1,
#  'Osprey': 1,
#  '8': 1,
#  'a 4,400 lb': 1,
#  '1,815 kilo': 1,
#  'well over 180': 1,
#  'all these years': 1,
#  'two-year': 1,
#  'Vertical Mag': 1,
#  '124 kWh': 2,
#  '177 mph': 1,
#  '150 miles': 2,
#  '240 kilometers': 1,
#  '465 kilometers': 1,
#  'this past week': 1,
#  'The Eva XC': 1,
#  'CleanTechnica': 1,
#  'CleanTech Talk': 1,
#  'Patreon': 1,
#  'Vermont Air National Guard': 1,
#  'F-35': 1,
#  'three-year-old': 1,
#  'Transportation': 1,
#  '20-foot': 1,
#  'overnight': 1,
#  'Chip Palombini': 1,
#  'early January': 1,
#  '20 miles': 1,
#  'Canadian': 1,
#  '40-year-old': 1,
#  'Cessna': 1,
#  'winter': 1,
#  'B-52': 1,
#  'Tony Stark': 1,
#  'Edward Scissorhands': 2,
#  '34-foot': 1,
#  '143-horsepower': 1,
#  '90-degrees': 1,
#  '172 mph': 1,
#  'morning': 1,
#  '175': 1,
#  '176th': 1,
#  '70 degrees': 1,
#  'more than 130': 1,
#  'Larry Page': 1,
#  'Kitty Hawk': 2,
#  'Joby': 2,
#  '50 feet': 1,
#  'moments': 1,
#  'April 2000': 1,
#  'V-22 Osprey': 1,
#  'Black Hawk': 1,
#  '2011': 1,
#  'Osama bin Laden': 1,
#  'just 3 feet': 1,
#  'about 200': 1,
#  'Lilium': 1,
#  'the few short years': 1,
#  'Wyoming': 1,
#  'Matt Mead': 1,
#  'Arkansas': 1,
#  'Mead': 1,
#  'early this year': 1,
#  'hours': 1,
#  'New York City': 1,
#  'TexasUP': 1,
#  'Ava-XC': 1,
#  '4,000-lb': 1,
#  '1,815-kg': 1,
#  '6,000-pound': 1,
#  '2,720-kilogram': 1,
#  '400 kilometers': 1,
#  'TexasUP.': 1,
#  'F550': 1,
#  '120 knots': 1,
#  '14-foot': 1,
#  'three to four': 1,
#  'the East Coast': 1}

# %%
c["ent_lists"]["ORG"]
# Out:
# ['The U.S. Army',
#  'Beta Technologies',
#  'Army',
#  'Beta',
#  'the U.S. Air Force',
#  'Agility Prime',
#  'Army',
#  'Beta',
#  'the Air Force',
#  "the Air Force's",
#  'FAA',
#  'UPS',
#  'United Therapeutics',
#  'Blade Urban Air Mobility',
#  'Beta',
#  'CAE',
#  'BETA',
#  'BETA Technologies',
#  'UPS Flight Forward',
#  'United Therapeutics & Blade',
#  'CAE',
#  'BETA Technologies',
#  'BETA',
#  'CAE',
#  'CAE',
#  'BETA',
#  'CAE',
#  'Advanced Air Mobility',
#  'BETA',
#  'CAE',
#  'BETA',
#  'CAE',
#  'CAE',
#  'CAE',
#  'Civil Aviation Training Solutions',
#  'CAE',
#  'BETA',
#  'BETA',
#  'BETA',
#  'BETA',
#  'the U.S. Air Force',
#  'UPS Flight Forward',
#  'United Therapeutics',
#  'Blade',
#  'U.S. Air Force',
#  'BETA',
#  'ALIA',
#  'CAE',
#  'CAE',
#  'Beta Technologies',
#  'Beta',
#  'Beta',
#  'Beta Technologies Photo',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta Technologies Photo',
#  'Beta',
#  'Beta',
#  'Ferrier',
#  'Ferrier',
#  'eVTOL.com',
#  'Lan',
#  'Beta',
#  'Alia',
#  'Beta',
#  'Beta Technologies',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Fidelity Management',
#  'Amazon',
#  'Climate Change Fund',
#  'Blade',
#  'UPS',
#  'Beta',
#  'Beta',
#  'Ford',
#  'United Therapeutics',
#  "Beta Technologies'",
#  'Beta',
#  'Vermont Flight Academy',
#  'FLIGHT VT',
#  'The Flight Academy',
#  'BETA Technologies',
#  'Beta',
#  'Vermont Flight Academy',
#  'the Vermont Flight Academy',
#  'Flight VT',
#  'Airport',
#  'BETA',
#  'Spectrum Youth & Family Services',
#  'Sara Holbrook Community Center',
#  'King Street Center',
#  'Boys & Girls Club',
#  'Boys & Girls Club of Vergennes',
#  'Flight VT',
#  'FLIGHT VT',
#  'Spectrum',
#  'Redmond',
#  'FLIGHT VT',
#  'WCS',
#  'WCS',
#  'Observer',
#  'Beta Technologies',
#  'Williston Central School',
#  'Beta Technologies',
#  'Williston Central',
#  'Amazon',
#  'Fidelity',
#  'Wayman',
#  'Obama Administration',
#  'Wayman',
#  'Beta',
#  'Williston Central School',
#  'Wayman',
#  'WCS',
#  'Essex',
#  'Essex High School',
#  'Harvard',
#  'the Washington Capitals',
#  'NHL',
#  'Amazon',
#  'UPS',
#  'United Therapeutics',
#  'VTDigger',
#  'Beta',
#  'UPS',
#  'Amazon',
#  'UPS',
#  'Amazon',
#  'United Therapeutics',
#  "Beta Technologies'",
#  'Amazon',
#  'The Climate Pledge Fund',
#  'Amazon',
#  'Beta',
#  'CNBC',
#  'Amazon',
#  'Beta',
#  'United Parcel Service',
#  'UPS',
#  'Beta',
#  'Blade Air Mobility',
#  'the Air Force',
#  'United Therapeutics',
#  'Joby Aviation',
#  'Archer',
#  'SPAC',
#  'The Federal Aviation Administration',
#  'Beta',
#  'Beta Technologies',
#  "Beta Technologies'",
#  'Beta',
#  'Beta',
#  'Clark',
#  'Beta',
#  'Beta Technologies',
#  'Beta',
#  'Metallica',
#  'Alia',
#  'the U.S. Air Force',
#  'Alia',
#  'Beta',
#  'United Parcel Service',
#  'UPS',
#  'Beta',
#  'Blade',
#  'Beta',
#  'Beta',
#  'Beta',
#  'U.S. Securities and Exchange Commission',
#  'Beta',
#  'Harvard University',
#  'the Harvard Gazette',
#  'The Washington Capitals',
#  'Harvard',
#  'iTherm Technologies',
#  'Dynapower',
#  'Dynapower',
#  'Designbook',
#  'Venture.co',
#  'Designbook',
#  'Sirius Satellite Radio',
#  'United Therapeutics',
#  'the Terasem Movement',
#  'Terasem',
#  'Uber',
#  'United Therapeutics',
#  'United Therapeutics',
#  'Lung Biotechnology',
#  'EHang',
#  'Seven Days',
#  'United Therapeutics',
#  'Rothblatt',
#  'Beta',
#  'Stone Point',
#  'Boston Scientific',
#  'MicroStrain',
#  'Beta',
#  'Beta',
#  'Beta',
#  'U.S. Air Force',
#  'Beta',
#  'Ava',
#  'the Environmental Protection Agency',
#  'the Massachusetts Institute of Technology',
#  'Beta',
#  'Alia',
#  'Beta',
#  'Rolls-Royce',
#  'Safran',
#  'Alia',
#  'Ava',
#  'Alia',
#  'Alia',
#  'the Vertical Flight Society',
#  'Beta',
#  'Beta',
#  'the Federal Aviation Administration',
#  'Beta',
#  'FAA',
#  'Alia',
#  'FlightAware',
#  'Beta',
#  'the U.S. Air Force',
#  'Department of Defense',
#  'the Air Force',
#  'The Air Force',
#  'Beta',
#  'Alia',
#  "the Air Force's",
#  'Beta',
#  'Air Force',
#  'Beta',
#  'Teal Group',
#  'Eclipse Aviation',
#  'McKinsey & Company',
#  'McKinsey',
#  'Riedel',
#  'FAA',
#  'Seven Days',
#  'Beta',
#  'Beta',
#  'FAA',
#  'Beta',
#  'UPS',
#  'United Therapeutics',
#  'UPS',
#  'Rothblatt',
#  'Riedel',
#  'United Therapeutics',
#  'Rothblatt',
#  'FAA',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'FAA',
#  'Beta',
#  'the University of Vermont',
#  'Green Mountain Coffee Roasters',
#  'Tesla',
#  'Beta',
#  'Beta',
#  'Beta',
#  'BTV',
#  'Vermont Business Magazine',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Vermont Employment Growth Incentive',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Congress',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'BTV',
#  'BETA Technologies',
#  'the US Air Force’s',
#  'The U.S. Air Force',
#  'BETA',
#  'Air Force',
#  'AFWERX',
#  'the United States Air Force',
#  'Air Force',
#  'Agility Prime',
#  'BETA',
#  'AFRL',
#  'the US Air Force',
#  'the Air Force Research Laboratory',
#  'the Air Force’s',
#  'BETA',
#  'the Air Force',
#  'Air Force Agility Prime',
#  'the Air Force',
#  'ALIA',
#  'BETA',
#  'ALIA',
#  'FAA',
#  'BETA',
#  'ALIA',
#  'BETA',
#  'BETA',
#  'Armed Forces',
#  'BETA',
#  'BLADE',
#  'UPS',
#  'BETA Technologies',
#  'Joby Aviation',
#  'BETA',
#  'BETA',
#  'BETA',
#  'Logistics',
#  'Medical',
#  'Defense',
#  'Passenger',
#  'Blade',
#  'UAM',
#  'BETA',
#  'BETA',
#  'Blade',
#  'Blade',
#  'Blade',
#  'Blade',
#  'BETA',
#  'Blade Urban Air Mobility',
#  'BETA',
#  'ALIA',
#  'BETA',
#  'Blade',
#  'ALIA',
#  'Blade',
#  'BETA',
#  'BETA',
#  'United Therapeutics',
#  'BETA',
#  'UPS',
#  'BETA',
#  'UPS',
#  'BETA',
#  'The United States Air Force',
#  'BETA',
#  'USAF',
#  'ALIA',
#  'BETA',
#  'BETA',
#  'Blade',
#  'BETA',
#  'BETA',
#  'BETA',
#  'BETA',
#  'BETA',
#  'BETA',
#  'FAA',
#  'BETA',
#  'BETA',
#  'BETA',
#  'BETA',
#  'BETA',
#  'the Federal Aviation Administration',
#  'Boeing',
#  'Tesla',
#  'SpaceX',
#  'Lockheed Martin',
#  'General Electric',
#  'Blade',
#  'Experience Investment Corp.',
#  'NASDAQ',
#  'EXPC',
#  'Blade',
#  'Experience Investment Corp.',
#  'BETA Technologies',
#  'Beta Technologies’',
#  'UPS',
#  'UPS',
#  'UPS',
#  'UPS Flight Forward',
#  'Beta Technologies',
#  'BETA',
#  'UPS',
#  'BETA',
#  'UPS',
#  'UPS',
#  'UPS',
#  'UPS',
#  'BETA',
#  'BETA',
#  'UPS',
#  'UPS',
#  'BETA',
#  'BETA',
#  'UPS',
#  'UPS',
#  'Arrival',
#  'BETA',
#  'UPS Flight Forward',
#  'U.S. Federal Aviation Administration',
#  'FAA',
#  'FAA',
#  'UPS Flight Forward',
#  'BETA',
#  'FAA',
#  'BETA',
#  'BETA',
#  'UPS Brand Central',
#  'UPS',
#  'UPS',
#  'NYSE',
#  'UPS',
#  'UPS',
#  'UPS',
#  'Beta Technologies',
#  'Beta Technologies’',
#  'Beta',
#  'The Federal Aviation Administration',
#  'Beta',
#  'Beta',
#  'Alia',
#  'Alia',
#  'Alia',
#  'Beta',
#  'Beta',
#  'the General Aviation Manufacturer’s Association',
#  'GAMA',
#  'the Air Force',
#  'the Air Force’s',
#  'Beta',
#  'The General Aerospace Manufacturers Association',
#  'GAMA',
#  'Beta Technologies',
#  'Toyota Motor North America',
#  'Joby Aviation',
#  'Beta Technologies',
#  'GAMA',
#  'Airbus Corporate Jets',
#  'Hartzell Engine Technologies',
#  'Incora',
#  'GAMA',
#  'Hyundai',
#  'Wisk',
#  'GAMA',
#  'the U.S. Congress',
#  'GAMA',
#  'Propulsion and Innovation',
#  'Joby Aviation',
#  'MagniX',
#  'Eviation',
#  'GAMA',
#  'Vermont Business Magazine',
#  'Beta Technologies',
#  'Beta',
#  'VBM',
#  'Beta',
#  'US Air Force',
#  'Boeing',
#  'Airbus',
#  'Beta',
#  'Beta',
#  'Beta',
#  'BTV',
#  'United Therapeutics',
#  'UT',
#  'Organ Manufacturing Group',
#  'Harvard',
#  'Alia',
#  'UT',
#  'UT',
#  'Beta',
#  'the Air Force',
#  'Federal Aviation Administration',
#  'the Air Force',
#  'The Air Force',
#  'UT',
#  'VBM',
#  'UT',
#  'the American Transplant Foundation',
#  'the United Network for Organ Sharing',
#  'Beta',
#  'Uber',
#  'Uber Elevate',
#  'Elevate Network',
#  'Uber',
#  'Alia',
#  'VBM',
#  'NASA',
#  'FAA',
#  'Beta Technologies',
#  'Air Force',
#  'Sikorsky',
#  'Helicarrier',
#  'something',
#  'Helicarrier',
#  'Beta Technologies',
#  'Beta',
#  'United Therapeutics',
#  'Beta',
#  'Beta',
#  'Alia',
#  'Beta',
#  'Joby Aviation',
#  'the US Air Force',
#  'Beta',
#  'Ava',
#  'Alia',
#  'Beta',
#  'Beta Technologies',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Beta',
#  'Uber',
#  'Lyft',
#  'Beta',
#  'Horizon Air',
#  'Beta',
#  'Burlington',
#  'Dealer.com',
#  'Tesla Motors',
#  'Beta',
#  'Ping-Pong',
#  'Beta',
#  'Boeing',
#  'Airbus',
#  'NASA',
#  'Defense Advanced Research Projects Agency',
#  'Toyota',
#  'General Motors',
#  'Tesla',
#  'Beta',
#  'the Environmental Defense Fund',
#  'Bell',
#  'Harvard University',
#  'LORD Sensing-MicroStrain',
#  'LORD',
#  'MicroStrain',
#  'Beta',
#  'MicroStrain',
#  'Beta',
#  'Twitter',
#  'Mozilla',
#  'Los Alamos National Laboratory',
#  'Adib',
#  'Federal Aviation Administration',
#  'Adib',
#  'Arms',
#  'Arms',
#  "O'Leary",
#  'Beta Technologies',
#  'the Air Force Reserve',
#  'Uber',
#  'The Drive',
#  'United Therapeutics',
#  'SiriusXM',
#  'Harvard',
#  'Ava',
#  'Beta',
#  'GE Global Research',
#  'Scaled Composites',
#  'Tesla',
#  'Beta',
#  'Clark',
#  'Ava',
#  'Beta Technologies',
#  'Uber',
#  'United Therapeutics',
#  'Lancair',
#  'RDD Enterprises',
#  'Blue Force Technologies',
#  'Beta Technologies’',
#  'Federal Aviation Administration',
#  'Douglas',
#  'Harvard',
#  'the Washington Capitals',
#  'Beta Technologies',
#  'FAA',
#  'Ava',
#  'FAA',
#  'Beta Technologies',
#  'Beta Technologies',
#  'Ava',
#  'Beta Technologies',
#  'Ava',
#  'Bell-Boeing',
#  'Ava',
#  'Beta Technologies’',
#  'FAA',
#  'Ava',
#  'Beta Technologies',
#  'GE Global Research',
#  'Scaled Composites',
#  'Tesla',
#  'The Drive',
#  'Beta Technologies',
#  'the Federal Aviation Administration',
#  'FAA',
#  'Vertical Mag',
#  'United Therapeutics',
#  'SiriusXM',
#  'CleanTechnica',
#  'Beta Technologies',
#  'Beta Technologies',
#  'Enstrom',
#  'Beta Technologies',
#  'CleanTechnica',
#  'CleanTechnica',
#  'CleanTechnica',
#  'Patreon',
#  'Vermont Air National Guard',
#  'Beta Technologies',
#  'Beta',
#  'Transportation',
#  'Beta',
#  'Air Force',
#  'Beta Technologies',
#  'Beta',
#  'Ava',
#  'Harvard',
#  'Beta',
#  'Beta',
#  'Airbus',
#  'Joby',
#  'Bell',
#  'Beta Technologies',
#  'Lilium',
#  'Joby',
#  'Kitty Hawk',
#  'Uber',
#  'Airbus',
#  'Beta Technologies',
#  'Beta',
#  'Beta Technologies',
#  'Beta',
#  'United Therapeutics',
#  'Lancair',
#  'TexasUP.',
#  'Ava',
#  'Beta',
#  'Beta',
#  'Ford',
#  'Beta',
#  'the Federal Aviation Administration',
#  'Beta',
#  'ALIA',
#  'Beta',
#  'Beta',
#  'United Therapeutics',
#  'Beta',
#  'United Therapeutics',
#  'Beta']

# %%
from collections import Counter
all_orgs = c['ent_lists']["ORG"]
cat = "ORG"

def display_n(cat):
    print(f"Times {cat} are mentioned: {c['label_counts'][cat]}")

display_n(cat)
# print("Times organizations are mentioned:", len(all_orgs))
# Out:
# Times ORG are mentioned: 25

# %%
# Get the most common entities mentioned across all categories
from collections import Counter
top_entities = lambda counts, n: Counter(counts['entity_counts']).most_common(n)

ent_cs = top_entities(c, 10)
ent_cs
# Out:
# [('Kyle Clark', 22),
#  ('Beta Technologies', 18),
#  ('Beta', 17),
#  ('Vermont', 16),
#  ('first', 14),
#  ('Clark', 14),
#  ('United Therapeutics', 13),
#  ('Burlington', 13),
#  ('two', 12),
#  ('Alia', 11)]

# %%
def ent_bar_data(ent_counts: tuple):
    n = len(ent_counts)
    ent_texts = [ent_counts[i][0] for i in range(n)]
    ent_n = [ent_counts[i][1] for i in range(n)]
    return ent_texts, ent_n

# %% [markdown]
# ## Visualizations
# Below, we can find visualizations of entity counts for the dataset passed in the beginning of the notebook.

# %%
x, height = ent_bar_data(ent_cs)
plt.bar(x, height, width=.8)
plt.xticks(rotation = 60)
plt.ylabel("Counts across all Beta announcements")
plt.savefig("vis/base_most_common_entities.png", dpi = 600)
plt.show()

# %%
from spacy import displacy
displacy.render(b_docs[0], style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The U.S. Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is to support flight testing of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beta Technologies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alia 250
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  eVTOL aircraft to assess possible military applications. Under a contract announced
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , which does not mention specific financial backing for the program,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  engineers will participate in flight testing, “to evaluate mission applicability, including measures of range, altitude, endurance, and payload limits before testing specific cargo and logistics missions.”</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s flight-test program has also been supported by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the U.S. Air Force
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  issued military airworthiness approval for the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and provided funding under an earlier contract as part of its
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agility Prime
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  program. The company has conducted multiple flights between its headquarters at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Burlington International Airport
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vermont
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and nearby
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plattsburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The longest flight to date with the all-electric aircraft, which uses fixed-pitch propellers, was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     205 miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  and it has cruised at altitudes of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8,000 feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# .</br></br>“This partnership with the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  marks another important step in the military’s commitment to advancing and adopting sustainable electric aviation solutions,” said
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  founder and CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kyle Clark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . “We’re gratified by the continued support of the sector, and this allows us to accelerate our development of
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  as an incredibly safe and reliable logistics aircraft for both military and civil applications.”</br></br>The company’s board of directors includes
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Will Roper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the former
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0

# %%
c["ent_lists"]['EVENT']
# Out:
# ['the Reagan National Defense Forum', 'Vermont Tech Jam']

# %% [markdown]
# ## Using custom entities

# %%
trained_nlp = spacy.load("models/output/model-last")

# %%
@timer
def custom_process(corpus):
    return list(trained_nlp.pipe(corpus))

cb_titles = custom_process(titles)
cb_docs = custom_process(bodies)
# Out:
# 0.0196 s
# 0.6097 s

# %%
displacy.render(cb_docs[0], style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S. Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GOVERNMENT_AGENCY</span>
# </mark>
#  is to support flight testing of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beta Technologies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UAM_COMPANY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alia 250 eVTOL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UAM_PRODUCT</span>
# </mark>
#  aircraft to assess possible military applications. Under a contract announced today, which does not mention specific financial backing for the program, Army engineers will participate in flight testing, “to evaluate mission applicability, including measures of range, altitude, endurance, and payload limits before testing specific cargo and logistics missions.”</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UAM_COMPANY</span>
# </mark>
# ’s flight-test program has also been supported by the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S. Air Force
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GOVERNMENT_AGENCY</span>
# </mark>
# , which last year issued military airworthiness approval for the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UAM_PRODUCT</span>
# </mark>
#  and provided funding under an earlier contract as part of its Agility Prime program. The company has conducted multiple flights between its headquarters at
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Burlington International Airport
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INFRASTRUCTURE</span>
# </mark>
#  in Vermont and nearby Plattsburg in New York. The longest flight to date with the all-electric aircraft, which uses fixed-pitch propellers, was
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     205 miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT_FIGURE</span>
# </mark>
#  and it has cruised at altitudes of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8,000 feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT_FIGURE</span>
# </mark>
# .</br></br>“This partnership with the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GOVERNMENT_AGENCY</span>
# </mark>
#  marks another important step in the military’s commitment to advancing and adopting sustainable electric aviation solutions,” said
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UAM_COMPANY</span>
# </mark>
#  founder and CEO Kyle Clark. “We’re gratified by the continued support of the sector, and this allows us to accelerate our development of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UAM_PRODUCT</span>
# </mark>
#  as an incredibly safe and reliable logistics aircraft for both military and civil applications.”</br></br>The company’s board of directors includes Will Roper, the former U.S. assistant secretary of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Air Force
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GOVERNMENT_AGENCY</span>
# </mark>
#  for acquisition, technology, and logistics. He was instrumental in establishing the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agility Prime
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROGRAM</span>
# </mark>
#  program, which is seeking to support efforts to exploit the potential for eVTOL aircraft for use in military missions, mainly through small business technology transfer contracts.</br></br>During the Reagan National Defense Forum held on December 5, 2021, the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Air Force
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GOVERNMENT_AGENCY</span>
# </mark>
# 's chief of staff, General Charles Brown, praised the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Afwerx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROGRAM</span>
# </mark>
#  program for expediting the development of technology that could strengthen national defense. &quot;It has marked a real cultural shift [in how public and private sectors collaborate], so we work very closely together rather than just pushing [a product or technology] back and forth over a fence until it works,&quot; he commented.</br></br>In the commercial aviation market, several prospective customers have signed “rights to purchase” the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UAM_PRODUCT</span>
# </mark>
# , which is expected to complete
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FAA Part 23 type certification
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">REGULATION</span>
# </mark>
#  in
# <mark class="entity" style="backgro
