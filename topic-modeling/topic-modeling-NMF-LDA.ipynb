# %% [markdown]
# # Topic modeling of Portuguese-language news

# %% [markdown]
# # Problem Definition

# %% [markdown]
# We use data available through NewsAPI that the service associates with a few distinct keywords (e.g. "congress, politics, economy, sports"), and train a Latent Dirichlet Allocation model on 400 pulled articles, trying to identify the dominant topics in each of them.
#
# The work presented here was started as part of my Capstone Project proposal (Flora, 2021).

# %% [markdown]
# # Solution Specification

# %% [markdown]
# I decided to use NewsAPI's data because of their ease to obtain, and immediate connection with the topic at hand. The code below is responsible for pulling the data from the API, and storing it in a dataframe we can use later to train scikit-learn models.
#
# To my great fortune, NewsAPI accesses data in Portuguese, and so I specified news articles that approximated 4 sets of keywords: one for politics, one for economic news, one for news about the "president" (in addition to the common names of the three most recent presidents of Brazil), and one for sports.
#
# Pulling 400 articles from the API, I could put their contents (the body of the text alone) into a list and tokenize and lemmatize them with relative ease. The steps below

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import (
    NMF, 
    LatentDirichletAllocation,
    TruncatedSVD
)
import requests, gensim, spacy, json, nltk
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV
from nltk.tokenize import wordpunct_tokenize
from nltk.metrics import ConfusionMatrix
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.stem import PorterStemmer, WordNetLemmatizer
import matplotlib.pyplot as plt
from functools import reduce
from io import StringIO
from time import time
import pandas as pd
import numpy as np
import re
# Out:
# D:\tiago\Downloads\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# D:\tiago\Downloads\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\tiago\Downloads\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\tiago\Downloads\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\tiago\Downloads\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\tiago\Downloads\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\tiago\Downloads\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# !python3 -m spacy download pt_core_news_sm
import pt_core_news_sm
nlp = pt_core_news_sm.load()

# %% [markdown]
# # Load data

# %%
# Get stopwords for Porguese and add prominent missing stopword ("to be")
# Full list of stopwords printed in appendix
pt_stopwords = nltk.corpus.stopwords.words('portuguese')
en_stopwords = nltk.corpus.stopwords.words('english')
html_elements = ['li', 'ul']
pt_stopwords.append("ser")
nltk_stopwords = pt_stopwords + en_stopwords + html_elements

# %% [markdown]
# ## NewsAPI

# %%
# Define API key and URLs for requests
headers = {'Authorization': '843f966d9f6d465bba288803803ee132'}
everything_news_url = 'https://newsapi.org/v2/everything'
sources_url = 'https://newsapi.org/v2/sources'

# %%
# headlines_payload = {'category': 'general', 'country': 'br, pt', "pageSize":100}
everything_politics_payload = {'q': 'congresso, política', 'language': 'pt', 'sortBy': 'popularity',\
                               'from':'2021-03-25', "pageSize":100}
everything_president_payload = {'q': "presidente, Dilma, Temer, Bolsonaro", 'language': 'pt', 'sortBy': 'popularity',\
                               'from':'2021-03-25', "pageSize":100}
everything_economy_payload = {'q': "economia", 'language': 'pt', 'sortBy': 'popularity',\
                             'from':'2021-03-25', "pageSize":100}
everything_sports_payload = {'q': 'esporte', 'language': 'pt', 'sortBy': 'popularity',
                            'from':'2021-03-25', "pageSize":100}
sources_payload= {'category': 'general', 'language': 'pt'}
sports_sources_payload = {'category': 'sports', 'language': 'pt'}

# %%
resp_sources = requests.get(url = sources_url,\
                           headers = headers,\
                           params = sources_payload)
resp_sports_sources = requests.get(url = sources_url,\
                           headers = headers,\
                           params = sports_sources_payload)

# %%
response_politics = requests.get(url=everything_news_url,\
                                 headers=headers, params=everything_politics_payload)
response_president = requests.get(url=everything_news_url,\
                                  headers=headers, params=everything_president_payload)
response_economy = requests.get(url=everything_news_url,\
                                  headers=headers, params=everything_economy_payload)
response_sports = requests.get(url=everything_news_url,\
                                  headers=headers, params=everything_sports_payload)

# %%
dict_pol = json.loads(json.dumps(response_politics.json()))
dict_pres = json.loads(json.dumps(response_president.json()))
dict_econ = json.loads(json.dumps(response_economy.json()))
dict_sports = json.loads(json.dumps(response_sports.json()))

# %%
dict_sources = json.loads(json.dumps(resp_sources.json()))
dict_sports_sources = json.loads(json.dumps(resp_sports_sources.json()))

# %%
dicts = [dict_pol, dict_pres, dict_econ, dict_sports]

for d in dicts:
    for article in d['articles']:
        article['source_name'] = article['source']['name']

# %%
pol_articles = dict_pol['articles']
pres_articles = dict_pres['articles']
econ_articles = dict_econ['articles']
sports_articles = dict_sports['articles']

# %%
df_pol = pd.read_json(StringIO(json.dumps(pol_articles)))
df_pres = pd.read_json(StringIO(json.dumps(pres_articles)))
df_econ = pd.read_json(StringIO(json.dumps(econ_articles)))
df_sports = pd.read_json(StringIO(json.dumps(sports_articles)))

# %%
df_pol.columns.values.tolist()
# Out:
# ['source',
#  'author',
#  'title',
#  'description',
#  'url',
#  'urlToImage',
#  'publishedAt',
#  'content',
#  'source_name']

# %%
df_pol['category'] = 0
df_pres['category'] = 1
df_econ['category'] = 2
df_sports['category'] = 3

CAT_TO_VAL = {'politics':0,'president':1,'economy':2,'sports':3}

# %%
# Have an idea of the content in the data
df_pres['content']
# Out:
# 0     O Alto Comando das forças armadas\r\n manda um...
# 1     Foto: André Coelho/Bloomberg via Getty Images\...
# 2     Seis substituições de ministros na maior remod...
# 3     <ul><li>Mariana Alvim</li><li>Da BBC News Bras...
# 4     <ul><li>Thais Carrança</li><li>Da BBC News Bra...
#                             ...
# 95    O presidente do Brasil, Jair Bolsonaro, discur...
# 96    O procurador-geral da República Augusto Aras e...
# 97    RIO - Uma recusa oficial a rezar uma missa pel...
# 98    Um dia após ter conseguido na Justiça a amplia...
# 99    BRASÍLIA - O presidente Jair Bolsonaro poderá ...
# Name: content, Length: 100, dtype: object

# %%
dfs = [df_pol, df_econ, df_pres, df_sports]

df = pd.concat(dfs, axis=0)
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                                           source  \
# 0              {'id': None, 'name': 'B9.com.br'}
# 1        {'id': None, 'name': 'Tecmundo.com.br'}
# 2        {'id': None, 'name': 'Tecmundo.com.br'}
# 3    {'id': None, 'name': 'Catracalivre.com.br'}
# 4        {'id': None, 'name': 'Tecmundo.com.br'}
# ..                                           ...
# 395        {'id': None, 'name': 'Tecnoblog.net'}
# 396             {'id': None, 'name': 'BBC News'}
# 397           {'id': None, 'name': 'Uol.com.br'}
# 398         {'id': None, 'name': 'Terra.com.br'}
# 399         {'id': None, 'name': 'Terra.com.br'}
#
#                                author  \
# 0                       Pedro Strazza
# 1                       Nilton Kleina
# 2                       Nilton Kleina
# 3                             Redação
# 4                       Thiago Simões
# ..                                ...
# 395                 Victor Hugo Silva
# 396  https://www.facebook.com/bbcnews
# 397                               UOL
# 398                  Gazeta Esportiva
# 399                           Reuters
#
#                                                  title  \
# 0    Criaram uma planilha para acompanhar a gincana...
# 1    AppLock: bloqueie aplicativos no seu celular A...
# 2    EUA prometem cortar 50% das emissões de carbon...
# 3    Professor improvisa aula em caminhão e leva ed...
# 4    NEOGEO POCKET COLOR SELECTION Vol.1 peca pela ...
# ..                                                 ...
# 395  Receita quer imposto sobre livros, e isso deve...
# 396  Matt Gaetz: escândalo sexual ameaça um dos pri...
# 397  Advogado de Flávio Bolsonaro | CGU vê risco de...
# 398  Felipe Conceição comemora evolução do Cruzeiro...
# 399  Relator recomenda arquivamento de caso de Edua...
#
#                                            description  \
# 0    Explodiu nas redes sociais no fim da última qu...
# 1    Em certas ocasiões, o padrão de segurança conv...
# 2    O presidente dos Estados Unidos, Joe Biden, of...
# 3    Em meios aos desafios provocados pela pandemia...
# 4    O mercado de videogames resolveu reativar os j...
# ..                                                 ...
# 395  Para defender cobrança de imposto, Receita Fed...
# 396  Congressista republicano da Flórida pode ter t...
# 397  Uma auditoria da CGU (Controladoria Geral da U...
# 398  Depois da vitória por 2 a 0 contra o Coimbra n...
# 399  O relator do caso de Eduardo Bolsonaro (PSL-SP...
#
#                                                    url  \
# 0    https://www.b9.com.br/141227/criaram-uma-plani...
# 1    https://www.tecmundo.com.br/software/214261-ap...
# 2    https://www.tecmundo.com.br/ciencia/215998-eua...
# 3    https://catracalivre.com.br/cidadania/professo...
# 4    https://www.tecmundo.com.br/voxel/215351-neoge...
# ..                                                 ...
# 395  https://tecnoblog.net/429453/receita-quer-impo...
# 396  https://www.bbc.com/portuguese/internacional-5...
# 397  https://noticias.uol.com.br/politica/ultimas-n...
# 398  https://www.terra.com.br/esportes/cruzeiro/fel...
# 399  https://www.terra.com.br/noticias/brasil/relat...
#
#                                             urlToImage           publishedAt  \
# 0    https://assets.b9.com.br/wp-content/uploads/20...  2021-03-26T14:14:50Z
# 1    https://img.ibxk.com.br/2021/03/21/21182129600...  2021-03-27T11:00:01Z
# 2    https://img.ibxk.com.br/2021/04/22/22091604149...  2021-04-22T13:00:02Z
# 3    https://catracalivre.com.br/wp-content/uploads...  2021-03-29T15:34:28Z
# 4    https://img.ibxk.com.br/2021/04/01/01142116271...  2021-04-11T22:00:01Z
# ..                                                 ...                   ...
# 395  https://tecnoblog.net/wp-content/uploads/2019/...  2021-04-07T22:16:38Z
# 396  https://ichef.bbci.co.uk/news/1024/branded_por...  2021-04-06T11:51:00Z
# 397  https://conteudo.imguol.com.br/c/noticias/f3/2...  2021-04-10T21:52:03Z
# 398  https://p2.trrsf.com/image/fget/cf/1200/628/mi...  2021-04-07T23:17:35Z
# 399  https://p2.trrsf.com/image/fget/cf/1200/628/mi...  2021-04-05T20:05:51Z
#
#                                                content          source_name  \
# 0    Explodiu nas redes sociais no fim da última qu...            B9.com.br
# 1    Em certas ocasiões, o padrão de segurança conv...      Tecmundo.com.br
# 2    O presidente dos Estados Unidos, Joe Biden, of...      Tecmundo.com.br
# 3    Últimas notícias:\r\nUtilizamos cookies essenc...  Catracalivre.com.br
# 4    O mercado de videogames resolveu reativar os j...      Tecmundo.com.br
# ..                                                 ...                  ...
# 395  A Receita Federal voltou a defender a cobrança...        Tecnoblog.net
# 396  <ul><li>Anthony Zurcher - @awzurcheron</li><li...             BBC News
# 397  Uma auditoria da CGU (Controladoria Geral da U...           Uol.com.br
# 398  Depois da vitória por 2 a 0 contra o Coimbra n...         Terra.com.br
# 399  O relator do caso de Eduardo Bolsonaro (PSL-SP...         Terra.com.br
#
#      category
# 0           2
# 1           2
# 2           2
# 3           0
# 4           3
# ..        ...
# 395         2
# 396         0
# 397         1
# 398         3
# 399         0
#
# [400 rows x 10 columns]

# %%
X = df['content']
# Not immediately useful for unsupervised learning, but for planned
# supervised-learning extensions
y = df['category']

# %%
df.to_csv('news_api.csv')

# %%
# Remove escaped characters and single quotes
data = X.values.tolist()
data = [re.sub(r'\s+', ' ', t) for t in data]
data = [re.sub(r"\'", "", t) for t in data]

# %%
# First 3 data points
data[:3]
# Out:
# ['Explodiu nas redes sociais no fim da última quinta-feira (25) uma gincana de calouros da Fundação Getúlio Vargas (FGV) que envolveu todo tipo de celebridade após o que aparentemente foi um erro geral… [+2925 chars]',
#  'Em certas ocasiões, o padrão de segurança convencional do seu celular Android pode não ser o suficiente e o usuário pode querer uma camada adicional de proteção que vai além de senha, PIN, biometria … [+3355 chars]',
#  'O presidente dos Estados Unidos, Joe Biden, oficializou nesta quinta-feira (22) uma nova e ousada meta do país para reduzir os impactos das mudanças climáticas. Em comunicado, Biden confirmou que o p… [+992 chars]']

# %% [markdown]
# ## Data preparation steps
#
# The code below is heavily based on the work of Chen (2018).
#
# We first clean the data by removing unimportant characters and single quotes from the articles. Stopwords are passed as arguments to the models later, but removing them could also be a part of this step.
#
# After cleaning the data to have just relevant words and no additional characters like punctuation marks in the data, we tokenize it, as seen below. The data is tokenized by breaking each article into smaller pieces, in this case words. (Chen, 2018).

# %%
def text_to_words(article):
    for sentence in article:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

data = list(text_to_words(data))
print(data[:1])
words = data
# Out:
# [['explodiu', 'nas', 'redes', 'sociais', 'no', 'fim', 'da', 'ultima', 'quinta', 'feira', 'uma', 'gincana', 'de', 'calouros', 'da', 'fundacao', 'getulio', 'vargas', 'fgv', 'que', 'envolveu', 'todo', 'tipo', 'de', 'celebridade', 'apos', 'que', 'aparentemente', 'foi', 'um', 'erro', 'geral', 'chars']]

# %% [markdown]
# We proceed by stemming, or lemmatizing, the data. This process requires language-specific data that allows us to remove redundancy from our data, with words that share meaning and spelling. We use the `spacy` package to do so, since it has good support for lemmatization in Portuguese, while NLTK and other packages do not.

# %%
def lemmatization(data, allowed_postags = ['NOUN', 'ADJ', 'VERB', 'ADV']): #'NOUN', 'ADJ', 'VERB', 'ADV'
    data_lemmatized = []
    for sent in data:
        doc = nlp(" ".join(sent)) 
        data_lemmatized.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return data_lemmatized

# %%
# Initialize spacy 'pt' model
nlp = spacy.load("pt_core_news_sm", disable=['parser', 'ner'])

# Perform lemmatization keeping nouns, adjectives, verbs, and adverbs
data_lemmatized = lemmatization(words, allowed_postags=['NOUN', 'VERB']) #select noun and verb
print(data_lemmatized[:3])
# Out:
# ['explodir rede fim ultimar feirar gincana calouro fundacao envolver tipo celebridade apo errar chars', 'ocasioes padrao seguranca celular android poder poder querer camada protecao alar senha biometria', 'presidente estar unir oficializar feirar ousar meter pai reduzir impacto mudancas comunicar confirmar chars']

# %% [markdown]
# ### Vectorization
#
# The first use of Scikit-Learn here is to build a document-word matrix using CountVectorizer. We pass the stopwords we generated before using a mix of Portuguese and English stopwords. All words that have more than 10 occurrences are considered in the vectorizer.

# %%
# Use sklearn's CountVectorizer to vectorize the lemmatized data
vectorizer = CountVectorizer(analyzer='word',       
                             min_df=10,
                             stop_words = nltk_stopwords,
                             lowercase=True,
                             token_pattern='[a-zA-Z0-9]{3,}')

data_vectorized = vectorizer.fit_transform(data_lemmatized)
# Out:
# D:\tiago\Downloads\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['amos', 'est', 'estiv', 'houv', 'nhamos', 'ramos', 'ssemos', 'tamb', 'ter', 'tiv', 'vamos', 'voc'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %% [markdown]
# ### Train LDA model
#
# We proceed to use the vectorized data to train both a Non-negative Matrix Factorization model and a Latent Dirichlet Allocation model using the news data we obtained. While I will not use the NMF model further, it could be used for an extension of the current analysis, allowing us to extract insights from language data by getting some of the most explanatory features in high-dimensional data.
#
# I performed grid search on the parameters of the LDA model, varying the number of components (topics) that the model would extract, and its learning rate.

# %%
# Train an NMF model for comparison with LDA
nmf_model = NMF(n_components = 20, random_state = 2021,
              alpha=.1, l1_ratio=.5)

nmf_output = nmf_model.fit_transform(data_vectorized)
# Out:
# D:\tiago\Downloads\Anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1077: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   " improve convergence." % max_iter, ConvergenceWarning)

# %%
print("Reconstruction error ", nmf_model.reconstruction_err_)
# Out:
# Reconstruction error  26.409832884164427

# %%
search_params = {'n_components': [10, 15, 20, 25, 30], 'learning_decay': [.5, .75, .95]}

lda = LatentDirichletAllocation(max_iter = 10,random_state = 2021)

model = GridSearchCV(lda, param_grid=search_params)

# Perform grid search on the possible LDA models

model.fit(data_vectorized)

GridSearchCV(cv=None, error_score='raise',
       estimator=LatentDirichletAllocation(batch_size=128,
             evaluate_every=-1),
       param_grid={'n_topics': [5, 10, 15, 20], 'learning_decay': [0.5, 0.7, 0.9]},
       pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
       scoring=None, verbose=0)
# Out:
# GridSearchCV(error_score='raise', estimator=LatentDirichletAllocation(),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_topics': [5, 10, 15, 20]},
#              return_train_score='warn')

# %% [markdown]
# # Testing and Analysis
#
# The best log-likelihood score obtained on the LDA models searched above is in the range of -2000, much better than a default model (log-likelihood around -8000). With the number of components the best model used, we can identify both the most prominent topics (10), and the top words associated with each of them.

# %%
# Best model
best_lda_model = model.best_estimator_
print("Best model parameters: ", model.best_params_)
print("Best log-likelihood score: ", model.best_score_)
# Out:
# Best model parameters:  {'learning_decay': 0.5, 'n_components': 10}
# Best log-likelihood score:  -2138.068831754471

# %%
lda_output = best_lda_model.transform(data_vectorized)

topic_names = ["Topic " + str(i) for i in range(best_lda_model.n_components)]
article_names = ["Article " + str(i) for i in range(len(data))]

# Put matrix in a dataframe with the appropriate labels
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns = topic_names, index = article_names)

# Extract the dominant topic for each document and put it in a column
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic["dominant_topic"] = dominant_topic
df_document_topic
# Out:
#              Topic 0  Topic 1  Topic 2  Topic 3  Topic 4  Topic 5  Topic 6  \
# Article 0       0.02     0.02     0.02     0.54     0.02     0.02     0.02
# Article 1       0.42     0.02     0.02     0.22     0.02     0.02     0.02
# Article 2       0.02     0.02     0.02     0.02     0.02     0.02     0.02
# Article 3       0.01     0.01     0.01     0.01     0.91     0.01     0.01
# Article 4       0.37     0.37     0.03     0.03     0.03     0.03     0.03
# ...              ...      ...      ...      ...      ...      ...      ...
# Article 395     0.52     0.03     0.03     0.03     0.27     0.03     0.03
# Article 396     0.01     0.01     0.01     0.01     0.01     0.91     0.01
# Article 397     0.52     0.03     0.03     0.27     0.03     0.03     0.03
# Article 398     0.03     0.03     0.37     0.03     0.03     0.03     0.37
# Article 399     0.82     0.02     0.02     0.02     0.02     0.02     0.02
#
#              Topic 7  Topic 8  Topic 9  dominant_topic
# Article 0       0.02     0.02     0.30               3
# Article 1       0.22     0.02     0.02               0
# Article 2       0.02     0.85     0.02               8
# Article 3       0.01     0.01     0.01               4
# Article 4       0.03     0.03     0.03               0
# ...              ...      ...      ...             ...
# Article 395     0.03     0.03     0.03               0
# Article 396     0.01     0.01     0.01               5
# Article 397     0.03     0.03     0.03               0
# Article 398     0.03     0.03     0.03               2
# Article 399     0.02     0.02     0.02               0
#
# [400 rows x 11 columns]

# %% [markdown]
# The table above gives us the probability that each article in our dataset belongs to each of 10 topics. The topics with the highest probabilities are called the dominant topics, and we can extract the words most strongly associated with each topic from the model as well, as shown below.

# %%
df_topic_keywords = pd.DataFrame(best_lda_model.components_)

df_topic_keywords.columns = vectorizer.get_feature_names()
df_topic_keywords.index = topic_names
df_topic_keywords.head()
# Out:
#            acordar  agenciar        ano   anunciar        apo  apresentar  \
# Topic 0   0.100007  2.099941  36.922568   0.100004   0.100013    0.100004
# Topic 1   0.100000  2.100080   0.100006   0.100004   1.468048   14.099966
# Topic 2   0.100007  0.100008   0.100009   0.100010   0.100002    0.100007
# Topic 3   0.100006  0.100004   0.100006  34.099957  20.053013    0.100001
# Topic 4  24.099949  0.100000   0.100007   0.100007   0.100000    0.100000
#
#             armar  aumentar       bbc    brasil  ...  superliga   supremo  \
# Topic 0  0.100000  0.100002  0.100000  0.100006  ...   0.100001  0.100001
# Topic 1  0.100019  0.100002  0.100001  1.654864  ...   0.100004  0.100005
# Topic 2  0.100001  0.100000  0.100001  0.100042  ...   0.100039  0.100000
# Topic 3  0.100001  3.100004  0.100000  0.100008  ...  14.099938  0.100002
# Topic 4  0.100000  0.100000  0.100000  3.742706  ...   0.100001  0.100002
#
#          tecnologia     temer       ter      terca      tres   utilizar  \
# Topic 0    0.100005  0.100003  0.100012   0.100002  4.046660   0.100007
# Topic 1    0.100000  2.100020  0.119536   0.100008  0.100000   0.100000
# Topic 2    0.100005  0.100006  0.100009  14.099950  0.100000   0.100000
# Topic 3    0.100000  0.100000  0.100009   0.100002  0.100004   0.100004
# Topic 4   13.099983  0.100000  0.100002   0.100002  0.100000  13.100127
#
#               voce     voltar
# Topic 0   0.100006  11.099996
# Topic 1   0.100000   0.100019
# Topic 2   0.100006   2.099935
# Topic 3   0.100004   0.100011
# Topic 4  11.784818   0.100002
#
# [5 rows x 82 columns]

# %% [markdown]
# Finally, we can see the top words associated with each topic by sorting them according to their weight in determining each topic. This also gives us, the researchers, a good idea of how to label each topic if so was necessary.

# %%
def show_topics(vectorizer=vectorizer, lda_model = best_lda_model, n_words = 10):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

topic_keywords = show_topics(vectorizer=vectorizer, lda_model = best_lda_model)

df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#              Word 0      Word 1    Word 2      Word 3     Word 4      Word 5  \
# Topic 0       chars         ano     poder    empresar       sera      voltar
# Topic 1      marcar  apresentar  portugal    publicar   governar  presidente
# Topic 2     futebol       mundo    feirar      partir      chars     esporte
# Topic 3    anunciar       chars       apo  presidente      clube   superliga
# Topic 4     acordar       chars  utilizar  tecnologia  continuar   politicar
# Topic 5         ler        foto  creditar    legendar        bbc       paulo
# Topic 6   ministrar       dizer     chars      silvar     forcar       armar
# Topic 7  presidente       chars      jair    governar    supremo         lei
# Topic 8       chars  presidente       dar         pai      estar      brasil
# Topic 9       chars         ter  pandemia    governar      crise       covid
#
#             Word 6     Word 7     Word 8      Word 9
# Topic 0      criar        dar   publicar      feirar
# Topic 1   economia     feirar   agenciar       temer
# Topic 2      terca     semana      clube        sera
# Topic 3  exercitar     querer     feirar       fazer
# Topic 4       voce  concordar  condicoes      passar
# Topic 5      chars   brasilia   agenciar  presidente
# Topic 6     defeso   fernando        dia        tres
# Topic 7        stf  seguranca     feirar         dia
# Topic 8    iniciar      pedir      estao    rousseff
# Topic 9     chegar   economia     semana      partir

# %% [markdown]
# From the table above, we can see that there are well defined topics around:
# - The Brazilian president's handling of the covid-19 pandemic
# - The budget that is going through congress in Brazil at the moment
# - The European football super-league, which was canceled earlier this week.
#
# These results show how we can use LDA models to extract topics and have insights into what receives the most coverage in newspapers. A planned extension to this work will use the domain from which the news come as a source of information, as I try to grapple with source bias in my analysis.

# %% [markdown]
# # References

# %% [markdown]
# Chen, Y. (2018). How to generate an LDA topic model for text analysis. Retrieved from https://medium.com/@yanlinc/how-to-build-a-lda-topic-model-using-from-text-601cdcbfd3a6.
#
# Flora, T. (2021). Exploratory analysis of sentiment and bias in Portuguese-language news. Retrieved from https://gist.github.com/TiagoFlora/f532bd2aeaa35fe4a6ef82106d352bf2.
#
# Grisel, O., Buitinck, L., Yau, C.K. (n.d.). Retrieved from https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html

# %% [markdown]
# # Appendix
# ## Stopwords

# %%
print(nltk_stopwords)
# Out:
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'estivermos', 'estiverem', 'hei', 'há', 'havemos', 'hão', 'houve', 'houvemos', 'houveram', 'houvera', 'houvéramos', 'haja', 'hajamos', 'hajam', 'houvesse', 'houvéssemos', 'houvessem', 'houver', 'houvermos', 'houverem', 'houverei', 'houverá', 'houveremos', 'houverão', 'houveria', 'houveríamos', 'houveriam', 'sou', 'somos', 'são', 'era', 'éramos', 'eram', 'fui', 'foi', 'fomos', 'foram', 'fora', 'fôramos', 'seja', 'sejamos', 'sejam', 'fosse', 'fôssemos', 'fossem', 'for', 'formos', 'forem', 'serei', 'será', 'seremos', 'serão', 'seria', 'seríamos', 'seriam', 'tenho', 'tem', 'temos', 'tém', 'tinha', 'tínhamos', 'tinham', 'tive', 'teve', 'tivemos', 'tiveram', 'tivera', 'tivéramos', 'tenha', 'tenhamos', 'tenham', 'tivesse', 'tivéssemos', 'tivessem', 'tiver', 'tivermos', 'tiverem', 'terei', 'terá', 'teremos', 'terão', 'teria', 'teríamos', 'teriam', 'ser', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'li', 'ul']

# %% [markdown]
# ## Example of data object used

# %%
pretty_json_output = json.dumps(response_politics.json(), indent=4)
print(pretty_json_output)
# Out:
# {
#     "status": "ok",
#     "totalResults": 1410,
#     "articles": [
#         {
#             "source": {
#                 "id": null,
#                 "name": "The Intercept"
#             },
#             "author": "Lucas Rezende",
#             "title": "Militares ficar\u00e3o abra\u00e7ados a Bolsonaro at\u00e9 o fim do governo",
#             "description": "Mesmo que surjam novos atritos, generais est\u00e3o de cabe\u00e7a na miss\u00e3o. Conhe\u00e7a 4 cen\u00e1rios para o futuro \u2013 nenhum \u00e9 bom para a democracia.\nThe post Militares ficar\u00e3o abra\u00e7ados a Bolsonaro at\u00e9 o fim do governo appeared first on The Intercept.",
#             "url": "https://theintercept.com/2021/04/13/militares-ficarao-abracados-a-bolsonaro-ate-o-fim-do-governo/",
#             "urlToImage": "https://theintercept.com/wp-uploads/sites/1/2021/04/vozes-milbols.jpg",
#             "publishedAt": "2021-04-13T17:00:55Z",
#             "content": "Foto: Andr\u00e9 Coelho/Bloomberg via Getty Images\r\nA demiss\u00e3o do ministro da Defesa,\r\n general Fernando Azevedo e Silva, e dos dos tr\u00eas comandantes das For\u00e7as Armadas brasileiras a dois dias do anivers\u00e1r\u2026 [+14139 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Uol.com.br"
#             },
#             "author": "Dharna Noor",
#             "title": "Greta Thunberg para EUA: parem de dar dinheiro para combust\u00edveis f\u00f3sseis",
#             "description": "Thunberg fez seus coment\u00e1rios em uma audi\u00eancia virtual realizada pelo subcomit\u00ea ambiental do Comit\u00ea de Supervis\u00e3o da C\u00e2mara dos EUA.\nThe post Greta Thunberg para EUA: parem de dar dinheiro para combust\u00edveis f\u00f3sseis appeared first on Gizmodo Brasil.",
#             "url": "https://gizmodo.uol.com.br/greta-thunberg-pede-eua-parem-financiar-combustiveis-fosseis/",
#             "urlToImage": "https://gizmodo.uol.com.br/wp-content/blogs.dir/8/files/2021/04/tcr25xfspzlqebotbai8-1-1000x561.jpg",
#             "publishedAt": "2021-04-23T17:40:19Z",
#             "content": "Entre a libera\u00e7\u00e3o de novos compromissos clim\u00e1ticos no \u00e2mbito do Acordo de Paris e a organiza\u00e7\u00e3o de uma c\u00fapula internacional do Dia da Terra, est\u00e1 claro que o presidente norte-americano Joe Biden dese\u2026 [+6381 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "The Intercept"
#             },
#             "author": "Tatiana Dias",
#             "title": "Vacina da covid-19: guerra das patentes vai escancarar se Congresso apoia voc\u00ea ou a ind\u00fastria farmac\u00eautica",
#             "description": "Projetos de lei podem facilitar o acesso a vacinas e medicamentos para a covid-19. Mas, para isso, deputados e senadores ter\u00e3o que peitar empresariado.\nThe post Vacina da covid-19: guerra das patentes vai escancarar se Congresso apoia voc\u00ea ou a ind\u00fastria farm\u2026",
#             "url": "https://theintercept.com/2021/04/07/patentes-vacina-covid-19-congresso-farmaceutica/",
#             "urlToImage": "https://theintercept.com/wp-uploads/sites/1/2021/04/redes-pfizer.jpg",
#             "publishedAt": "2021-04-07T20:09:17Z",
#             "content": "Na C\u00e2mara, o PL 1.462/2020, que prop\u00f5e a suspens\u00e3o tempor\u00e1ria de patentes para vacinas, medicamentos, equipamentos de prote\u00e7\u00e3o individual, os EPIs, e qualquer outro insumo utilizado no combate e no t\u2026 [+8605 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "The Intercept"
#             },
#             "author": "Lee Fang",
#             "title": "Farmac\u00eauticas prometem a investidores subir pre\u00e7os da vacina contra covid-19",
#             "description": "Pfizer, Moderna e Johnson & Johnson se comprometeram a oferecer vacinas acess\u00edveis, mas apenas enquanto durar a pandemia.\nThe post Farmac\u00eauticas prometem a investidores subir pre\u00e7os da vacina contra covid-19 appeared first on The Intercept.",
#             "url": "https://theintercept.com/2021/04/02/farmaceuticas-prometem-subir-precos-vacinas-covid-19/",
#             "urlToImage": "https://theintercept.com/wp-uploads/sites/1/2021/03/redes-pfizer.jpg",
#             "publishedAt": "2021-04-02T05:02:22Z",
#             "content": "Essa situa\u00e7\u00e3o, eles esperam, deve mudar quando a pandemia acabar: uma data que os pr\u00f3prios fabricantes se reservam o direito de definir. Representantes das farmac\u00eauticas, durante falas em recentes co\u2026 [+10524 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "The Intercept"
#             },
#             "author": "Lee Fang",
#             "title": "Press\u00e3o sobre Biden contra vacinas gen\u00e9ricas de covid-19 para outros pa\u00edses vem at\u00e9 de ex-governador democrata",
#             "description": "Howard Dean, ex-governador democrata no estado de Vermont, se junta \u00e0 ind\u00fastria farmac\u00eautica para lutar contra o compartilhamento de propriedade intelectual para vacinas de baixo custo.\nThe post Press\u00e3o sobre Biden contra vacinas gen\u00e9ricas de covid-19 para ou\u2026",
#             "url": "https://theintercept.com/2021/04/16/pressao-biden-contra-vacinas-genericas-covid-19/",
#             "urlToImage": "https://theintercept.com/wp-uploads/sites/1/2021/04/redes-HowardDean.jpg",
#             "publishedAt": "2021-04-16T11:00:47Z",
#             "content": "HOWARD DEAN\r\n, grande ex-defensor de pautas progressistas, est\u00e1 tentando convencer o presidente Joe Biden a rejeitar uma ren\u00fancia de propriedade intelectual especial que permitiria a produ\u00e7\u00e3o de vaci\u2026 [+6537 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Tecnoblog.net"
#             },
#             "author": "Emerson Alecrim",
#             "title": "Como o open banking vai turbinar sua rela\u00e7\u00e3o com o dinheiro",
#             "description": "Open banking promete trazer mais concorr\u00eancia, menos burocracia e novos servi\u00e7os ao sistema banc\u00e1rio brasileiro\nComo o open banking vai turbinar sua rela\u00e7\u00e3o com o dinheiro",
#             "url": "https://tecnoblog.net/425423/open-banking-brasil-vai-turbinar-sua-relacao-com-dinheiro/",
#             "urlToImage": "https://tecnoblog.net/wp-content/uploads/2021/03/capa-especial-open-banking.png",
#             "publishedAt": "2021-03-26T22:30:22Z",
#             "content": "Em 2020, o Pix trouxe uma moderniza\u00e7\u00e3o importante para o sistema financeiro do Brasil. Mas nada promete ser t\u00e3o transformador quanto o open banking: o conceito estabelece que cidad\u00e3os e organiza\u00e7\u00f5es \u2026 [+13082 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Publico.pt"
#             },
#             "author": "publico@publico.pt",
#             "title": "Mafalda Pratas Fernandes. Porque est\u00e1 t\u00e3o polarizada a pol\u00edtica nos EUA?",
#             "description": "O podcast 45 Graus \u00e9 um dos parceiros da Rede P\u00daBLICO.",
#             "url": "https://www.publico.pt/2021/03/25/mundo/noticia/mafalda-pratas-fernandes-tao-polarizada-politica-eua-1955837",
#             "urlToImage": "https://imagens.publico.pt/imagens.aspx/1566990?tp=UH&db=IMAGENS&type=JPG&share=1&o=BarraFacebook_Podcasts.png",
#             "publishedAt": "2021-03-25T08:14:00Z",
#             "content": "Esta semana, no podcast 45 Graus, a convidada \u00e9 Mafalda Pratas Fernandes, que nasceu em Minneapolis (EUA), cresceu em Lisboa, e regressou \u00e0 Am\u00e9rica em 2012, onde se licenciou em Economia e Ci\u00eancia Po\u2026 [+3313 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Publico.pt"
#             },
#             "author": "joao.ruela@publico.pt",
#             "title": "Michael Bustamante: \u201cTrump empenhou-se em derrubar o Governo cubano\u201d",
#             "description": "O 8.\u00ba Congresso do Partido Comunista de Cuba, que esta sexta-feira come\u00e7ou em Havana, vai marcar o fim dos Castro na lideran\u00e7a, o historiador do Cuban Research Institute analisa os desafios enfrentados pela nova gera\u00e7\u00e3o que vai ascender ao poder.",
#             "url": "https://www.publico.pt/2021/04/17/mundo/noticia/michael-bustamante-trump-empenhouse-derrubar-governo-cubano-1958832",
#             "urlToImage": "https://imagens.publico.pt/imagens.aspx/1574880?tp=UH&db=IMAGENS&type=JPG&x=681&y=486&share=1&o=BarraFacebook_Publico.png",
#             "publishedAt": "2021-04-17T06:30:00Z",
#             "content": "Michael Bustamante, professor de Hist\u00f3ria da Am\u00e9rica Latina na Florida International University (EUA), investigador do Cuban\u00a0Research Institute, \u00e9 um ardente defensor do fim do embargo econ\u00f3mico dos \u2026 [+384 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Publico.pt"
#             },
#             "author": "sergio.anibal@publico.pt",
#             "title": "Biden aumenta impostos e lan\u00e7a mais dois bili\u00f5es para reformular a economia",
#             "description": "Proposta da Casa Branca refor\u00e7a investimento p\u00fablico em infraestruturas, ambiente e cuidados a idosos, aumentando impostos sobre as empresas. Aprova\u00e7\u00e3o no Congresso enfrenta obst\u00e1culos",
#             "url": "https://www.publico.pt/2021/03/31/economia/noticia/biden-aumenta-impostos-lanca-dois-bilioes-reformular-economia-1956761",
#             "urlToImage": "https://imagens.publico.pt/imagens.aspx/1569374?tp=UH&db=IMAGENS&type=JPG&share=1&o=BarraFacebook_Publico.png",
#             "publishedAt": "2021-03-31T20:36:18Z",
#             "content": "Poucas semanas passaram desde que os 1,9 bili\u00f5es de d\u00f3lares (1,6 bili\u00f5es de euros) do pacote de emerg\u00eancia contra a crise come\u00e7aram a chegar \u00e0 economia dos EUA e aos bolsos dos americanos, mas Joe Bi\u2026 [+3808 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Publico.pt"
#             },
#             "author": "joao.ruela@publico.pt",
#             "title": "Biden prepara-se para ser o primeiro Presidente dos EUA a reconhecer o genoc\u00eddio arm\u00e9nio",
#             "description": "A declara\u00e7\u00e3o dever\u00e1 ser realizada no s\u00e1bado, quando se assinala o anivers\u00e1rio do in\u00edcio do massacre de 1,5 milh\u00f5es de arm\u00e9nios pelo Imp\u00e9rio Otomano. Biden j\u00e1 tinha prometido faz\u00ea-lo durante a campanha eleitoral.",
#             "url": "https://www.publico.pt/2021/04/22/mundo/noticia/biden-preparase-presidente-eua-reconhecer-genocidio-armenio-1959581",
#             "urlToImage": "https://imagens.publico.pt/imagens.aspx/1576684?tp=UH&db=IMAGENS&type=JPG&share=1&o=BarraFacebook_Publico.png",
#             "publishedAt": "2021-04-22T10:19:14Z",
#             "content": "O massacre de 1,5 milh\u00f5es de arm\u00e9nios durante a I Guerra Mundial pelo Imp\u00e9rio Otomano est\u00e1 prestes a ser reconhecido como um genoc\u00eddio pelo Presidente dos EUA, Joe Biden, de acordo com v\u00e1rias fontes \u2026 [+3078 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Publico.pt"
#             },
#             "author": "publico@publico.pt",
#             "title": "Taiwan denuncia maior incurs\u00e3o de sempre da avia\u00e7\u00e3o chinesa",
#             "description": "Governo da ilha diz que 20 aeronaves entraram no seu espa\u00e7o a\u00e9reo. Estados Unidos temem que a China esteja a ponderar assumir o controlo do Estado que considera ser parte do seu territ\u00f3rio.",
#             "url": "https://www.publico.pt/2021/03/27/mundo/noticia/taiwan-denuncia-maior-incursao-ja-registada-aviacao-chinesa-1956228",
#             "urlToImage": "https://imagens.publico.pt/imagens.aspx/1568148?tp=UH&db=IMAGENS&type=JPG&share=1&o=BarraFacebook_Publico.png",
#             "publishedAt": "2021-03-27T20:12:04Z",
#             "content": "Vinte avi\u00f5es militares chineses entraram na zona de defesa \u00e1rea de Taiwan, na maior incurs\u00e3o registada desde que o Minist\u00e9rio da Defesa de Taip\u00e9 come\u00e7ou a divulgar os voos de Pequim sobre as \u00e1guas en\u2026 [+2933 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Itamaraty 'menor' e isolamento do Brasil: o legado de Ernesto Ara\u00fajo na pol\u00edtica externa do pa\u00eds",
#             "description": "Ernesto Ara\u00fajo pediu demiss\u00e3o nesta segunda ap\u00f3s forte press\u00e3o do Congresso para sua sa\u00edda, em meio aos atrasos do Brasil na compra de vacinas; analistas apontam os efeitos de sua gest\u00e3o na diplomacia brasileira.",
#             "url": "https://www.bbc.com/portuguese/internacional-56570803",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/5BD1/production/_117750532_50996219113_c210c874d6_k.jpg",
#             "publishedAt": "2021-03-29T22:37:30Z",
#             "content": "<ul><li>Let\u00edcia Mori e Paula Adamo Idoeta</li><li>BBC News Brasil em S\u00e3o Paulo</li></ul>\r\nCr\u00e9dito, Minist\u00e9rio das Rela\u00e7\u00f5es Exteriores\r\nLegenda da foto, Ara\u00fajo fazia parte da ala mais ideol\u00f3gica do go\u2026 [+12499 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Por que o Congresso quer demiss\u00e3o de Ernesto Ara\u00fajo?",
#             "description": "Identificado como um dos respons\u00e1veis pela escassez de vacinas contra a covid-19 no Brasil, chanceler \u00e9 visto por base aliada como empecilho para governo Bolsonaro superar crise.",
#             "url": "https://www.bbc.com/portuguese/brasil-56532188",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/0B90/production/_107706920_cf6b2ece-4bb0-4ac9-a022-806f7e0ef58b.jpg",
#             "publishedAt": "2021-03-25T22:38:04Z",
#             "content": "<ul><li>Mariana Sanches - @mariana_sanches</li><li>Da BBC News Brasil em Washington</li></ul>\r\nCr\u00e9dito, Ricardo Moraes/Reuters\r\nLegenda da foto, Na avalia\u00e7\u00e3o de um senador que conversou com a reporta\u2026 [+9526 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Por que pol\u00edtica ambiental de Bolsonaro afasta ajuda financeira internacional?",
#             "description": "Brasil pedir\u00e1 dinheiro para preserva\u00e7\u00e3o em C\u00fapula do Clima, mas pa\u00edses ricos querem queda do desmatamento antes de abrir a carteira.",
#             "url": "https://www.bbc.com/portuguese/brasil-56825520",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/1551A/production/_118122378_tv066589358.jpg",
#             "publishedAt": "2021-04-21T07:34:36Z",
#             "content": "<ul><li>Mariana Schreiber - @marischreiber</li><li>Da BBC News Brasil em Bras\u00edlia</li></ul>\r\nPressionado globalmente a reduzir o desmatamento da Amaz\u00f4nia, o presidente Jair Bolsonaro adotou uma estra\u2026 [+10064 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "CPI da Covid: as consequ\u00eancias de uma comiss\u00e3o com 18 homens e nenhuma mulher",
#             "description": "Blocos partid\u00e1rios indicaram apenas nomes de senadores homens para a CPI que vai investigar a resposta do governo \u00e0 pandemia e que promete ser a principal vitrine pol\u00edtica nos pr\u00f3ximos meses.",
#             "url": "https://www.bbc.com/portuguese/brasil-56761034",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/617D/production/_117375942_tv066033085.jpg",
#             "publishedAt": "2021-04-16T09:45:32Z",
#             "content": "<ul><li>La\u00eds Alegretti - @laisalegretti</li><li>Da BBC News Brasil em Londres</li></ul>\r\nCr\u00e9dito, REUTERS/Adriano Machado\r\nLegenda da foto, Falta de mulheres na CPI da Covid \u00e9 marcante mesmo se compa\u2026 [+7898 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Militares foram 's\u00e1bios' ao escolher Constitui\u00e7\u00e3o em vez de Bolsonaro, diz Financial Times",
#             "description": "Em editorial, jornal brit\u00e2nico elogia postura do comando das For\u00e7as Armadas, que na semana passada teria deixado um governo Bolsonaro 'err\u00e1tico e imprevis\u00edvel', 'sabiamente' escolhendo 'jurar fidelidade \u00e0 Constitui\u00e7\u00e3o do Brasil\u2019.",
#             "url": "https://www.bbc.com/portuguese/internacional-56640395",
#             "urlToImage": "https://news.files.bbci.co.uk/include/articles/public/portuguese/images/metadata/poster-1024x576.png",
#             "publishedAt": "2021-04-05T12:38:48Z",
#             "content": "Cr\u00e9dito, Reuters\r\nLegenda da foto, Em foto de 2018, Bolsonaro em cerim\u00f4nia de gradua\u00e7\u00e3o das Agulhas Negras; epis\u00f3dio da semana passada indicou cis\u00e3o do presidente om a c\u00fapula militar\r\nA sa\u00edda do coma\u2026 [+6880 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "As 6 mudan\u00e7as anunciadas pelo governo Bolsonaro em dia de 'dan\u00e7a das cadeiras' nos minist\u00e9rios",
#             "description": "Ao todo, foram mudados os comandos de seis pastas, mas enquanto alguns ministros permaneceram no Planalto, outros est\u00e3o deixando o governo, e novos chegam para compor o primeiro escal\u00e3o de Jair Bolsonaro.",
#             "url": "https://www.bbc.com/portuguese/brasil-56572044",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/144B5/production/_117752138_ee9f6f82-248f-4878-9c9c-23d48789d045.jpg",
#             "publishedAt": "2021-03-29T22:45:14Z",
#             "content": "Cr\u00e9dito, Getty Images\r\nLegenda da foto, Sa\u00edda de Fernando Azevedo foi a primeira anunciada no dia\r\nO governo federal anunciou na segunda-feira (29/3) a troca de comando de seis minist\u00e9rios. As mudan\u00e7\u2026 [+3055 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Bolsonaro luta para n\u00e3o ser culpado por 'neglig\u00eancia criminosa', diz especialista em ditaduras latinas",
#             "description": "Diretor do Projeto de Documenta\u00e7\u00e3o Brasileiro do Arquivo de Seguran\u00e7a Nacional Americano, em Washington, Peter Kornbluh v\u00ea tentativa de se fortalecer em ato do presidente.",
#             "url": "https://www.bbc.com/portuguese/brasil-56585195",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/65C4/production/_116625062_gettyimages-1229365587.jpg",
#             "publishedAt": "2021-03-31T08:47:02Z",
#             "content": "<ul><li>Mariana Sanches - @mariana_sanches</li><li>Da BBC News Brasil em Washington</li></ul>\r\nCr\u00e9dito, AFP/Getty Images\r\nLegenda da foto, Mudan\u00e7as nas For\u00e7as Armadas acontecem um dia antes do aniver\u2026 [+6072 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "C\u00fapula do clima: EUA surpreendem com metas de cortes de emiss\u00e3o ambiciosas",
#             "description": "A Casa Branca confirma que os EUA ter\u00e3o como objetivo reduzir as emiss\u00f5es de carbono em 50-52%, no dia em que l\u00edderes mundiais se re\u00fanem para uma c\u00fapula virtual.",
#             "url": "https://www.bbc.com/portuguese/internacional-56843301",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/0EC8/production/_118148730_gettyimages-1230701818.jpg",
#             "publishedAt": "2021-04-22T13:17:30Z",
#             "content": "Cr\u00e9dito, Robert Alexander\r\nLegenda da foto, A Casa Branca confirma que os EUA ter\u00e3o como objetivo reduzir as emiss\u00f5es de carbono em 50-52%, no dia em que l\u00edderes mundiais se re\u00fanem para uma c\u00fapula vi\u2026 [+6657 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "C\u00fapula do Clima: apesar de Bolsonaro falar em 'fortalecimento da fiscaliza\u00e7\u00e3o', nova norma dificulta aplica\u00e7\u00e3o de multas ambientais",
#             "description": "'N\u00e3o adianta dobrar or\u00e7amento se fiscais n\u00e3o t\u00eam condi\u00e7\u00f5es de trabalhar', diz ex-presidente do Ibama.",
#             "url": "https://www.bbc.com/portuguese/brasil-56853879",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/D24C/production/_118163835_3b9c17cf-b7bd-4ab1-80c6-f3fb3e9c741a.jpg",
#             "publishedAt": "2021-04-22T21:58:30Z",
#             "content": "<ul><li>Camilla Veras Mota - @cavmota*</li><li>Da BBC Brasil em S\u00e3o Paulo</li></ul>\r\nCr\u00e9dito, Marcelo Camargo/Ag\u00eancia Brasil\r\nLegenda da foto, Instru\u00e7\u00e3o Normativa assinada no in\u00edcio do m\u00eas por Salles\u2026 [+4917 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Demiss\u00e3o de Ernesto Ara\u00fajo: fim de uma gest\u00e3o sem precedentes na diplomacia brasileira",
#             "description": "A gest\u00e3o de Ara\u00fajo foi marcada n\u00e3o s\u00f3 por um distanciamento em rela\u00e7\u00e3o a posi\u00e7\u00f5es hist\u00f3ricas do pa\u00eds no xadrez global, mas tamb\u00e9m por uma redefini\u00e7\u00e3o sobre quais atores internacionais seriam considerados aliados priorit\u00e1rios.",
#             "url": "https://www.bbc.com/portuguese/brasil-56570801",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/6D7F/production/_107913082_48181692471_415cb37a3a_k.jpg",
#             "publishedAt": "2021-03-29T22:01:16Z",
#             "content": "<ul><li>Mariana Schreiber - @marischreiber</li><li>Da BBC News Brasil em Bras\u00edlia</li></ul>\r\nCr\u00e9dito, Raylson Ribeiro/MRE\r\nLegenda da foto, Ernesto Ara\u00fajo fazia parte do setor mais ideol\u00f3gico do gove\u2026 [+11986 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "EUA querem se engajar com Brasil e acordo sobre clima \u00e9 poss\u00edvel, diz Ian Bremmer",
#             "description": "Presidente de uma das consultorias mais ouvidas do mundo, Bremmer afirmou que o Brasil vem pagando um pre\u00e7o alt\u00edssimo pela politiza\u00e7\u00e3o da pandemia por parte do governo de Jair Bolsonaro.",
#             "url": "https://www.bbc.com/portuguese/brasil-56822910",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/CB4B/production/_118134025_eac9387c-7b05-4c54-93de-6c01390294dd.jpg",
#             "publishedAt": "2021-04-20T17:36:59Z",
#             "content": "<ul><li>Caio Quero</li><li>Da BBC News Brasil em S\u00e3o Paulo</li></ul>\r\nCr\u00e9dito, Reuters\r\nLegenda da foto, Para consultor Ian Bremmer, c\u00fapula organizada por Joe Biden (acima) pode resultar em acordo em\u2026 [+15737 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Mergulhado no 'discurso da estupidez', Brasil est\u00e1 se acostumando \u00e0 multiplica\u00e7\u00e3o das mortes, diz psicanalista",
#             "description": "Para Mauro Mendes, a estupidez tem caracterizado um posicionamento de algumas pessoas diante da vida no mundo contempor\u00e2neo.",
#             "url": "https://www.bbc.com/portuguese/brasil-56680189",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/9831/production/_113916983_100mil.png",
#             "publishedAt": "2021-04-17T13:54:25Z",
#             "content": "<ul><li>Amanda MontAlv\u00e3o Veloso</li><li>De S\u00e3o Paulo para a BBC News Brasil</li></ul>\r\nCr\u00e9dito, REUTERS/Adriano Machado\r\nLegenda da foto, Homenagem em Bras\u00edlia em frente a proje\u00e7\u00e3o sobre as mais de 1\u2026 [+13213 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Golpe de 1964: novo ministro da Defesa fala em celebrar anivers\u00e1rio 'no contexto hist\u00f3rico' - mas qual \u00e9 este contexto?",
#             "description": "Entenda, a partir de documentos, relat\u00f3rios, entrevistas e reportagens de \u00e9poca, o contexto em que se inseriu o in\u00edcio da ditadura militar no Brasil",
#             "url": "https://www.bbc.com/portuguese/brasil-56591969",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/6FAF/production/_104719582_desfilemilitar7setembro1972.jpg",
#             "publishedAt": "2021-03-31T12:52:37Z",
#             "content": "<ul><li>Matheus Magenta</li><li>BBC News Brasil en Londres</li></ul>\r\nCr\u00e9dito, Acervo Arquivo Nacional\r\nLegenda da foto, Os anos ap\u00f3s o AI-5 foram os mais violentos da ditadura militar; foto mostra d\u2026 [+11513 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Vacina contra a Covid-19: Pr\u00f3-ivermectina, empres\u00e1rio que produz Sputnik V no Brasil critica Anvisa e diz que Bolsonaro n\u00e3o nega ci\u00eancia",
#             "description": "Ex-candidato, Fernando Marques diz que quer quebrar \u2018monop\u00f3lio\u2019 da Fiocruz e do Butantan, mas esbarra em 'interesses pol\u00edticos e econ\u00f4micos'; Anvisa diz que n\u00e3o recebeu informa\u00e7\u00f5es b\u00e1sicas para an\u00e1lise",
#             "url": "https://www.bbc.com/portuguese/brasil-56530574",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/A3C1/production/_117712914_19dad636-0646-4090-8a2c-c941fbbfd794.jpg",
#             "publishedAt": "2021-03-26T08:54:00Z",
#             "content": "<ul><li>Rafael Barifouse</li><li>Da BBC News Brasil em S\u00e3o Paulo</li></ul>\r\nCr\u00e9dito, Reuters\r\nLegenda da foto, Enquanto empres\u00e1rio acusa ag\u00eancia de ver 'pelo em ovo', Anvisa diz que ainda faltam dado\u2026 [+13559 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Interfer\u00eancia na PF, pandemia, 'passar a boiada': o que fez governo Bolsonaro em um ano desde reuni\u00e3o ministerial",
#             "description": "A reuni\u00e3o ministerial que Sergio Moro dizia ser prova de interfer\u00eancia do presidente na Pol\u00edcia Federal completa um ano em abril. A BBC News fez um balan\u00e7o dos acontecimentos em \u00e1reas citadas pelo governo no encontro e mostra no que deram as falas e projetos \u2026",
#             "url": "https://www.bbc.com/portuguese/brasil-56821979",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/14181/production/_112250328_reuniao-22abr-marcoscorrea-pr-1.jpg",
#             "publishedAt": "2021-04-20T20:00:45Z",
#             "content": "<ul><li>Let\u00edcia Mori @leticiamori_</li><li>BBC News, Sao Paulo</li></ul>\r\nCr\u00e9dito, Marcos Corr\u00eaa / PR \r\nLegenda da foto, Em imagens da reuni\u00e3o, o ent\u00e3o ministro Sergio Moro aparece com o semblante ca\u2026 [+12565 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Bolsonaro se rendeu \u00e0s press\u00f5es do mercado e decepcionou policiais, diz presidente da Fenapef",
#             "description": "'O presidente da Rep\u00fablica, num dado momento, se rendeu \u00e0 press\u00e3o do Minist\u00e9rio da Economia', diz Lu\u00eds Ant\u00f4nio Boudens, presidente da Fenapef.",
#             "url": "https://www.bbc.com/portuguese/brasil-56597434",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/E839/production/_117794495_boudens.jpg",
#             "publishedAt": "2021-04-01T15:40:19Z",
#             "content": "<ul><li>Felipe Corazza e Leandro Machado</li><li>De BBC News Brasil em S\u00e3o Paulo</li></ul>\r\nCr\u00e9dito, Divulga\u00e7\u00e3o Fenapef\r\nLegenda da foto, Lu\u00eds Ant\u00f4nio Boudens, presidente da Federa\u00e7\u00e3o Nacional dos Po\u2026 [+12967 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Equador e Peru: o que esperar das elei\u00e7\u00f5es de domingo em dois pa\u00edses devastados pela pandemia",
#             "description": "As cenas dram\u00e1ticas de pessoas morrendo nas ruas da equatoriana Guayaquil e as intermin\u00e1veis filas para a compra de tubos de oxig\u00eanio no mercado paralelo na capital peruana, Lima, em 2020, ainda est\u00e3o na mem\u00f3ria do eleitorado.",
#             "url": "https://www.bbc.com/portuguese/internacional-56686836",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/78DB/production/_117893903_gettyimages-1019876476.jpg",
#             "publishedAt": "2021-04-10T18:05:06Z",
#             "content": "<ul><li>Marcia Carmo</li><li>De Buenos Aires para a BBC News Brasil</li></ul>\r\nCr\u00e9dito, Getty Images\r\nLegenda da foto, Neste 11 de abril, Peru e Equador v\u00e3o \u00e0s urnas escolher o presidente em primeiro\u2026 [+9768 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Aux\u00edlio emergencial: Com benef\u00edcio reduzido em 2021, Brasil ter\u00e1 61 milh\u00f5es na pobreza",
#             "description": "Pesquisa in\u00e9dita mostra ainda que 19,3 milh\u00f5es de brasileiros viver\u00e3o na extrema pobreza, com aux\u00edlio reduzido. Aumento da mis\u00e9ria \u00e9 sinal de insufici\u00eancia da nova ajuda emergencial, dizem pesquisadoras.",
#             "url": "https://www.bbc.com/portuguese/brasil-56843399",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/31BF/production/_118153721_3favela..jpg",
#             "publishedAt": "2021-04-22T08:46:42Z",
#             "content": "<ul><li>Thais Carran\u00e7a</li><li>Da BBC News Brasil em S\u00e3o Paulo</li></ul>\r\nCr\u00e9dito, Arnaldo Carvalho/Getty Images\r\nLegenda da foto, Mulheres e a popula\u00e7\u00e3o negra s\u00e3o mais afetadas pela piora das condi\u00e7\u2026 [+11342 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Covid: 6 perguntas que CPI deve responder sobre conduta do governo Bolsonaro na pandemia",
#             "description": "A BBC News Brasil ouviu especialistas em sa\u00fade, direito, gest\u00e3o p\u00fablica e economia para apontar as principais perguntas que devem ser avaliadas pela CPI da Covid, que se prop\u00f5e a apurar as 'a\u00e7\u00f5es e omiss\u00f5es' do governo federal no combate \u00e0 pandemia.",
#             "url": "https://www.bbc.com/portuguese/brasil-56746026",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/339F/production/_118051231_gettyimages-1228550428.jpg",
#             "publishedAt": "2021-04-15T17:37:52Z",
#             "content": "<ul><li>La\u00eds Alegretti - @laisalegretti</li><li>Da BBC News Brasil em Londres</li></ul>\r\nCr\u00e9dito, Getty Images\r\nLegenda da foto, Especialistas em diferentes \u00e1reas apontam perguntas que devem ser resp\u2026 [+17442 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Abril.com.br"
#             },
#             "author": "Edoardo Ghirotto",
#             "title": "Congresso inova, para pior, o processo or\u00e7ament\u00e1rio",
#             "description": "As distor\u00e7\u00f5es do Or\u00e7amento aprovado s\u00e3o de tal gravidade que o conserto pode exigir in\u00e9dito veto presidencial, permitindo que se recomece tudo do zero",
#             "url": "https://veja.abril.com.br/blog/mailson-da-nobrega/congresso-inova-para-pior-o-processo-orcamentario/",
#             "urlToImage": "https://veja.abril.com.br/wp-content/uploads/2021/03/50998164612_8c79a1b69b_o-1.jpg.jpg?quality=70&strip=info&w=680&h=453&crop=1",
#             "publishedAt": "2021-03-28T17:26:33Z",
#             "content": "A irresponsabilidade do Congresso na aprova\u00e7\u00e3o do Or\u00e7amento para 2021 atingiu o impens\u00e1vel. Houve barbaridades t\u00e9cnicas e contabilidade criativa. Esse comportamento dos parlamentares come\u00e7ou no Or\u00e7am\u2026 [+2873 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Abril.com.br"
#             },
#             "author": "robsonbonin",
#             "title": "Elei\u00e7\u00e3o de 2022 ser\u00e1 plebiscito sobre tr\u00e1gica obra de Bolsonaro, diz Dino",
#             "description": "Para o governador do Maranh\u00e3o, a uni\u00e3o de for\u00e7as da sociedade contra a pol\u00edtica destrutiva do Planalto durar\u00e1 at\u00e9 a elei\u00e7\u00e3o",
#             "url": "https://veja.abril.com.br/blog/radar/eleicao-de-2022-sera-plebiscito-sobre-tragica-obra-de-bolsonaro-diz-dino/",
#             "urlToImage": "https://veja.abril.com.br/wp-content/uploads/2020/10/Bolsonaro-nova-1.jpg?quality=70&strip=info&w=680&h=453&crop=1",
#             "publishedAt": "2021-03-26T12:30:16Z",
#             "content": "Um dos principais articuladores da frente de partidos de centro e de esquerda que passou a conversar para atuar contra Jair Bolsonaro, o governador do Maranh\u00e3o, Fl\u00e1vio Dino, avalia que o presidente c\u2026 [+960 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Abril.com.br"
#             },
#             "author": "Guga Noblat",
#             "title": "Or\u00e7amento desgasta Paulo Guedes (Por Jo\u00e3o Bosco Rabello)",
#             "description": "Papel central no impasse",
#             "url": "https://veja.abril.com.br/blog/noblat/orcamento-desgasta-paulo-guedes-por-joao-bosco-rabello/",
#             "urlToImage": "https://veja.abril.com.br/wp-content/uploads/2021/03/46758131384_88ff0c546c_o.jpg.jpg?quality=70&strip=info&w=680&h=453&crop=1",
#             "publishedAt": "2021-04-06T14:00:02Z",
#             "content": "A semana come\u00e7a com o or\u00e7amento aprovado pelo Congresso como o principal elemento de obstru\u00e7\u00e3o na pauta pol\u00edtica. O ministro da Economia, Paulo Guedes, n\u00e3o ficou bem no epis\u00f3dio.\r\nO ministro fez coro\u2026 [+3952 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Abril.com.br"
#             },
#             "author": "Eduardo Gon\u00e7alves",
#             "title": "Quem \u00e9 Fl\u00e1via Arruda, a deputada do Centr\u00e3o que ganhou o cofre das emendas",
#             "description": "Respons\u00e1vel pela articula\u00e7\u00e3o pol\u00edtica, a nova ministra da Secretaria de Governo \u00e9 do PL de Valdemar Costa Neto e \u00e9 descrita como conciliadora e competente",
#             "url": "https://veja.abril.com.br/blog/maquiavel/quem-e-flavia-arruda-a-deputada-do-centrao-que-ganhou-o-cofre-das-emendas/",
#             "urlToImage": "https://veja.abril.com.br/wp-content/uploads/2021/02/Flavia-Arruda.jpg?quality=70&strip=info&w=680&h=453&crop=1",
#             "publishedAt": "2021-03-31T13:18:18Z",
#             "content": "Rec\u00e9m-empossada como nova ministra-chefe da Secretaria de Governo, a deputada federal Fl\u00e1via Arruda (PL-DF) ganhou promeni\u00eancia na articula\u00e7\u00e3o pol\u00edtica ao conseguir aprovar o Or\u00e7amento de 2021 na \u00falt\u2026 [+2904 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Abril.com.br"
#             },
#             "author": "Julia Braun",
#             "title": "Gest\u00e3o de Ara\u00fajo deixa danos \u00e0 reputa\u00e7\u00e3o do Brasil, dizem ex-diplomatas",
#             "description": "Especialistas argumentam que diplomacia brasileira precisa de grande revis\u00e3o, mas n\u00e3o est\u00e3o otimistas de que isso acontecer\u00e1 em um futuro pr\u00f3ximo",
#             "url": "https://veja.abril.com.br/mundo/gestao-de-araujo-deixa-danos-na-reputacao-do-brasil-dizem-ex-diplomatas/",
#             "urlToImage": "https://veja.abril.com.br/wp-content/uploads/2021/02/EDUARDO-BOLSONARO-ERNESTO-ARAUJO-CASA-BRANCA-EUA-2019-11-35.jpg.jpg?quality=70&strip=info&w=680&h=453&crop=1",
#             "publishedAt": "2021-03-29T18:32:45Z",
#             "content": "Diplomatas e ex-membros do Itamaraty concordam que ser\u00e1 necess\u00e1rio um grande esfor\u00e7o de reconstru\u00e7\u00e3o da pol\u00edtica externa e da reputa\u00e7\u00e3o brasileira no exterior para reparar os danos deixados pelo chan\u2026 [+2811 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Abril.com.br"
#             },
#             "author": "Da Reda\u00e7\u00e3o",
#             "title": "Bolsonaro: Barroso n\u00e3o tem coragem moral e faz politicalha com a esquerda",
#             "description": "Em conversa com apoiadores, presidente diz que ministro do STF que mandou abrir a CPI da Pandemia j\u00e1 defendeu terrorista e agora quer desgastar o governo",
#             "url": "https://veja.abril.com.br/politica/bolsonaro-barroso-nao-tem-coragem-moral-e-faz-politicalha-com-a-esquerda/",
#             "urlToImage": "https://veja.abril.com.br/wp-content/uploads/2021/04/Bolsonaro-Barroso-3.jpg?quality=70&strip=info&w=680&h=453&crop=1",
#             "publishedAt": "2021-04-09T13:12:25Z",
#             "content": "O presidente Jair Bolsonaro, em conversa com apoiadores em frente ao Pal\u00e1cio da Alvorada, na manh\u00e3 desta sexta-feira, 9, atacou duramente o ministro Lu\u00eds Roberto Barroso, do Supremo Tribunal Federal,\u2026 [+3050 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Abril.com.br"
#             },
#             "author": "Larissa Quintino",
#             "title": "Mudan\u00e7a na LDO \u00e9 sancionada e programa de redu\u00e7\u00e3o de sal\u00e1rio depende de MP",
#             "description": "Presidente Jair Bolsonaro tem at\u00e9 esta quinta-feira para sancionar o or\u00e7amento de 2021",
#             "url": "https://veja.abril.com.br/economia/mudanca-na-ldo-e-sancionada-e-programa-de-reducao-de-salario-depende-de-mp/",
#             "urlToImage": "https://veja.abril.com.br/wp-content/uploads/2017/12/economia-emprego-clt-carteira-de-trabalho-20171219-0007.jpg?quality=70&strip=info&w=680&h=453&crop=1",
#             "publishedAt": "2021-04-22T14:05:29Z",
#             "content": "O presidente Jair Bolsonaro sancionou a altera\u00e7\u00e3o na Lei de Diretrizes Or\u00e7ament\u00e1rias de 2021 que permite a abertura de cr\u00e9dito extraordin\u00e1rio destinado a programas emergenciais, como o BEm, que autor\u2026 [+4101 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Matt Gaetz: esc\u00e2ndalo sexual amea\u00e7a um dos principais herdeiros pol\u00edticos de Donald Trump",
#             "description": "Congressista republicano da Fl\u00f3rida pode ter tido rela\u00e7\u00f5es sexuais com uma garota de 17 anos. Desde revela\u00e7\u00e3o, investiga\u00e7\u00e3o se transformou em hist\u00f3ria que envolve \"sugar daddies\", extors\u00e3o, fraude e tr\u00e1fico sexual",
#             "url": "https://www.bbc.com/portuguese/internacional-56648505",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/1148A/production/_117849707_gettyimages-1210610071.jpg",
#             "publishedAt": "2021-04-06T11:51:00Z",
#             "content": "<ul><li>Anthony Zurcher - @awzurcheron</li><li>Rep\u00f3rter da BBC para a Am\u00e9rica do Norte</li></ul>\r\nCr\u00e9dito, Getty Images\r\nLegenda da foto, Investiga\u00e7\u00e3o se transformou em uma hist\u00f3ria complexa que envo\u2026 [+10727 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Fernando Azevedo deixa o Minist\u00e9rio da Defesa",
#             "description": "Sa\u00edda n\u00e3o era esperada; expectativa \u00e9 que Ernesto Ara\u00fajo tamb\u00e9m oficialize sa\u00edda do governo Bolsonaro hoje.",
#             "url": "https://www.bbc.com/portuguese/brasil-56571741",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/82EB/production/_117751533_69fc3ba2-5bc2-472d-bf93-6b6190298d95.jpg",
#             "publishedAt": "2021-03-29T19:27:44Z",
#             "content": "<ul><li>Mariana Schreiber</li><li>Da BBC News Brasil em Bras\u00edlia</li></ul>\r\n29 mar\u00e7o 2021, 16:10 -03\r\nCr\u00e9dito, Getty Images\r\nLegenda da foto, A sa\u00edda de Azevedo do governo n\u00e3o era esperada\r\nO ministr\u2026 [+2668 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Ministros do STF ficam 'surpresos' com demiss\u00f5es e avaliam que Bolsonaro tentou 'politizar' For\u00e7as Armadas",
#             "description": "Fernando Azevedo Silva teria deixado o comando da Defesa por se recusar a 'politizar as For\u00e7as Armadas', segundo relato de ministros do Supremo.",
#             "url": "https://www.bbc.com/portuguese/brasil-56582275",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/BF96/production/_117764094_78862e3d-3644-40eb-b83d-133f62ea9c60.jpg",
#             "publishedAt": "2021-03-30T19:04:02Z",
#             "content": "<ul><li>Nathalia Passarinho - @npassarinho</li><li>Da BBC News Brasil em Londres</li></ul>\r\nCr\u00e9dito, EPA/Joedson Alves\r\nLegenda da foto, Fernando Azevedo Silva teria deixado o comando da Defesa por s\u2026 [+5085 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "'N\u00e3o queremos o presidente de joelhos', diz K\u00e1tia Abreu ap\u00f3s press\u00e3o do Senado pela sa\u00edda de Ernesto Ara\u00fajo",
#             "description": "Senadora K\u00e1tia Abreu falou com a BBC News Brasil ap\u00f3s se envolver em pol\u00eamica com Ernesto Ara\u00fajo, que deve pedir demiss\u00e3o do Minist\u00e9rio das Rela\u00e7\u00f5es Exteriores nesta segunda-feira.",
#             "url": "https://www.bbc.com/portuguese/brasil-56570773",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/7AEC/production/_117286413_1-katia.jpg",
#             "publishedAt": "2021-03-29T19:26:33Z",
#             "content": "<ul><li>Nathalia Passarinho</li><li>Da BBC News Brasil em Londres</li></ul>\r\nCr\u00e9dito, Leopoldo Silva/Ag\u00eancia Senado\r\nLegenda da foto, Senadora K\u00e1tia Abreu chamou o agora ex-chanceler Ernesto Ara\u00fajo d\u2026 [+13680 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "Teto de gastos na berlinda: por que economistas chamam or\u00e7amento para 2021 de 'pe\u00e7a de fic\u00e7\u00e3o'",
#             "description": "Relator subestimou despesas obrigat\u00f3rias como gasto com aposentadorias; consertar o problema pode paralisar a administra\u00e7\u00e3o federal.",
#             "url": "https://www.bbc.com/portuguese/brasil-56574795",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/A055/production/_117754014_9964938f-021b-42c3-86f4-a8abf0004f22.jpg",
#             "publishedAt": "2021-03-30T08:40:06Z",
#             "content": "<ul><li>Thais Carran\u00e7a</li><li>De S\u00e3o Paulo para a BBC News Brasil</li></ul>\r\nCr\u00e9dito, Reuters\r\nLegenda da foto, Previs\u00e3o de gastos do governo foi aprovada pelo Congresso na semana passada, com tr\u00eas \u2026 [+10158 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "\u00daltimos presidentes que entraram em conflito com as For\u00e7as Armadas foram depostos, diz historiadora",
#             "description": "Demiss\u00f5es do ministro da Defesa e do comando das For\u00e7as Armadas escancararam crise entre Jair Bolsonaro e militares, que tentam barrar sua politiza\u00e7\u00e3o pelo governo e n\u00e3o d\u00e3o sinais de disposi\u00e7\u00e3o para interven\u00e7\u00e3o, avalia Heloisa Starling, da UFMG.",
#             "url": "https://www.bbc.com/portuguese/brasil-56597234",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/1692B/production/_117795429_f56c115b-a6db-414d-832d-060bb38b0ec8.jpg",
#             "publishedAt": "2021-04-03T10:43:52Z",
#             "content": "<ul><li>Rafael Barifouse</li><li>Da BBC News Brasil em S\u00e3o Paulo</li></ul>\r\nCr\u00e9dito, Reuters\r\nLegenda da foto, Bolsonaro enfrenta uma crise militar e pol\u00edtica em seu governo\r\nOs \u00faltimos presidentes c\u2026 [+6209 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "https://www.facebook.com/bbcnews",
#             "title": "'A boiada passou e corre o risco de passar de novo': as preocupa\u00e7\u00f5es de ambientalistas um ano ap\u00f3s reuni\u00e3o ministerial de Bolsonaro",
#             "description": "Um ano depois de reuni\u00e3o em que falou sobre 'ir passando a boiada', Salles est\u00e1 novamente sob holofotes durante C\u00fapula do Clima \u2014 e Brasil chama aten\u00e7\u00e3o internacional por problemas ambientais enfrentados desde desde ent\u00e3o",
#             "url": "https://www.bbc.com/portuguese/brasil-56831720",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_portuguese/15BD5/production/_118154098_gettyimages-1228578266.jpg",
#             "publishedAt": "2021-04-22T16:38:02Z",
# ...
#                 "name": "Terra.com.br"
#             },
#             "author": "Reuters",
#             "title": "Bolsonaro classifica aumento do g\u00e1s como \"inadmiss\u00edvel\"",
#             "description": "O presidente Jair Bolsonaro afirmou nesta quarta-feira que o aumento do pre\u00e7o do g\u00e1s anunciado ...",
#             "url": "https://www.terra.com.br/economia/bolsonaro-classifica-aumento-do-gas-como-inadmissivel,6cd107908a89efad42deef7819201febd5x63meu.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/images.terra.com/2021/04/07/2021-04-07T190016Z_1_LYNXMPEH361IO_RTROPTP_4_POLITICA-BOLSONARO-AUMENTOGAS.JPG",
#             "publishedAt": "2021-04-07T19:07:23Z",
#             "content": "O presidente Jair Bolsonaro afirmou nesta quarta-feira que o aumento do pre\u00e7o do g\u00e1s anunciado pela Petrobras nesta semana, de 39%, \u00e9 \"inadmiss\u00edvel\" e, apesar de dizer que n\u00e3o ir\u00e1 interferir na estat\u2026 [+496 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Estad\u00e3o Conte\u00fado",
#             "title": "Or\u00e7amento p\u00f5e Bolsonaro sob risco de perder base no Congresso ou Guedes",
#             "description": "Presidente tenta encontrar meio-termo ap\u00f3s ouvir de Arthur Lira que o Parlamento n\u00e3o aceita vetos \u00e0 proposta or\u00e7ament\u00e1ria; e do ministro da Economia que, se o texto for sancionado como est\u00e1, abandonar\u00e1 o cargo",
#             "url": "https://www.terra.com.br/economia/orcamento-poe-bolsonaro-sob-risco-de-perder-base-no-congresso-ou-guedes,c42a0b12167be0345f8eb0526d1a3da08wilm12e.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-15T16:01:30Z",
#             "content": "BRAS\u00cdLIA - A novela da san\u00e7\u00e3o do Or\u00e7amento est\u00e1 longe de um cap\u00edtulo final. Em reuni\u00e3o na ter\u00e7a-feira \u00e0 tarde no Pal\u00e1cio do Planalto, o presidente da C\u00e2mara, Arthur Lira (Progressistas-AL), alertou o\u2026 [+6663 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Reuters",
#             "title": "Economia e l\u00edderes do Congresso concordam em rever gastos no Or\u00e7amento e buscam ajustes, diz fonte",
#             "description": "A \u00e1rea econ\u00f4mica do governo e os l\u00edderes do Congresso chegaram a um consenso sobre a necessidade de mudan\u00e7as no Or\u00e7amento aprovado para 2021, e o acordo apon",
#             "url": "https://www.terra.com.br/economia/economia-e-lideres-do-congresso-concordam-em-rever-gastos-no-orcamento-e-buscam-ajustes-diz-fonte,8b8c4af6d686f117ee4e6c62e1f807870ai8bzg1.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-03T19:41:28Z",
#             "content": "A \u00e1rea econ\u00f4mica do governo e os l\u00edderes do Congresso chegaram a um consenso sobre a necessidade de mudan\u00e7as no Or\u00e7amento aprovado para 2021, e o acordo aponta para a revis\u00e3o de premissas de gastos e\u2026 [+4223 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Estad\u00e3o Conte\u00fado",
#             "title": "CPI da Covid: Saiba como Estados usaram o dinheiro federal na pandemia; 17 n\u00e3o detalham gastos",
#             "description": "Parte do valor foi utilizado para pagar sal\u00e1rios e custeio da m\u00e1quina p\u00fablica, o que foi permitido pelo Congresso",
#             "url": "https://www.terra.com.br/noticias/coronavirus/cpi-da-covid-saiba-como-estados-usaram-o-dinheiro-federal-na-pandemia-17-nao-detalham-gastos,3e76cb947a89f5f9b80b8abb54d3e9227e9a73hw.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-20T17:01:17Z",
#             "content": "BRAS\u00cdLIA - Alvo da investiga\u00e7\u00e3o da CPI da Covid, a maneira como os Estados aplicaram a maior parte dos recursos enviados pelo governo federal como socorro financeiro na pandemia \u00e9 ainda uma inc\u00f3gnita\u2026 [+9088 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Reuters",
#             "title": "Educa\u00e7\u00e3o e Economia s\u00e3o os mais afetados em decreto sobre bloqueio or\u00e7ament\u00e1rio",
#             "description": "O governo publicou decreto nesta sexta-feira sobre o bloqueio de dota\u00e7\u00f5es or\u00e7ament\u00e1rias prim\u00e1rias discricion\u00e1rias, sendo os maiores valores referentes aos ...",
#             "url": "https://www.terra.com.br/economia/educacao-e-economia-sao-os-mais-afetados-em-decreto-sobre-bloqueio-orcamentario,fc5d84c0bee9564ecdea8a0fd3a11f96do08tib6.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-23T13:12:10Z",
#             "content": "O governo publicou decreto nesta sexta-feira sobre o bloqueio de dota\u00e7\u00f5es or\u00e7ament\u00e1rias prim\u00e1rias discricion\u00e1rias, sendo os maiores valores referentes aos Minist\u00e9rios da Educa\u00e7\u00e3o e da Economia. \r\nO p\u2026 [+1629 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Reuters",
#             "title": "Governo fixa meta de d\u00e9ficit prim\u00e1rio de R$170,5 bi para 2022 em projeto da LDO",
#             "description": "Em meio \u00e0s incertezas que cercam as contas p\u00fablicas neste ano, a equipe econ\u00f4mica definiu nesta quinta-feira uma meta de d\u00e9ficit prim\u00e1rio de 170,474 bilh\u00f5es",
#             "url": "https://www.terra.com.br/economia/governo-fixa-meta-de-deficit-primario-de-r1705-bi-para-2022-em-projeto-da-ldo,254c91969870db3cd979cdc6e5d612f1jmq3l7b4.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/images.terra.com/2021/04/15/2021-04-15T184828Z_1_LYNXMPEH3E1C8_RTROPTP_4_MACRO-ARRECADACAO-JANEIRO.JPG",
#             "publishedAt": "2021-04-15T18:51:18Z",
#             "content": "Em meio \u00e0s incertezas que cercam as contas p\u00fablicas neste ano, a equipe econ\u00f4mica definiu nesta quinta-feira uma meta de d\u00e9ficit prim\u00e1rio de 170,474 bilh\u00f5es de reais para o governo central em 2022, s\u2026 [+1834 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Estad\u00e3o Conte\u00fado",
#             "title": "'Sobra' de recursos do Bolsa Fam\u00edlia pode resolver impasse do Or\u00e7amento",
#             "description": "Folga propiciada pela transfer\u00eancia de benefici\u00e1rios do Bolsa para o aux\u00edlio emergencial deve render economia de at\u00e9 R$ 8 bi - h\u00e1, por\u00e9m, entrave legal para adotar sa\u00edda; Bolsonaro tem at\u00e9 dia 22 para sancionar lei",
#             "url": "https://www.terra.com.br/economia/sobra-de-recursos-do-bolsa-familia-pode-resolver-impasse-do-orcamento,1126eaf253ead65807067e8b11e2cbc4y5ng3p4e.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-17T16:01:19Z",
#             "content": "BRAS\u00cdLIA - A fim de evitar indisposi\u00e7\u00e3o com o Congresso, o governo mira em cortar despesas pr\u00f3prias para resolver o impasse do Or\u00e7amento de 2021. O uso da \"sobra\" de recursos do Bolsa Fam\u00edlia \u00e9 uma d\u2026 [+3684 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Estad\u00e3o Conte\u00fado",
#             "title": "'Empres\u00e1rios querem ambiente pol\u00edtico calmo'",
#             "description": "O ministro das Comunica\u00e7\u00f5es, F\u00e1bio Faria, disse ao Estad\u00e3o que o governo far\u00e1 encontros peri\u00f3dicos com representantes do PIB para medir a temperatura",
#             "url": "https://www.terra.com.br/noticias/brasil/politica/empresarios-querem-ambiente-politico-calmo,02453610bd6cd3e58581fecf30c18707zdhwfzbc.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-09T16:08:23Z",
#             "content": "O ministro das Comunica\u00e7\u00f5es, F\u00e1bio Faria, disse ao Estad\u00e3o que o governo far\u00e1 encontros peri\u00f3dicos com representantes do PIB para medir a temperatura da crise e encontrar solu\u00e7\u00f5es conjuntas. Dono de \u2026 [+9989 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Estad\u00e3o Conte\u00fado",
#             "title": "Bolsa fecha em baixa de 1,18%, a 115.253,31 pontos, mas avan\u00e7a 0,41% na semana",
#             "description": "Em mais uma sess\u00e3o desconectado do exterior, com ganhos de at\u00e9 1,76% em Nova York (Nasdaq) e petr\u00f3leo em alta superior a 3% (Brent e WTI), o Ibo",
#             "url": "https://www.terra.com.br/economia/bolsa-fecha-em-baixa-de-118-a-11525331-pontos-mas-avanca-041-na-semana,49753907a7a4a201b32250f154bef68cegj954xq.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-01T21:07:26Z",
#             "content": "Em mais uma sess\u00e3o desconectado do exterior, com ganhos de at\u00e9 1,76% em Nova York (Nasdaq) e petr\u00f3leo em alta superior a 3% (Brent e WTI), o Ibovespa iniciou o m\u00eas colocando no bolso uma fra\u00e7\u00e3o do ga\u2026 [+3242 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Estad\u00e3o Conte\u00fado",
#             "title": "Os 'rompedores do teto' est\u00e3o ganhando a guerra, diz s\u00f3cio da consultoria\u00a0Tend\u00eancias",
#             "description": "Para o economista Nathan Blanche, a situa\u00e7\u00e3o fiscal do Brasil nunca foi t\u00e3o preocupante, exceto no per\u00edodo do governo de Fernando Collor de Mello",
#             "url": "https://www.terra.com.br/noticias/coronavirus/os-rompedores-do-teto-estao-ganhando-a-guerra-diz-socio-da-consultoria-tendencias,7367198bdb7fceca2c384b293a49c6f8zjo1t5kf.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-21T15:25:17Z",
#             "content": "BRAS\u00cdLIA - Mesmo com a perspectiva de acordo entre governo e Congresso para san\u00e7\u00e3o do Or\u00e7amento de 2021 na quinta-feira (22), o problema fiscal brasileiro est\u00e1 longe de uma solu\u00e7\u00e3o. \r\nPara o economis\u2026 [+3379 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Deutsche Welle",
#             "title": "\"Sem vacina\u00e7\u00e3o em massa, nova rodada do aux\u00edlio ter\u00e1 que ser estendida\"",
#             "description": "Governo retomar\u00e1 transfer\u00eancias em abril, por quatro meses. Novos valores, de R$ 150 a R$ 375, s\u00e3o insuficientes para isolamento social prolongado, diz econo",
#             "url": "https://www.terra.com.br/noticias/sem-vacinacao-em-massa-nova-rodada-do-auxilio-tera-que-ser-estendida,f4f04db38b9111f5efdbb19638ff90a74acp1xcm.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-03-28T08:26:25Z",
#             "content": "Governo retomar\u00e1 transfer\u00eancias em abril, por quatro meses. Novos valores, de R$ 150 a R$ 375, s\u00e3o insuficientes para isolamento social prolongado, diz economista da UFPE.Ap\u00f3s atravessarem os tr\u00eas pr\u2026 [+9334 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Estad\u00e3o Conte\u00fado",
#             "title": "Juros recuam com fala de Kanczuk, melhora no c\u00e2mbio e exterior favor\u00e1vel",
#             "description": "Os juros futuros fecharam a sess\u00e3o regular em queda firme, devolvendo, numa tacada s\u00f3, boa parte do aumento da inclina\u00e7\u00e3o visto desde o fim de m",
#             "url": "https://www.terra.com.br/economia/juros-recuam-com-fala-de-kanczuk-melhora-no-cambio-e-exterior-favoravel,135fe26f2bc6fcd0777802db0625f9435d3dqcyz.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-08T21:03:26Z",
#             "content": "Os juros futuros fecharam a sess\u00e3o regular em queda firme, devolvendo, numa tacada s\u00f3, boa parte do aumento da inclina\u00e7\u00e3o visto desde o fim de mar\u00e7o na curva, com as taxas intermedi\u00e1rias e longas rec\u2026 [+2734 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Reuters",
#             "title": "Relator recomenda arquivamento de caso de Eduardo Bolsonaro no Conselho de \u00c9tica",
#             "description": "O relator do caso de Eduardo Bolsonaro (PSL-SP) no Conselho de \u00c9tica na C\u00e2mara, Igor Timo (Podemos-MG), recomendou nesta segunda-feira o arquivamento da repr",
#             "url": "https://www.terra.com.br/noticias/brasil/relator-recomenda-arquivamento-de-caso-de-eduardo-bolsonaro-no-conselho-de-etica,b3ba9de104acd6bb73066b49c3c36362shj8y1tk.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/images.terra.com/2021/04/05/48912.jpg",
#             "publishedAt": "2021-04-05T20:05:51Z",
#             "content": "O relator do caso de Eduardo Bolsonaro (PSL-SP) no Conselho de \u00c9tica na C\u00e2mara, Igor Timo (Podemos-MG), recomendou nesta segunda-feira o arquivamento da representa\u00e7\u00e3o contra o deputado por quebra de \u2026 [+3261 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Terra.com.br"
#             },
#             "author": "Estad\u00e3o Conte\u00fado",
#             "title": "Guedes recha\u00e7a a investidores classifica\u00e7\u00e3o de 'fura-teto' de PEC da covid",
#             "description": "Em encontro virtual, ministro da Economia disse que inten\u00e7\u00e3o da PEC \u00e9 tentar resolver a necessidade de mais despesas no momento e refor\u00e7ou que a prioridade agora \u00e9 o combate \u00e0 pandemia",
#             "url": "https://www.terra.com.br/noticias/coronavirus/guedes-rechaca-a-investidores-classificacao-de-fura-teto-de-pec-da-covid,7ca939d8370aee2f75fb3f125c1cde53ghzozpcz.html",
#             "urlToImage": "https://p2.trrsf.com/image/fget/cf/1200/628/middle/s1.trrsf.com/atm/3/core/_img/terra-logo-white-bg-v3.jpg",
#             "publishedAt": "2021-04-13T22:56:27Z",
#             "content": "O ministro da Economia, Paulo Guedes, disse a investidores nesta ter\u00e7a-feira, 13, que n\u00e3o considera a Proposta de Emenda \u00e0 Constitui\u00e7\u00e3o (PEC) - que deixa algumas despesas ligadas \u00e0 pandemia, como as \u2026 [+2733 chars]"
#         }
#     ]
# }

# %%
dict_pres['articles'][:3]
# Out:
# [{'source': {'id': None, 'name': 'The Intercept'},
#   'author': 'Rafael Moro Martins, Leandro Demori',
#   'title': 'Imprensa dá voz à farsa de que generais se descolaram de Bolsonaro, mas militares seguem afundados no governo',
#   'description': 'Forças Armadas tentam saída à francesa da festa de terror que ajudaram a criar. Digitais dos quartéis estão nos mais de 317 mil mortos da pandemia.\nThe post Imprensa dá voz à farsa de que generais se descolaram de Bolsonaro, mas militares seguem afundados no …',
#   'url': 'https://theintercept.com/2021/03/30/imprensa-farsa-militares-governo-bolsonaro/',
#   'urlToImage': 'https://theintercept.imgix.net/wp-uploads/sites/1/2021/03/destt-1.jpg?auto=compress%2Cformat&q=90&fit=crop&w=1200&h=800',
#   'publishedAt': '2021-03-30T22:25:20Z',
#   'content': 'O Alto Comando das forças armadas\r\n manda um recado a Bolsonaro: não cederá ao golpismo e nem irá politizar os quartéis, avisa a imprensa brasileira num uníssono narrativo que não se ouvia desde os á… [+11258 chars]',
#   'source_name': 'The Intercept'},
#  {'source': {'id': None, 'name': 'The Intercept'},
#   'author': 'Lucas Rezende',
#   'title': 'Militares ficarão abraçados a Bolsonaro até o fim do governo',
#   'description': 'Mesmo que surjam novos atritos, generais estão de cabeça na missão. Conheça 4 cenários para o futuro – nenhum é bom para a democracia.\nThe post Militares ficarão abraçados a Bolsonaro até o fim do governo appeared first on The Intercept.',
#   'url': 'https://theintercept.com/2021/04/13/militares-ficarao-abracados-a-bolsonaro-ate-o-fim-do-governo/',
#   'urlToImage': 'https://theintercept.com/wp-uploads/sites/1/2021/04/vozes-milbols.jpg',
#   'publishedAt': '2021-04-13T17:00:55Z',
#   'content': 'Foto: André Coelho/Bloomberg via Getty Images\r\nA demissão do ministro da Defesa,\r\n general Fernando Azevedo e Silva, e dos dos três comandantes das Forças Armadas brasileiras a dois dias do aniversár… [+14139 chars]',
#   'source_name': 'The Intercept'},
#  {'source': {'id': None, 'name': 'Publico.pt'},
#   'author': 'manuel.carvalho@publico.pt',
#   'title': 'O Brasil caminha sobre brasas',
#   'description': 'Há muito que deixou de valer a pena avaliar Bolsonaro pela sua incoerência, pela demagogia, pela propensão para a mentira ou pela defesa de doutrinas autoritárias. Hoje, é mais judicioso julgá-lo pela sua incompetência estrutural e pela irresponsabilidade mor…',
#   'url': 'https://www.publico.pt/2021/03/30/mundo/noticia/brasil-caminha-brasas-1956580',
#   'urlToImage': 'https://imagens.publico.pt/imagens.aspx/1525298?tp=UH&db=IMAGENS&type=JPG&share=1&o=BarraFacebook_Publico.png',
#   'publishedAt': '2021-03-30T20:30:31Z',
#   'content': 'Seis substituições de ministros na maior remodelação em décadas, demissão em bloco dos chefes dos três ramos das Forças Armadas na maior crise militar desde a ditadura, aumento da influência do “cent… [+2502 chars]',
#   'source_name': 'Publico.pt'}]

# %%
pretty_sources = json.dumps(resp_sources.json(), indent=4)
print(pretty_sources)
# Out:
# {
#     "status": "ok",
#     "sources": [
#         {
#             "id": "blasting-news-br",
#             "name": "Blasting News (BR)",
#             "description": "Descubra a se\u00e7\u00e3o brasileira da Blasting News, a primeira revista feita pelo  p\u00fablico, com not\u00edcias globais e v\u00eddeos independentes. Junte-se a n\u00f3s e torne- se um rep\u00f3rter.",
#             "url": "https://br.blastingnews.com",
#             "category": "general",
#             "language": "pt",
#             "country": "br"
#         },
#         {
#             "id": "globo",
#             "name": "Globo",
#             "description": "S\u00f3 na globo.com voc\u00ea encontra tudo sobre o conte\u00fado e marcas do Grupo Globo. O melhor acervo de v\u00eddeos online sobre entretenimento, esportes e jornalismo do Brasil.",
#             "url": "http://www.globo.com/",
#             "category": "general",
#             "language": "pt",
#             "country": "br"
#         },
#         {
#             "id": "google-news-br",
#             "name": "Google News (Brasil)",
#             "description": "Cobertura jornal\u00edstica abrangente e atualizada, agregada de fontes do mundo inteiro pelo Google Not\u00edcias.",
#             "url": "https://news.google.com",
#             "category": "general",
#             "language": "pt",
#             "country": "br"
#         }
#     ]
# }
